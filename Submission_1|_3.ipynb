# %% [markdown]
# <a href="https://colab.research.google.com/github/radhika004/CustomerSupportTickets/blob/main/Submission_1%7C_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/customer_support.csv")

# %%
data.head()
# Out:
#               id                                            subject  \
# 0  1001352387736  Urgent: Critical impact on enterprise network ...
# 1  1004699418379     Intermittent Cursor Freezing Issue on Dell XPS
# 2  1006966905046  Dringend: Unterstützung für die Datenwiederher...
# 3  1009231330404           Anfrage zu den MacBook Air M1 Funktionen
# 4  1024440081041  Solicitação de Assistência com Erro de Instala...
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support,<br><br>I hope this mess...
# 2  Hallo, wir haben severe Datenverluste in MySQL...
# 3  Sehr geehrtes Kundenserviceteam,\n\n\nich hoff...
# 4  Caro Suporte ao Cliente,\n\n\nEstou enfrentand...
#
#                                               answer      type  \
# 0  Subject: Re: Urgent: Critical impact on enterp...  Incident
# 1  Dear <name>,\n\n\nThank you for reaching out r...  Incident
# 2  Hallo, vielen Dank, dass Sie uns kontaktiert h...  Incident
# 3  Sehr geehrter <name>,\n\n\nvielen Dank für Ihr...   Request
# 4  Caro <name>,\n\n\nObrigado por entrar em conta...   Problem
#
#                  queue priority language      business_type  \
# 0    Technical Support     high       en        IT Services
# 1      Product Support      low       en  Tech Online Store
# 2    Technical Support     high       de        IT Services
# 3  Sales and Pre-Sales      low       de  Tech Online Store
# 4    Technical Support   medium       pt        IT Services
#
#                tag_1            tag_2              tag_3               tag_4  \
# 0     Service Outage    Network Issue       Urgent Issue   Technical Support
# 1  Technical Support  Product Support   Hardware Failure  Problem Resolution
# 2        Data Breach   Backup Restore  Technical Support        Urgent Issue
# 3   Customer Service  Product Support      Sales Inquiry  Technical Guidance
# 4  Technical Support     Software Bug       Urgent Issue  Problem Resolution
#
#                 tag_5               tag_6                  tag_7  \
# 0  Problem Resolution    Critical Failure           System Crash
# 1        Urgent Issue    Service Recovery  Documentation Request
# 2        Software Bug  Problem Resolution                    NaN
# 3      Warranty Claim     General Inquiry                    NaN
# 4     Product Support                 NaN                    NaN
#
#                 tag_8  tag_9
# 0  Service Disruption    NaN
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN

# %%
data_en = data.loc[data["language"].eq("en"),:]
data_en.head()
# Out:
#               id                                            subject  \
# 0  1001352387736  Urgent: Critical impact on enterprise network ...
# 1  1004699418379     Intermittent Cursor Freezing Issue on Dell XPS
# 5  1024619926727    Exchange Request for Malfunctioning Dell XPS 13
# 6  1026487543175       Request for Server Administration Assistance
# 7  1027850274374   Immediate Attention Required: AWS Outage Concern
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support,<br><br>I hope this mess...
# 5  Dear Tech Online Store Customer Support,\n\n\n...
# 6  Dear IT Services Customer Support, \n\n\nWe ar...
# 7  Greetings IT Services Customer Support,\n\n\nI...
#
#                                               answer      type  \
# 0  Subject: Re: Urgent: Critical impact on enterp...  Incident
# 1  Dear <name>,\n\n\nThank you for reaching out r...  Incident
# 5  Dear <name>,\n\n\nThank you for reaching out a...    Change
# 6  Subject: Re: Request for Server Administration...   Request
# 7  Hello <name>,\n\n\nWe appreciate you informing...  Incident
#
#                    queue priority language      business_type  \
# 0      Technical Support     high       en        IT Services
# 1        Product Support      low       en  Tech Online Store
# 5  Returns and Exchanges   medium       en  Tech Online Store
# 6        Product Support   medium       en        IT Services
# 7      Technical Support     high       en        IT Services
#
#                    tag_1                tag_2               tag_3  \
# 0         Service Outage        Network Issue        Urgent Issue
# 1      Technical Support      Product Support    Hardware Failure
# 5  Returns and Exchanges  Product Replacement    Customer Service
# 6      Technical Support           IT Support  Performance Tuning
# 7         Service Outage         Urgent Issue          IT Support
#
#                 tag_4               tag_5             tag_6  \
# 0   Technical Support  Problem Resolution  Critical Failure
# 1  Problem Resolution        Urgent Issue  Service Recovery
# 5   Technical Support         Order Issue               NaN
# 6  Problem Resolution  Technical Guidance  Service Recovery
# 7  System Maintenance     Incident Report  Customer Service
#
#                    tag_7               tag_8  tag_9
# 0           System Crash  Service Disruption    NaN
# 1  Documentation Request                 NaN    NaN
# 5                    NaN                 NaN    NaN
# 6                    NaN                 NaN    NaN
# 7                    NaN                 NaN    NaN

# %%
# subject and body
tickets = data_en.loc[:, ["subject", "body"]].apply(lambda x: f"subject: {x['subject']} \n\n\n Body: {x['body']}", axis=1)

# %%
# subject and answer
ticket_answer = data_en.loc[:,["subject","answer"]].apply(lambda x:f"subject:{x['subject']} \n answer:{x['answer']}",axis=1)

# %%
print(tickets[0])
# Out:
# subject: Urgent: Critical impact on enterprise network connectivity
#
#
#  Body: Dear Customer Support Team, We are experiencing a complete outage affecting our enterprise network involving Cisco Router ISR4331. This disruption is critically impacting our secure WAN connectivity across all domains, urgently requiring your immediate intervention. Due to this issue, our company has halted various essential operations, significantly affecting our services and commitments to clients. As our technical team has not been able to resolve the problem internally, we need your expert support to diagnose and rectify this issue swiftly. Please consider this a high priority and provide us with the necessary technical assistance to restore our network’s functionality. Thank you for your prompt attention. Best regards, <name>, IT Manager at <company>

# %%
print(ticket_answer[0])
# Out:
# subject:Urgent: Critical impact on enterprise network connectivity
#  answer:Subject: Re: Urgent: Critical impact on enterprise network connectivity
#
#
# Dear <name>,
#
#
# Thank you for reaching out to us regarding the critical outage affecting your Cisco Router ISR4331.
#
#
# We understand the urgency and impact of this issue on your operations. Our technical support team is prioritizing your case and will promptly begin diagnosing the problem to facilitate a quick resolution.
#
#
# Please ensure all relevant technical logs are available for our team to access, which will assist in expediting the diagnostic process. We will maintain close communication and provide updates as our investigation proceeds.
#
#
# Your patience and cooperation are greatly appreciated, and we're committed to resolving this matter as swiftly as possible.
#
#
# Best regards,
#
#
# Customer Support Team

# %%
# removing stop words and applying lammetization

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words and word.isalnum()]
    return " ".join(words)

processed_tickets = tickets.apply(preprocess_text)

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(processed_tickets)

tfidf_matrix
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# <339x1936 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16786 stored elements in Compressed Sparse Row format>

# %%
# PCAs

from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca_result = pca.fit_transform(tfidf_matrix.toarray())
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2', 'PC3'])

pca_df
# Out:
#           PC1       PC2       PC3
# 0   -0.130984  0.319533  0.020532
# 1   -0.150997 -0.151325  0.059677
# 2   -0.161961 -0.268909  0.074006
# 3    0.065946 -0.026010 -0.313476
# 4    0.203016  0.111567  0.009834
# ..        ...       ...       ...
# 334  0.240192  0.098514  0.121834
# 335  0.107350  0.119993 -0.295124
# 336 -0.210467  0.343919  0.094171
# 337 -0.151002 -0.226354  0.102842
# 338  0.046978  0.066278 -0.276599
#
# [339 rows x 3 columns]

# %%
# combine and form token of tags

import pandas as pd

def combine_tags(row):
    tags = []
    for i in range(1, 10):  # Assuming tags are from tag_1 to tag_9
        tag_col = f"tag_{i}"
        if tag_col in row and pd.notna(row[tag_col]):
            tags.append(str(row[tag_col]))
    return " ".join(tags)

data_en['combined_tags'] = data_en.apply(combine_tags, axis=1)

# Calculate value counts for unique strings of combined tags
tag_counts = data_en['combined_tags'].value_counts().reset_index()
tag_counts.columns = ['combined_tags', 'count']

tag_counts
# Out:
# <ipython-input-16-1371f4c4e4a3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_en['combined_tags'] = data_en.apply(combine_tags, axis=1)
#                                          combined_tags  count
# 0    Technical Support Product Support IT Support P...      3
# 1    Technical Support Product Support General Inqu...      2
# 2    Technical Support Urgent Issue Software Bug Pr...      2
# 3    Network Issue Technical Support Urgent Issue P...      2
# 4    Urgent Issue IT Support Service Disruption Inc...      2
# ..                                                 ...    ...
# 327  Product Support Technical Support Warranty Cla...      1
# 328  IT Support Urgent Issue Network Issue Technica...      1
# 329  Technical Support Urgent Issue Problem Resolut...      1
# 330  Technical Support Urgent Issue Software Bug Ac...      1
# 331  IT Support Urgent Issue Network Issue Problem ...      1
#
# [332 rows x 2 columns]

# %%
# !pip install nltk
import nltk
nltk.download('punkt_tab')
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
def preprocess_and_tokenize_tags(row):
    """Combines and tokenizes tags from tag_1 to tag_4."""
    tag_columns = [f"tag_{i}" for i in range(1, 4)]
    tags = " ".join(str(row[col]) for col in tag_columns if pd.notna(row[col]) and row[col] != '')

    nltk.download('punkt', quiet=True)
    nltk.download('stopwords', quiet=True)
    nltk.download('wordnet', quiet=True)

    tokens = nltk.word_tokenize(tags.lower())
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words and token.isalnum()]  # Keep only alphanumeric tokens

    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    return " ".join(sorted(set(tokens)))

data_en['combined_tags'] = data_en.apply(preprocess_and_tokenize_tags, axis=1)
data_en['combined_tags'].value_counts()
# Out:
# <ipython-input-18-1cf58d476687>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_en['combined_tags'] = data_en.apply(preprocess_and_tokenize_tags, axis=1)
# combined_tags
# failure hardware product support technical               19
# issue network support technical urgent                   18
# disruption issue service support technical urgent        17
# bug product software support technical                   16
# bug issue software support technical urgent              12
#                                                          ..
# exchange product replacement return support technical     1
# guidance notification service support technical           1
# customer product service support technical                1
# access email issue support technical urgent               1
# issue network problem resolution urgent                   1
# Name: count, Length: 123, dtype: int64

# %%
# PCA variance plot

import matplotlib.pyplot as plt

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Scree plot
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid(True)
plt.show()

# %%
# plot 3 PCAs for answer column
import plotly.express as px

fig = px.scatter_3d(pca_df, x='PC1', y='PC2', z='PC3', color=data_en['tag_1'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dfdcdee6-f42c-4edd-916f-77e152542ed9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfdcdee6-f42c-4edd-916f-77e152542ed9")) {                    Plotly.newPlot(                        "dfdcdee6-f42c-4edd-916f-77e152542ed9",                        [{"hovertemplate":"color=Service Outage\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Service Outage","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Service Outage","scene":"scene","showlegend":true,"x":[-0.13098413973773632,0.20301607004913325,0.15857011229405907,0.07669565727361015,-0.07329457396686527,0.2651536216373946,0.20842223105156196,0.08755484864850029,-0.011300346536852045,-0.007332548325535391,0.009852212352495063,0.21813921412871104,0.20456041500243255],"y":[0.31953319347573866,0.11156677541569977,0.07331015140438871,0.16726422305497032,0.2587296420941591,0.14857611473770413,0.1487593104237142,0.15548104496520163,0.06349756651607895,0.031398364430687775,0.04792014779508903,0.10761085371801526,0.10789224901794225],"z":[0.02053194241294956,0.009833694484461813,-0.018410141844967542,-0.27651463816931426,0.028475953877435595,0.08778133080441841,0.0027482861448145613,-0.24800549898196675,-0.0804296350111575,-0.07694650311161721,-0.07338951909235956,0.030696971166328114,0.0342143230734731],"type":"scatter3d"},{"hovertemplate":"color=Technical Support\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technical Support","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Technical Support","scene":"scene","showlegend":true,"x":[-0.15099705398528313,0.06594591540663235,0.015569422043421825,0.16217049022193245,0.3243885523727971,0.062468280027610776,-0.1466869829216962,0.3086993491316358,-0.2373328254577375,-0.14872184808968336,-0.10441623581529887,-0.213193110697385,-0.030655546280341596,-0.1726401583059009,-0.02264141162033699,0.1801353197407656,-0.19183096133088406,-0.20811352693475899,-0.051109010078872155,0.30924704461371166,-0.011432685189759893,-0.15411412666055446,-0.09060916309195073,-0.15721363931563073,-0.17540161795959994,-0.0916272613819369,-0.15692404304452653,-0.14527228483009388,-0.1959645722369181,-0.11394541517477881,-0.07471927626548833,-0.10182121609261556,-0.02622379361728726,-0.06870418269743235,-0.09164040340666021,-0.12701749281140864,-0.0008580881378366463,-0.12598236838816854,-0.12265076620260618,-0.19587230657140256,0.05001486938465871,0.09629991917389737,-0.2972587266934098,-0.0005200811572261345,-0.17913860247321262,-0.13428974374596522,-0.182722989551242,-0.01046270356822913,0.013706437480890012,-0.03513898112778053,0.06811847759130281,-0.12958369120573024,-0.1778523371868387,-0.10310755216241639,0.29125104604120405,-0.13011368810701143,-0.1974950800105927,-0.008246064216386014,0.035756664074248073,0.025895230229598217,0.30760490125178447,-0.0824934128694024,-0.12226316657481023,0.013360444883720781,0.3897538708690011,0.14595861489840603,-0.06959084144269197,0.022325955476319305,-0.13770071005077988,-0.005842839679420273,0.3458605132965035,-0.17883986267273902,-0.10381196419374102,0.47614505128699447,-0.007871506402393352,-0.04051985037062053,0.028964682225206075,0.31947830387029374,-0.18342777761589676,-0.1499096023085979,0.02520702883285023,-0.213484657725664,-0.11528860982479151,-0.1452509149738197,-0.17900750128477155,-0.2250867827031587,-0.19661150947605174,0.17965137207504206,-0.10863549381754167,-0.12066637099703134,-0.18487497743137263,0.20589905123763433,0.37657013351785124,-0.11866977541078426,-0.05501825276550341,0.0045319202491342315,0.31146 ...

# %%
import plotly.express as px

fig = px.scatter_3d(pca_df, x='PC1', y='PC2', z='PC3', color=data_en.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f65407dc-ed3a-475a-9f9c-ae71e13e75a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f65407dc-ed3a-475a-9f9c-ae71e13e75a5")) {                    Plotly.newPlot(                        "f65407dc-ed3a-475a-9f9c-ae71e13e75a5",                        [{"hovertemplate":"PC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0,1,5,6,7,8,11,13,18,20,21,23,24,26,32,37,39,40,43,48,49,52,53,56,59,63,65,66,70,72,74,78,81,82,83,84,87,92,95,104,106,107,112,116,117,118,120,121,123,127,129,130,131,136,137,140,143,146,148,153,156,160,161,163,167,168,169,170,171,173,174,176,183,184,190,191,194,197,201,202,203,205,207,213,214,221,222,224,225,226,228,233,234,236,240,241,244,249,251,253,256,265,268,269,271,272,277,278,279,281,283,284,291,293,296,302,305,309,310,315,318,322,327,332,334,338,342,345,347,349,350,354,358,361,367,372,373,375,378,379,383,384,386,390,400,401,408,412,413,414,416,417,418,422,424,426,430,431,433,437,438,444,448,449,451,453,454,461,468,469,472,480,482,484,487,488,493,495,497,500,501,506,512,514,518,519,521,528,530,536,543,544,570,571,572,579,581,584,587,591,596,598,599,600,603,611,612,613,619,622,623,626,629,632,633,636,640,644,645,653,662,672,680,686,687,689,690,705,706,707,708,714,719,720,725,729,732,737,748,756,759,775,776,779,780,789,790,791,792,809,813,814,817,820,825,832,845,847,853,867,872,874,877,879,892,894,895,906,917,919,921,928,931,935,946,961,969,980,993,998,1009,1026,1027,1036,1037,1041,1058,1060,1061,1062,1064,1090,1092,1100,1101,1108,1121,1129,1134,1136,1143,1147,1158,1162,1173,1175,1222,1232,1236,1277,1282,1289,1299,1301,1314,1324,1330,1340,1343,1346,1354,1364,1371,1378,1385,1395,1408,1423,1430,1435,1440,1447,1498,1512,1517,1528,1536,1537,1561],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.13098413973773632,-0.15099705398528313,-0.1619605260578364,0.06594591540663235,0.20301607004913325,0.015569422043421825,-0.050539494854982873,0.16217049022193245,0.3243885523727971,0.062468280027610776,0.10016417179241223,-0.1466869829216962,0.15942021231649472,0.3086993491316358,-0.004829142838485324,-0.2373328254577375,-0.22314900694639156,0.2410411066121989,0.18903745720900958,-0.06630464314253147,-0.14872184808968336,-0.10441623581529887,-0.213193110697385,0.05023678365944081,-0.030655546280341596,-0.20749330005203553,-0.1842270051068904,-0.1726401583059009,-0.02264141162033699,0.1801353197407656,-0.19183096133088406,-0.20811352693475899,0.24498865170353556,-0.051109010078872155,0.30924704461371166,0.39865183965431744,0.08716445418399801,-0.011432685189759893,-0.15411412666055446,0.03772740043447148,-0.09060916309195073,0.252572253761566,0.04263726324944573,0.030220484106205807,-0.22552447509013568,-0.15721363931563073,-0.17540161795959994,-0.0916272613819369,-0.15692404304452653,-0.14527228483009388,-0.1959645722369181,-0.11394541517477881,-0.07471927626548833,-0.1638871221924306,-0.10182121609261556,-0.02622379361728726,-0.06870418269743235,-0.09164040340666021,-0.12701749281140864,-0.01154897195246541,0.06109020924710484,0.05252651645816428,-0.0008580881378366463,-0.12598236838816854,-0.12265076620260618,-0.19587230657140256,0.05001486938465871,0.24246424833313351,-0.053069749269411624,0.09629991917389737,-0.020373543835256747,-0.2972587266934098,0.047005479703093815,-0.0005200811572261345,-0.17913860247321262,-0.13428974374596522,-0.182722989551242,0.22165613335295004,0.059101360835737374,-0.14696910617656955,0.15857011229405907,-0.01046270356822913,-0.06159338667429817,0.013706437480890012,-0.03513898112778053,0.06811847759130281, ...

# %%
data_en.loc[[48, 59], ["subject"]].values
# Out:
# array([['Urgent: User unable to join scheduled Zoom meeting'],
#        ['Urgent Assistance Needed for Zoom Issues']], dtype=object)

# %%
data_en.loc[[980, 817, 293, 433, 43, 633], ["subject"]].values
# Out:
# array([['Urgent Issue with AWS Deployment'],
#        ['Immediate Attention Required'],
#        ['Urgent Assistance Needed for AWS Access Issue'],
#        ['Critical: Significant AWS Service Disruption'],
#        ['Urgent AWS Connectivity Issue'],
#        ['Urgent: AWS Downtime Issue']], dtype=object)

# %%
data_en.loc[[26, 518, 980, 1173, 1512], ["subject"]].values
# Out:
# array([['Urgent Care Needed: Issue with AWS Deployment'],
#        ['Critical: Problem with AWS Deployment'],
#        ['Urgent Issue with AWS Deployment'],
#        ['Urgent Assistance Needed: Issue with AWS Deployment'],
#        ['Urgent Assistance Required: Issue with AWS Deployment']],
#       dtype=object)

# %%
data_en.loc[[1346, 1324, 1330, 1343], ["subject"]].values
# Out:
# array([['Help with Printer Configuration'],
#        ['Immediate Help Required'],
#        ['Seeking Assistance: Router Leading to Network Disruptions'],
#        ['Immediate Support Required: Cisco ISR4331 Router Outage']],
#       dtype=object)

# %%
data_en.loc[[194, 626, 536, 906, 53, 931], ["subject"]].values
# Out:
# array([['Assistance Needed for Printer Setup'],
#        ['Help Needed: Printer Connection Problem'],
#        ['Request for Printer Exchange'],
#        ['Help Needed for Printer Connection Issue'],
#        ['Wi-Fi Connectivity Issues with Canon PIXMA MG3620 Printer'],
#        ['Issue with Canon PIXMA MG3620 Wi-Fi Connection']], dtype=object)

# %%
#  3d tsne of tfidf_matrix.toarray() and plot a 3d plotly express graph assign index for each color

import plotly.express as px
from sklearn.manifold import TSNE

tsne = TSNE(n_components=3, random_state=0)
tsne_result = tsne.fit_transform(tfidf_matrix.toarray())
tsne_df = pd.DataFrame(data=tsne_result, columns=['TSNE1', 'TSNE2', 'TSNE3'])

fig = px.scatter_3d(tsne_df, x='TSNE1', y='TSNE2', z='TSNE3', color=data_en.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1005b682-41ab-414a-9dc7-a5fe6a403e30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1005b682-41ab-414a-9dc7-a5fe6a403e30")) {                    Plotly.newPlot(                        "1005b682-41ab-414a-9dc7-a5fe6a403e30",                        [{"hovertemplate":"TSNE1=%{x}\u003cbr\u003eTSNE2=%{y}\u003cbr\u003eTSNE3=%{z}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0,1,5,6,7,8,11,13,18,20,21,23,24,26,32,37,39,40,43,48,49,52,53,56,59,63,65,66,70,72,74,78,81,82,83,84,87,92,95,104,106,107,112,116,117,118,120,121,123,127,129,130,131,136,137,140,143,146,148,153,156,160,161,163,167,168,169,170,171,173,174,176,183,184,190,191,194,197,201,202,203,205,207,213,214,221,222,224,225,226,228,233,234,236,240,241,244,249,251,253,256,265,268,269,271,272,277,278,279,281,283,284,291,293,296,302,305,309,310,315,318,322,327,332,334,338,342,345,347,349,350,354,358,361,367,372,373,375,378,379,383,384,386,390,400,401,408,412,413,414,416,417,418,422,424,426,430,431,433,437,438,444,448,449,451,453,454,461,468,469,472,480,482,484,487,488,493,495,497,500,501,506,512,514,518,519,521,528,530,536,543,544,570,571,572,579,581,584,587,591,596,598,599,600,603,611,612,613,619,622,623,626,629,632,633,636,640,644,645,653,662,672,680,686,687,689,690,705,706,707,708,714,719,720,725,729,732,737,748,756,759,775,776,779,780,789,790,791,792,809,813,814,817,820,825,832,845,847,853,867,872,874,877,879,892,894,895,906,917,919,921,928,931,935,946,961,969,980,993,998,1009,1026,1027,1036,1037,1041,1058,1060,1061,1062,1064,1090,1092,1100,1101,1108,1121,1129,1134,1136,1143,1147,1158,1162,1173,1175,1222,1232,1236,1277,1282,1289,1299,1301,1314,1324,1330,1340,1343,1346,1354,1364,1371,1378,1385,1395,1408,1423,1430,1435,1440,1447,1498,1512,1517,1528,1536,1537,1561],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-4.3904715,-25.219141,-6.0681443,14.028312,-13.04326,12.912165,22.617558,-27.069279,-5.887887,1.3783356,11.305013,19.878176,-11.5613,-29.929062,-26.748041,18.929575,5.9518466,-5.8160825,-12.440239,-23.15731,-11.000136,-7.020199,12.738685,14.811116,-13.928618,7.2618823,-20.606339,12.07258,0.5147504,-18.690697,-3.1598148,-5.34539,2.5663238,-18.550583,-21.52618,-11.997358,-7.2173514,24.948427,23.527742,27.288136,-0.07302681,-15.550209,16.797283,-0.31208226,2.071127,-16.572895,-11.750374,-5.287952,-20.557917,-11.007781,-22.819647,-6.925101,-2.856456,-4.501788,-4.566559,35.14654,8.609159,-18.906218,12.332475,3.9932988,-8.701506,0.7191856,16.369055,-6.0550156,14.239774,14.543022,21.846832,-24.607134,-9.731794,12.46818,-5.473298,9.36347,5.2530947,2.7274795,18.005608,0.48974937,17.34942,2.2677474,-20.961195,-5.4387617,-7.924855,29.465504,24.892904,11.966374,-30.704575,17.771036,20.039513,6.412745,19.365822,-4.2556167,6.58607,-3.5921896,11.104213,-3.230762,29.073057,7.133326,-0.18793969,15.898775,1.1252878,-24.085674,15.406962,23.186693,30.573002,22.943851,7.3476396,-1.398303,4.714613,0.6764483,-6.284143,25.7235,-1.2779565,3.9047074,-9.106858,-32.574,-26.842789,-4.875662,-27.824265,14.936114,17.191671,-5.2590094,30.724428,18.118814,11.283696,4.976541,-24.568684,-4.0686903,-15.857525,20.711628,25.31307,23.608803,-7.571603,20.696447,3.543571,12.48983,10.197103,11.159361,-2.129346,-2.1456077,-13.585343,-20.888472,2.5205116,9.723678,17.271935,-11.427341,36.76164,20.582642,-27.803827,21.356062,-30.485636,31.100578,-8.859652,4.893862,-4.0769267,4.978638,3.994121,-14.89092,-5.141599,12.765342,-13.616753,12.7867985,11.326496,-4.1964617,-7.805995,7.145773,-2.927849,21.213646,-14.97447,-0.33558258,-17.812292,-1.1588771,0.6938477,-17.493486,-21.209164,-14. ...

# %%
# prompt:3d tsne of tfidf_matrix.toarray() and plot a 3d plotly express graph assign index for each color

import plotly.express as px
from sklearn.manifold import TSNE

tsne = TSNE(n_components=3, random_state=0)
tsne_result = tsne.fit_transform(tfidf_matrix.toarray())
tsne_df = pd.DataFrame(data=tsne_result, columns=['TSNE1', 'TSNE2', 'TSNE3'])

fig = px.scatter_3d(tsne_df, x='TSNE1', y='TSNE2', z='TSNE3', color=data_en['combined_tags'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b133f973-8d04-4ab0-863d-b9ba3c4194ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b133f973-8d04-4ab0-863d-b9ba3c4194ec")) {                    Plotly.newPlot(                        "b133f973-8d04-4ab0-863d-b9ba3c4194ec",                        [{"hovertemplate":"color=issue network outage service urgent\u003cbr\u003eTSNE1=%{x}\u003cbr\u003eTSNE2=%{y}\u003cbr\u003eTSNE3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"issue network outage service urgent","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"issue network outage service urgent","scene":"scene","showlegend":true,"x":[-4.3904715,10.197103,-11.306617],"y":[-1.8830096,2.6454477,29.772919],"z":[19.466032,26.507837,-0.7827121],"type":"scatter3d"},{"hovertemplate":"color=failure hardware product support technical\u003cbr\u003eTSNE1=%{x}\u003cbr\u003eTSNE2=%{y}\u003cbr\u003eTSNE3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"failure hardware product support technical","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"failure hardware product support technical","scene":"scene","showlegend":true,"x":[-25.219141,-11.000136,-0.07302681,-11.750374,-11.007781,-6.0550156,-4.2556167,-3.5921896,-15.857525,12.7867985,-7.805995,-2.927849,-17.493486,13.895452,-27.999865,-14.047934,11.824973,-18.699438,11.100985],"y":[-39.130905,-28.737484,-30.426569,-18.361235,-19.395176,-36.088543,-16.69934,-22.446304,-17.896214,-23.910782,-18.480555,-33.76234,-31.782038,-21.832777,-33.37902,-41.042095,-27.73232,-30.600914,-41.0571],"z":[-1.2961433,-6.3151245,-23.915388,7.1937456,2.191297,-14.184277,4.022853,26.017365,1.8785071,15.105484,-6.244289,-18.475151,-4.274852,3.400664,-7.593406,4.2634044,22.372671,-11.304366,4.1354375],"type":"scatter3d"},{"hovertemplate":"color=customer exchange product replacement return service\u003cbr\u003eTSNE1=%{x}\u003cbr\u003eTSNE2=%{y}\u003cbr\u003eTSNE3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"customer exchange product replacement return service","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"customer exchange product replacement return service","scene":"scene","showlegend":true,"x":[-6.0681443],"y":[-33.448128],"z":[5.2442436],"type":"scatter3d"},{"hovertemplate":"color=performance support technical tuning\u003cbr\u003eTSNE1=%{x}\u003cbr\u003eTSNE2=%{y}\u003cbr\u003eTSNE3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"performance support technical tuning","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"performance support technical tuning","scene":"scene","showlegend":true,"x":[14.028312,2.5663238,12.46818,-6.284143,12.765342],"y":[29.62496,18.524809,31.72035,19.911686,37.96071],"z":[-0.281651,-19.515072,-8.655514,-22.374397,3.758001],"type":"scatter3d"},{"hovertemplate":"color=issue outage service support urgent\u003cbr\u003eTSNE1=%{x}\u003cbr\u003eTSNE2=%{y}\u003cbr\u003eTSNE3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"issue outage service support urgent","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"issue outage service support urgent","scene":"scene","showlegend":true,"x":[-13.04326,-7.924855,-3.230762,-8.259549,-9.308891,-7.708024,-16.824154],"y":[25.723318,30.773987,19.754488,24.906769,22.135288,21.891273,28.378302],"z":[-1.1690922,-8.73773,11.268489,12.556421,-2.1636748,15.592861,-6.603149],"type":"scatter3d"},{"hovertemplate":"color=bug issue software support technical urgent\u003cbr\u003eTSNE1=%{x}\u003cbr\u003eTSNE2=%{y}\u003cbr\u003eTSNE3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bug issue software support technical urgent","mar ...

# %%
# use sentence embedder to embedd tickets

# !pip install sentence-transformers

from sentence_transformers import SentenceTransformer

# Load the Sentence Transformer model
model = SentenceTransformer('all-mpnet-base-v2')


# Generate embeddings
ticket_embeddings = model.encode(tickets.tolist())
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
#
#
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# pc1, 2 3 for ticket_embeddings and plot

import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA


pca = PCA(n_components=3)
pc_result = pca.fit_transform(ticket_embeddings)
pc_df = pd.DataFrame(data=pc_result, columns=['PC1', 'PC2', 'PC3'])

fig = px.scatter_3d(pc_df, x='PC1', y='PC2', z='PC3', color=data_en['combined_tags'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="10a4014d-b3f7-466b-b47b-aa5094d76e25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10a4014d-b3f7-466b-b47b-aa5094d76e25")) {                    Plotly.newPlot(                        "10a4014d-b3f7-466b-b47b-aa5094d76e25",                        [{"hovertemplate":"color=issue network outage service urgent\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"issue network outage service urgent","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"issue network outage service urgent","scene":"scene","showlegend":true,"x":[0.43781126,0.524885,-0.3425055],"y":[-0.45284098,-0.41455466,-0.26996323],"z":[-0.06478442,-0.114560455,-0.30783543],"type":"scatter3d"},{"hovertemplate":"color=failure hardware product support technical\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"failure hardware product support technical","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"failure hardware product support technical","scene":"scene","showlegend":true,"x":[0.1534602,0.10031573,-0.0011813263,0.16264337,0.113290764,0.07346443,0.08860554,0.16158563,0.1541548,0.32761708,0.061449256,0.08090224,0.0003931859,0.19141486,-0.002135419,0.036702733,0.3465012,0.010624231,0.4701827],"y":[0.26153097,0.32041082,0.37433702,0.36904186,0.3872604,0.2934426,0.353629,0.2606621,0.36201537,0.20664403,0.40510434,0.30811742,0.30970258,0.25122103,0.26088056,0.2596758,0.2825028,0.3148314,0.17308162],"z":[-0.06826509,-0.15474048,-0.24221833,-0.21376058,-0.1783589,-0.23032697,-0.11522662,-0.19463548,-0.20588833,-0.07141841,-0.10460446,-0.22780456,-0.086852506,-0.070575565,-0.1329731,-0.06482618,-0.087698385,-0.102760226,-0.18802835],"type":"scatter3d"},{"hovertemplate":"color=customer exchange product replacement return service\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"customer exchange product replacement return service","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"customer exchange product replacement return service","scene":"scene","showlegend":true,"x":[-0.039388858],"y":[0.34713846],"z":[-0.063551575],"type":"scatter3d"},{"hovertemplate":"color=performance support technical tuning\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"performance support technical tuning","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"performance support technical tuning","scene":"scene","showlegend":true,"x":[-0.21301374,-0.49968508,-0.22376113,-0.4721153,-0.19075978],"y":[-0.13745609,-0.10770519,-0.10603284,-0.16440985,-0.12853418],"z":[0.49972513,-0.057031915,0.42154706,-0.19792522,0.38131997],"type":"scatter3d"},{"hovertemplate":"color=issue outage service support urgent\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"issue outage service support urgent","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"issue outage service support urgent","scene":"scene","showlegend":true,"x":[-0.33493343,-0.29577646,-0.07855388,-0.08124324,-0.33751702,-0.06974148,-0.33206242],"y":[-0.26503047,-0.2996021,-0.2522593,-0.2610437,-0.25765646,-0.25789034,-0.28765658],"z":[-0.24663284,-0.2945553,0.22203942,0.20363562,-0.33487034,0.19492838,-0.33099315],"type":"scatter3d"},{"hovertemplate":"color=bug issue software support technical urgent\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\ ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
def get_all_nouns(el):
    doc = nlp(el)
    tokens = [(token.text, token.pos_) for token in doc]

    final_nouns = []
    curr_noun = ""
    with_occured = False
    for el in tokens:
        if el[0] == "with":
            with_occured = True
        elif el[1] not in ["NOUN", "PROPN"]:
            with_occured = False

        if el[1] in ["NOUN", "PROPN"] and with_occured:
            curr_noun += " " + el[0]
        else:
            if curr_noun != "":
                final_nouns.append(curr_noun.strip())
                curr_noun = ""

    if curr_noun != "":
        final_nouns.append(curr_noun.strip())

    return final_nouns

data_en["nouns"] = data_en["subject"].apply(get_all_nouns)
# Out:
# <ipython-input-32-13ac4fa8d544>:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_en.loc[data_en["nouns"].map(len) > 0, "nouns"].shape
# Out:
# (58,)

# %%
data_en.loc[data_en["nouns"].map(len) > 0, "nouns"]
# Out:
# 18              [AWS Resource Optimization]
# 26                         [AWS Deployment]
# 49                               [Dell XPS]
# 53             [Canon PIXMA MG3620 Printer]
# 72      [AWS Management Service Deployment]
# 74                           [Cisco Router]
# 95                             [HP DeskJet]
# 107                [AWS Management Service]
# 127                           [Surface Pro]
# 129                              [Dell XPS]
# 130                        [MacBook Air M1]
# 143                       [Adobe Photoshop]
# 146                      [Zoom application]
# 176                          [Cisco Router]
# 202                 [Microsoft Surface Pro]
# 222                     [Wireless Printing]
# 225                            [HP DeskJet]
# 253                              [Dell XPS]
# 256                  [Cisco Router ISR4331]
# 283                           [Surface Pro]
# 332                  [Cisco Router ISR4331]
# 338                       [Adobe Photoshop]
# 342                 [Microsoft Surface Pro]
# 354                [IT Consultancy Options]
# 414             [Slack Channel Integration]
# 448                           [Surface Pro]
# 461                          [Cisco Router]
# 472                        [Router ISR4331]
# 480                              [Dell XPS]
# 493                        [Wireless Setup]
# 518                        [AWS Deployment]
# 612                         [Printer Setup]
# 613                         [Jira Software]
# 622                         [Server Outage]
# 645                  [Cisco ISR4331 Router]
# 653                            [HP DeskJet]
# 708                   [PostgreSQL Database]
# 725                              [Dell XPS]
# 732                     [Network Stability]
# 775                 [MySQL 8.0.30 Database]
# 790                        [AWS Management]
# 791                                   [AWS]
# 845                  [Cisco Router ISR4331]
# 847                       [Adobe Photoshop]
# 874                   [AWS Billing Charges]
# 892                                [Office]
# 894                         [Ticket System]
# 931                 [Canon PIXMA MG3620 Wi]
# 961                         [IntelliJ IDEA]
# 980                        [AWS Deployment]
# 1101                             [Dell XPS]
# 1173                       [AWS Deployment]
# 1232                          [AWS Service]
# 1289                  [Network Reliability]
# 1340               [AWS Management Service]
# 1346                [Printer Configuration]
# 1512                       [AWS Deployment]
# 1528                    [Server Management]
# Name: nouns, dtype: object

# %% [markdown]
# Group tickets where the same nouns occured

# %%
# from tickets group body of   same nouns occured in multiple groups

import pandas as pd


def group_tickets_by_nouns(df):
    """Groups tickets based on common nouns in the 'subject' field."""

    grouped_tickets = {}
    for index, row in df.iterrows():
        if isinstance(row['nouns'], list) and row['nouns']:  # Check for valid 'nouns' lists
            for noun in row['nouns']:
                if noun not in grouped_tickets:
                    grouped_tickets[noun] = []
                grouped_tickets[noun].append(index)

    return grouped_tickets


def print_grouped_tickets(grouped_tickets):
    """Prints groups of ticket indices based on common nouns."""
    for noun, ticket_indices in grouped_tickets.items():
        print(f"Noun: {noun}")
        print(f"Ticket indices: {ticket_indices}")
        print("-" * 20)


# Apply the function
grouped = group_tickets_by_nouns(data_en)

# Print the results
print_grouped_tickets(grouped)
# Out:
# Noun: AWS Resource Optimization
# Ticket indices: [18]
# --------------------
# Noun: AWS Deployment
# Ticket indices: [26, 518, 980, 1173, 1512]
# --------------------
# Noun: Dell XPS
# Ticket indices: [49, 129, 253, 480, 725, 1101]
# --------------------
# Noun: Canon PIXMA MG3620 Printer
# Ticket indices: [53]
# --------------------
# Noun: AWS Management Service Deployment
# Ticket indices: [72]
# --------------------
# Noun: Cisco Router
# Ticket indices: [74, 176, 461]
# --------------------
# Noun: HP DeskJet
# Ticket indices: [95, 225, 653]
# --------------------
# Noun: AWS Management Service
# Ticket indices: [107, 1340]
# --------------------
# Noun: Surface Pro
# Ticket indices: [127, 283, 448]
# --------------------
# Noun: MacBook Air M1
# Ticket indices: [130]
# --------------------
# Noun: Adobe Photoshop
# Ticket indices: [143, 338, 847]
# --------------------
# Noun: Zoom application
# Ticket indices: [146]
# --------------------
# Noun: Microsoft Surface Pro
# Ticket indices: [202, 342]
# --------------------
# Noun: Wireless Printing
# Ticket indices: [222]
# --------------------
# Noun: Cisco Router ISR4331
# Ticket indices: [256, 332, 845]
# --------------------
# Noun: IT Consultancy Options
# Ticket indices: [354]
# --------------------
# Noun: Slack Channel Integration
# Ticket indices: [414]
# --------------------
# Noun: Router ISR4331
# Ticket indices: [472]
# --------------------
# Noun: Wireless Setup
# Ticket indices: [493]
# --------------------
# Noun: Printer Setup
# Ticket indices: [612]
# --------------------
# Noun: Jira Software
# Ticket indices: [613]
# --------------------
# Noun: Server Outage
# Ticket indices: [622]
# --------------------
# Noun: Cisco ISR4331 Router
# Ticket indices: [645]
# --------------------
# Noun: PostgreSQL Database
# Ticket indices: [708]
# --------------------
# Noun: Network Stability
# Ticket indices: [732]
# --------------------
# Noun: MySQL 8.0.30 Database
# Ticket indices: [775]
# --------------------
# Noun: AWS Management
# Ticket indices: [790]
# --------------------
# Noun: AWS
# Ticket indices: [791]
# --------------------
# Noun: AWS Billing Charges
# Ticket indices: [874]
# --------------------
# Noun: Office
# Ticket indices: [892]
# --------------------
# Noun: Ticket System
# Ticket indices: [894]
# --------------------
# Noun: Canon PIXMA MG3620 Wi
# Ticket indices: [931]
# --------------------
# Noun: IntelliJ IDEA
# Ticket indices: [961]
# --------------------
# Noun: AWS Service
# Ticket indices: [1232]
# --------------------
# Noun: Network Reliability
# Ticket indices: [1289]
# --------------------
# Noun: Printer Configuration
# Ticket indices: [1346]
# --------------------
# Noun: Server Management
# Ticket indices: [1528]
# --------------------

# %%
import pandas as pd
import spacy


def group_tickets_by_nouns(df):
    """Groups tickets based on common nouns in the 'subject' and 'body' fields."""

    grouped_tickets = {}
    for index, row in df.iterrows():
        if isinstance(row['nouns'], list) and row['nouns']:
            for noun in row['nouns']:
                if noun not in grouped_tickets:
                    grouped_tickets[noun] = []
                grouped_tickets[noun].append((index, row['subject'], row['body']))

    return grouped_tickets


def print_grouped_tickets(grouped_tickets):
    """Prints groups of ticket indices based on common nouns, including subject and body."""
    for noun, ticket_data in grouped_tickets.items():
        print(f"Noun: {noun}")
        for index, subject, body in ticket_data:
            print(f"  Ticket Index: {index}")
            print(f"  Subject: {subject}")
            print(f"  Body: {body}")
            print("-" * 20)


# Apply the function
grouped = group_tickets_by_nouns(data_en)

# Print the results
print_grouped_tickets(grouped)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-fd3ae0d35b92> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import spacy
#       3
#       4
#       5 def group_tickets_by_nouns(df):
#
# /usr/local/lib/python3.10/dist-packages/spacy/__init__.py in <module>
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
#      12
# ---> 13 from . import pipeline  # noqa: F401
#      14 from . import util
#      15 from .about import __version__  # noqa: F401
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/__init__.py in <module>
#       1 from .attributeruler import AttributeRuler
# ----> 2 from .dep_parser import DependencyParser
#       3 from .edit_tree_lemmatizer import EditTreeLemmatizer
#       4 from .entity_linker import EntityLinker
#       5 from .entityruler import EntityRuler
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/dep_parser.pyx in init spacy.pipeline.dep_parser()
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/transition_parser.pyx in init spacy.pipeline.transition_parser()
#
# /usr/local/lib/python3.10/dist-packages/spacy/ml/__init__.py in <module>
# ----> 1 from .callbacks import create_models_with_nvtx_range  # noqa: F401
#       2 from .models import *  # noqa: F401, F403
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
def group_tickets_by_nouns(df):
    """Groups tickets based on common nouns in the 'subject' field,
       displaying only unique subjects for each noun."""

    grouped_tickets = {}
    for index, row in df.iterrows():
        if isinstance(row['nouns'], list) and row['nouns']:
            for noun in row['nouns']:
                if noun not in grouped_tickets:
                    grouped_tickets[noun] = set()
                grouped_tickets[noun].add(row['subject'])

    return grouped_tickets


def print_grouped_tickets(grouped_tickets):
    """Prints groups of unique subjects based on common nouns."""
    for noun, subjects in grouped_tickets.items():
        print(f"Noun: {noun}")
        for subject in subjects:
            print(f"  Subject: {subject}")
        print("-" * 20)


# Apply the function
grouped = group_tickets_by_nouns(data_en)

# Print the results
print_grouped_tickets(grouped)
# Out:
# Noun: AWS Resource Optimization
#   Subject: Issues with AWS Resource Optimization
# --------------------
# Noun: AWS Deployment
#   Subject: Urgent Assistance Required: Issue with AWS Deployment
#   Subject: Urgent Care Needed: Issue with AWS Deployment
#   Subject: Critical: Problem with AWS Deployment
#   Subject: Urgent Issue with AWS Deployment
#   Subject: Urgent Assistance Needed: Issue with AWS Deployment
# --------------------
# Noun: Dell XPS
#   Subject: Screen Flickering Issue with Dell XPS 13
#   Subject: Request for urgent assistance with Dell XPS 13 issues
#   Subject: Issue with Dell XPS 13 Powering On
#   Subject: Issue with Dell XPS 13 overheating
#   Subject: Issue with Dell XPS 13 9310 Performance
#   Subject: Performance Issue with Dell XPS 13 9310 Demo
# --------------------
# Noun: Canon PIXMA MG3620 Printer
#   Subject: Wi-Fi Connectivity Issues with Canon PIXMA MG3620 Printer
# --------------------
# Noun: AWS Management Service Deployment
#   Subject: Issues with AWS Management Service Deployment
# --------------------
# Noun: Cisco Router
#   Subject: Network Issues with Cisco Router
#   Subject: Intermittent Connectivity Issues with Cisco Router
#   Subject: Connectivity Issues with Cisco Router
# --------------------
# Noun: HP DeskJet
#   Subject: Assistance Required: Wireless Connectivity Issue with HP DeskJet 3755
#   Subject: Request for Setup Assistance with HP DeskJet 3755
#   Subject: Issue with HP DeskJet 3755 Connection
# --------------------
# Noun: AWS Management Service
#   Subject: Billing Issue with AWS Management Service
#   Subject: Urgent: Issues with AWS Management Service
# --------------------
# Noun: Surface Pro
#   Subject: Issue with Surface Pro 7 - Screen Flickering
#   Subject: Touchscreen and Keyboard Issues with Surface Pro 7
#   Subject: Battery Issue with Surface Pro
# --------------------
# Noun: MacBook Air M1
#   Subject: Urgent Support Required: Battery Issues with MacBook Air M1
# --------------------
# Noun: Adobe Photoshop
#   Subject: Assistance with Adobe Photoshop
#   Subject: Assistance Required: Issue with Adobe Photoshop 2024 Installation
#   Subject: Billing Issues with Adobe Photoshop
# --------------------
# Noun: Zoom application
#   Subject: Frequent audio issues with Zoom application
# --------------------
# Noun: Microsoft Surface Pro
#   Subject: Login Issues with Microsoft Surface Pro 7
#   Subject: Issue with Microsoft Surface Pro 7
# --------------------
# Noun: Wireless Printing
#   Subject: Request for Assistance with Wireless Printing
# --------------------
# Noun: Cisco Router ISR4331
#   Subject: Urgent: Connectivity Issues with Cisco Router ISR4331
#   Subject: Issues with Cisco Router ISR4331
#   Subject: Frequent Disconnect Issues with Cisco Router ISR4331
# --------------------
# Noun: IT Consultancy Options
#   Subject: Assistance with IT Consultancy Options
# --------------------
# Noun: Slack Channel Integration
#   Subject: Error with Slack Channel Integration
# --------------------
# Noun: Router ISR4331
#   Subject: Urgent: Critical Network Issue with Router ISR4331
# --------------------
# Noun: Wireless Setup
#   Subject: Assistance Needed with Wireless Setup for Canon PIXMA MG3620
# --------------------
# Noun: Printer Setup
#   Subject: Assistance with Printer Setup
# --------------------
# Noun: Jira Software
#   Subject: Access Issue with Jira Software
# --------------------
# Noun: Server Outage
#   Subject: Immediate Assistance Needed with Server Outage
# --------------------
# Noun: Cisco ISR4331 Router
#   Subject: Issues with Cisco ISR4331 Router
# --------------------
# Noun: PostgreSQL Database
#   Subject: Immediate Attention Required: Connectivity Problem with PostgreSQL Database
# --------------------
# Noun: Network Stability
#   Subject: Problems with Network Stability
# --------------------
# Noun: MySQL 8.0.30 Database
#   Subject: Performance Issues with MySQL 8.0.30 Database
# --------------------
# Noun: AWS Management
#   Subject: Assistance with AWS Management
# --------------------
# Noun: AWS
#   Subject: Intermittent Connectivity Issues with AWS
# --------------------
# Noun: AWS Billing Charges
#   Subject: Issue with AWS Billing Charges
# --------------------
# Noun: Office
#   Subject: Request for Assistance with Office 365 Installation Error
# --------------------
# Noun: Ticket System
#   Subject: Issue with Ticket System
# --------------------
# Noun: Canon PIXMA MG3620 Wi
#   Subject: Issue with Canon PIXMA MG3620 Wi-Fi Connection
# --------------------
# Noun: IntelliJ IDEA
#   Subject: Issues with IntelliJ IDEA 2024.1 Refactoring Features
# --------------------
# Noun: AWS Service
#   Subject: Billing Discrepancy with AWS Service
# --------------------
# Noun: Network Reliability
#   Subject: Problems with Network Reliability
# --------------------
# Noun: Printer Configuration
#   Subject: Help with Printer Configuration
# --------------------
# Noun: Server Management
#   Subject: Immediate Assistance Needed: Issues with Server Management
# --------------------

# %% [markdown]
# Tried to find similar type of issues

# %%
# from tickets amalyse context of the body and find similar bodies have similar meaning

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import plotly.express as px
from sklearn.manifold import TSNE
from sentence_transformers import SentenceTransformer
import spacy

# ... (rest of your existing code)

def group_tickets_by_similar_bodies(df, threshold=0.8):
    """Groups tickets with similar bodies using SentenceTransformer embeddings and cosine similarity."""

    model = SentenceTransformer('all-mpnet-base-v2')
    body_embeddings = model.encode(df['body'].tolist())

    from sklearn.metrics.pairwise import cosine_similarity
    similarity_matrix = cosine_similarity(body_embeddings)

    grouped_tickets = {}
    for i in range(len(df)):
        for j in range(i + 1, len(df)):
            if similarity_matrix[i, j] >= threshold:
                if i not in grouped_tickets:
                    grouped_tickets[i] = []
                grouped_tickets[i].append(j)

    return grouped_tickets

def print_grouped_tickets_with_bodies(grouped_tickets, df):
    for key_index, similar_indices in grouped_tickets.items():
        print(f"Group with key ticket index: {key_index}\nSubject: {df['subject'].iloc[key_index]}\nBody: {df['body'].iloc[key_index]}\n")
        for index in similar_indices:
          print(f"Similar ticket index: {index}\nSubject: {df['subject'].iloc[index]}\nBody: {df['body'].iloc[index]}\n")
        print("-" * 20)

# Example Usage
grouped_tickets_by_body = group_tickets_by_similar_bodies(data_en)
print_grouped_tickets_with_bodies(grouped_tickets_by_body, data_en)
# Out:
# Streaming output truncated to the last 5000 lines.
# Subject: Urgent AWS Deployment Issues
# Body: Dear IT Services Customer Support,
#
#
# I hope this message finds you well. I am reaching out to request urgent technical assistance with our AWS Management Service. We experienced significant server downtime over the weekend, which is impacting our operations. This issue has caused major disruptions for our team, and we need immediate help to resolve it. Please let us know if there are any specific logs or details you require from our end to expedite the troubleshooting process. Could we schedule a call at the earliest convenience to work through this issue? Your prompt response would be greatly appreciated.
#
#
# Thank you,
# <name>
#
# Similar ticket index: 277
# Subject: Urgent Issue with AWS Deployment
# Body: Dear IT Services Support Team, I am writing to inform you of a critical issue we are experiencing with our AWS infrastructure deployment, which is significantly affecting our cloud service operational efficiency and cost optimization efforts. The problem seems related to the AWS Management Service, causing disruptions in our regular business operations. We urgently require your assistance to rectify this issue. Please escalate this as a high-priority incident and advise on the next possible steps. Attached are relevant logs and performance data for your reference. Looking forward to your swift response. Thank you, <name>.
#
# Similar ticket index: 298
# Subject: Urgent Assistance Required for AWS Issues
# Body: Dear IT Services Support Team,
#
#
# I am writing to express that I am encountering significant challenges with cloud deployment, specifically using the AWS Management Service. The service has been experiencing frequent downtimes, creating a severe impact on our operational efficiency and overall business processes. This repeated disruption requires immediate technical intervention to mitigate any further impact.
#
#
# We have ensured that our configurations align with recommended practices, but these issues persist regardless. Swift resolution of this problem is paramount. Could you please coordinate with your technical experts to investigate and provide a solution as soon as possible?
#
#
# Thank you for your prompt attention to this urgent matter. Please let me know if any further information is needed at this time.
#
#
# Best regards,
#
#
# <name>
#
# Similar ticket index: 300
# Subject: Urgent: Major AWS Outage
# Body: Dear IT Services Customer Support Team, I am writing to bring attention to a major AWS outage that is significantly disrupting our cloud infrastructure. Our daily operations depend greatly on the AWS Management Service, and this unforeseen interruption is compromising our efficiency in serving our clients. We kindly request immediate action to rectify this situation and mitigate further complications. The urgency of this matter cannot be overstated, and your swift resolution would be immensely appreciated. Please provide us with updates on the steps being taken to tackle this outage at your earliest opportunity. We value your assistance and look forward to your prompt response. If you need any additional information or coordination, do not hesitate to reach me at <tel_num> or reply to this email. Thank you for your immediate attention to this pressing issue. Best regards, <name> <Position> <Company Name> <tel_num>
#
# Similar ticket index: 302
# Subject: Notification of Planned Maintenance
# Body: Hello Customer Support Team, I hope you are doing well. I'm contacting you to seek information regarding the recent announcement about the planned maintenance for the AWS Management Service, which I trust will maintain its high level of service for all users. We've been informed that there may be some temporary disruptions in cloud services due to this maintenance work. As a valued customer, it's crucial for us to grasp the extent of this downtime, enabling us to prepare and coordinate effectively with our staff. Could you share specific details regarding the maintenance schedule and the expected length of time it will take? Moreover, although you conveyed that the impacts are likely to be minimal, can you provide assurances concerning the integrity and security of our data during this period? Gaining this insight is vital for minimizing any unforeseen interruptions, particularly for our time-sensitive projects. I appreciate the effort to keep the infrastructure updated and fully acknowledge the reasons for this planned maintenance. Having timely and detailed information will empower us to keep our users well informed and manage their expectations sensibly. Thank you for your help. Sincerely, <name> IT Manager <acc_num>.
#
# Similar ticket index: 313
# Subject: Urgent: Critical AWS Service Outage Experienced
# Body: Dear Customer Support Team,
#
#
# I am writing to inform you of a critical service outage that we experienced during our recent infrastructure deployment while using your AWS Management Service. Our company, <name> Solutions, relies heavily on the stability and reliability of this service to maintain seamless operations and support for our clients' applications. However, this outage severely impacted our environment stability and hindered our ability to provide optimal service to our clients.
#
#
# We first noticed the issue on the evening of October 15th, 2023, where multiple attempts to deploy critical components across different regions were unresponsive and eventually failed, affecting multiple client environments. As this circumstance led to unanticipated downtime and disruptions for several hours, it has raised significant concerns about both the functionality and fault tolerance of the AWS Management Service under our usage pattern.
#
#
# We request immediate assistance and clarification on this matter. Could your technical team investigate the cause of this failure and provide insights on any mitigation plans and future preventive measures? We are eager to collaborate to prevent further disruptions as our reputation depends greatly on maintaining operational consistency.
#
#
# Furthermore, could you ensure that relevant contacts within your team provide us with a timeline for an anticipated resolution and confirm any additional steps we need to undertake during this period? If needed, feel free to reach out to me directly at <tel_num>.
#
#
# Thank you for swiftly addressing this urgent matter. Looking forward to your rapid response and proposed solutions.
#
#
# Best regards,
# <name>
# Account Number: <acc_num>
#
# Similar ticket index: 322
# Subject: Urgent Help Needed: AWS Deployment Issue
# Body: Dear IT Services Support Team,
#
#
# I am writing to inform you of a critical issue we are facing with the AWS Management Service. We have encountered an unexpected deployment issue that has resulted in significant downtime for our customer-facing applications. The situation requires immediate attention to restore our services and ensure customers can access our platform without any further disruption.
#
#
# We are particularly concerned about the potential impact on our customer satisfaction and service-level agreements if this problem is not addressed promptly. Please provide guidance on the necessary steps to resolve this issue quickly or direct our request to a specialist team that can assist us further.
#
#
# For reference, the affected account number is <acc_num>, and our last contact with support was under case ID <case_id>. We appreciate your urgent response to this matter and look forward to a swift resolution.
#
#
# Thank you for your prompt attention to this critical issue.
#
#
# Warm regards,
# <name>
#
#
# Phone: <tel_num>
#
# Similar ticket index: 323
# Subject: Urgent Support Required for AWS Issue Resolution
# Body: Dear IT Services Customer Support Team, I hope this message finds you well. I am writing to urgently request assistance with a critical issue we are experiencing with the AWS Management Service. Currently, our team is encountering significant challenges in deploying AWS resources, and this has resulted in extensive downtime, severely impacting our operations. The inability to seamlessly deploy resources has not only hindered our daily functioning but also resulted in substantial cost implications. As you can imagine, downtime in our systems leads to delayed project delivery and affects our service level commitments to our clients. We have attempted several workarounds but have yet to identify a successful solution. This matter has become pressing and requires an immediate resolution. Given the extensive impact on both financial and operational fronts, we would appreciate it if your team could provide us with prompt and efficient support. Please let me know the specific details you require from us to expedite the resolution process. Our account number is <acc_num>, and if necessary, I can be reached directly at <tel_num> for further information or coordination. I look forward to your immediate response. Thank you in advance for your attention and support. Kind regards, <name>
#
# --------------------
# Group with key ticket index: 215
# Subject: Urgent: Immediate IT Assistance Needed
# Body: Dear IT Consulting Support,
#
#
# I am writing to urgently request your immediate IT consulting services for an issue with the network that one of my clients is experiencing. Their network has gone down, and this is causing significant disruptions to their operations. As you can understand, it is crucial for them to have this issue resolved as soon as possible.
#
#
# The client requires immediate assistance with reconfiguring their servers to ensure continuity of their IT services. Since the situation is critical, I trust you will be able to provide the necessary skilled support promptly. Kindly prioritize this request and let us know the soonest available time for a consultant to start working on this issue at their site or through remote access, depending on what is feasible.
#
#
# Please contact me at <tel_num> to discuss further how we can expedite this process and mitigate the ongoing impact on their business operations. Your swift response will be highly appreciated.
#
#
# Thank you,
#
#
# <name>
#
# Similar ticket index: 255
# Subject: High Priority Request: Server Administration Issues
# Body: Dear Customer Support,
#
#
# I am writing to request urgent technical support regarding IT consulting services related to server administration issues affecting our operations severely. We're experiencing unexpected downtime and issues with server configuration and performance. Immediate assistance is required to diagnose and rectify the issues to prevent further disruptions.
#
#
# Please contact me at your earliest convenience at <tel_num> or respond to this email with potential solutions or arrangements for a remote troubleshooting session.
#
#
# Our account number is <acc_num>. Thank you in advance for your prompt attention to this matter.
#
#
# Best regards,
# <name>
#
# Similar ticket index: 276
# Subject: Immediate Assistance Needed to Resolve Server Outage
# Body: Dear IT Support Team,
#
#
# I am urgently contacting you to seek immediate help with a significant problem. We are facing server outage that is greatly affecting our business operations. The service that is impacted is your IT Consulting Service, which is leading to substantial disruptions. We depend on this service for our everyday processes and require a solution as soon as possible. Please make this issue a priority and provide the necessary assistance to restore normal functionality.
#
#
# Thank you for acknowledging this matter promptly.
#
#
# Sincerely,
# <name>
#
# Similar ticket index: 338
# Subject: Immediate Assistance Requested
# Body: Dear Customer Support Team,
#
#
# I am contacting you to seek prompt professional help regarding our IT Consulting Service. We are facing an urgent requirement for server setup and network enhancement. Our systems are presently experiencing difficulties that may negatively affect our business activities. It is imperative that we address these issues swiftly to avoid any interruptions.
#
#
# Could you kindly prioritize our request and allocate an expert to help us with these concerns? We need someone with specialized expertise in server setups and optimization methods. Please inform us at your earliest convenience about the availability of your support personnel.
#
#
# We are ready for a consultation call whenever it suits you to provide any additional information needed. You can reach me at <tel_num>.
#
#
# Thank you for your prompt attention to this issue. We anticipate your swift reply.
#
#
# Best regards,
#
#
# <name>
#
# --------------------
# Group with key ticket index: 216
# Subject: Intermittent Connectivity Issues Report
# Body: Dear Customer Support,
#
#
# I am writing to report intermittent connectivity issues experienced with the Cisco Router ISR4331. Our investigation showed potential network performance concerns and outdated firmware. Please advise on resolving these issues.
#
#
# Thank you,
# <name>
#
# Similar ticket index: 218
# Subject: Issues with Cisco ISR4331 Router
# Body: Dear Support Team,
#
#
# I am writing to report that we have been experiencing frequent disconnections and slow performance with our Cisco Router ISR4331 during business hours. This issue has significantly disrupted our operations. Could you please provide guidance or a solution to address what seems to be an ongoing problem? If there are firmware updates or configuration changes required, we would be keen to implement those. Thank you for your prompt attention to this matter.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 220
# Subject: Urgent: Cisco ISR4331 Issues
# Body: Dear Customer Support,
#
#
# I am writing to bring to your attention a significant issue we are facing with one of your products, the Cisco Router ISR4331. We have been utilizing this device due to its robust performance capabilities and reliability, essential for maintaining the seamless operations of our network infrastructure. However, we have recently encountered sudden performance issues that have caused serious disruptions across multiple user connections. This has raised considerable concern within our organization, considering the reliance we place on this router for network efficiency.
#
#
# The unexpected degradation in performance manifests in slow data transmission across our network, resulting in considerable downtime and decreased productivity. We suspect that this may be attributed to either firmware glitches or potential hardware malfunction, although we couldn’t determine the exact cause based solely on our internal assessment. We have exhausted initial troubleshooting protocols, including basic resets and configuration reevaluations, with no improvement.
#
#
# Given the critical nature of this router to our networking operations, we urgently seek your expertise to diagnose and resolve the anomaly. Please let us know if there are specific diagnostic measures or updates you recommend. Additionally, if you could advise on any potential steps we might undertake to mitigate these disruptions while a solution is being identified, it would be greatly appreciated.
#
#
# Thank you in advance for your prompt response and assistance in addressing this issue. I look forward to your guidance.
#
#
# Sincerely,
#
#
# <name>
#
# Similar ticket index: 231
# Subject: Network Connectivity Issues
# Body: Dear Customer Support,
#
#
# I am writing to report a network connectivity issue we are experiencing with our Cisco Router ISR4331, impacting our secure enterprise networking and high-performance connections. The router, which is essential for our daily operations, has been intermittently dropping connections and affecting our overall productivity. We have rebooted the router and checked all physical connections, yet the problem persists. As this device is critical to ensure high-speed data transfer across our network, a prompt resolution is necessary.
#
#
# Could you please provide guidance or arrange for a technical specialist to assist us in diagnosing and resolving the issue? Any immediate advice to mitigate disruptions would be greatly appreciated.
#
#
# Thank you for your attention to this matter. I can be reached at <tel_num> or via email at <email> should you require further details.
#
#
# Best Regards,
#
#
# <name>
# <acc_num>
#
# Similar ticket index: 245
# Subject: Critical: Recurring Network Disconnection Problem
# Body: Dear Support Team,
#
#
# We are facing recurring network disconnections with our Cisco Router ISR4331, which is significantly impacting our office connectivity. We urgently require immediate troubleshooting and resolution. Please help us in addressing this issue.
#
#
# Thank you,
# <name>
#
# Similar ticket index: 256
# Subject: Issues with Cisco Router ISR4331
# Body: Hello, I am experiencing frequent disconnections on my Cisco Router ISR4331, severely affecting network performance and client productivity. Please assist in resolving this issue promptly. Thank you!
#
# Similar ticket index: 273
# Subject: Company Network Issue
# Body: Dear Customer Support,
#
#
# I am writing to report an issue with our Cisco Router ISR4331 at our headquarters. We are experiencing intermittent connection drops which are frequently disrupting our company's network activities. This issue has become increasingly problematic, affecting our daily operations and causing significant inconvenience. Our IT department has verified the problem is not sourced from our end. We would appreciate it if your team could provide us with a solution or suggest the next steps for troubleshooting. Your prompt attention to this matter would be highly appreciated.
#
#
# Thank you,
# <name>
# IT Department
# <name> Ltd.
#
# Similar ticket index: 286
# Subject: Requesting Support: Router causing network issues
# Body: Dear Customer Support Team,
#
#
# I am reaching out to report a critical issue with our Cisco Router ISR4331. We have been experiencing repeated network disruptions at our enterprise due to frequent router resets and slow response times. These issues are severely impacting our organization's communication and operational efficiency, and we are unable to maintain stable network connections.
#
#
# We would greatly appreciate your prompt assistance in diagnosing and resolving this matter. Please let us know the next steps we should take to mitigate these disruptions.
#
#
# Thank you for your support.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 301
# Subject: Urgent Assistance Needed: Cisco ISR4331 Downtime
# Body: Dear Customer Support Team,
#
#
# I hope this message finds you well. I am reaching out to report an urgent issue with the Cisco Router ISR4331, which recently experienced sudden downtime, thereby significantly impacting our network performance at the office. This unexpected outage has disrupted our day-to-day operations, and we require immediate technical assistance to mitigate these issues.
#
#
# The router is critical to our network infrastructure and any prolonged downtime could hinder our core business processes. We have attempted initial diagnostics but were unable to resolve the issue on our own. Below, I have included some pertinent details for your reference:
#
#
# - Product Model: Cisco Router ISR4331
# - Date/Time of Issue: [Please Insert Date/Time]
#
#
# We kindly ask that a technical specialist be assigned to this matter at the earliest possible to assist us in troubleshooting and resolving the problem. Please let us know if further details are required from our end or if we should follow any preliminary steps before your team engages.
#
#
# Thank you very much for your prompt attention to this matter. We look forward to hearing from you soon.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 315
# Subject: Immediate Help Required
# Body: Dear Customer Service,
#
#
# I am encountering regular crashes with my Cisco Router ISR4331, which is greatly affecting my network performance. These interruptions are disrupting my daily tasks, and I urgently need your support to rectify this situation. Would you be able to provide any instructions or necessary actions to resolve this problem promptly? I am eager for your quick reply and assistance.
#
#
# Thank you,
#
#
# <name>
#
# Similar ticket index: 316
# Subject: Seeking Assistance: Router Leading to Network Disruptions
# Body: Dear Customer Support Team,
#
#
# I am contacting you to report a significant problem with our Cisco Router ISR4331. We have been encountering frequent network interruptions in our organization due to regular router resets and sluggish response times. These complications are profoundly affecting our enterprise's communication and operational productivity, hindering our ability to sustain stable network connections.
#
#
# We would sincerely appreciate your swift help in diagnosing and fixing this issue. Kindly inform us about the subsequent steps we should follow to alleviate these disturbances.
#
#
# Thank you for your assistance.
#
#
# Warm regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 318
# Subject: Immediate Support Required: Cisco ISR4331 Router Outage
# Body: Dear Customer Support,
#
#
# I trust this message finds you in good health. I am contacting you to inform you of a pressing issue with our Cisco Router ISR4331, which has recently gone offline unexpectedly, greatly affecting our network stability in the office. This unforeseen outage has interrupted our daily business activities, and we urgently seek technical support to address these challenges.
#
#
# The router plays a vital role in our network setup, and any extended outage could obstruct our essential business functions. We have conducted some preliminary diagnostics but were unsuccessful in resolving the problem independently. Here are relevant details for your reference:
#
#
# - Model: Cisco Router ISR4331
# - Time and Date of Issue: [Please Enter Date/Time]
#
#
# We humbly request that a technical expert be assigned to this case at your earliest convenience to aid us in the troubleshooting and resolution process. Please advise if any additional information is required on our part or if there are specific initial steps we should take prior to your team’s intervention.
#
#
# We greatly appreciate your immediate attention to this issue. We look forward to your swift response.
#
#
# Yours sincerely,
#   <name>
#   <tel_num>
#   <acc_num>
#
# Similar ticket index: 327
# Subject: High Priority: Recurrent Network Disconnections Problem
# Body: Hello Customer Care Team,
#
#
# We are facing recurrent disconnections with our Cisco Router ISR4331, which is significantly disrupting our office connectivity. We need immediate assistance and troubleshooting without delay. Please help us in addressing this issue.
#
#
# Best regards,
# <name>
#
# Similar ticket index: 336
# Subject: High Priority: Recurring Network Disruptions
# Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>
#
# --------------------
# Group with key ticket index: 218
# Subject: Issues with Cisco ISR4331 Router
# Body: Dear Support Team,
#
#
# I am writing to report that we have been experiencing frequent disconnections and slow performance with our Cisco Router ISR4331 during business hours. This issue has significantly disrupted our operations. Could you please provide guidance or a solution to address what seems to be an ongoing problem? If there are firmware updates or configuration changes required, we would be keen to implement those. Thank you for your prompt attention to this matter.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 220
# Subject: Urgent: Cisco ISR4331 Issues
# Body: Dear Customer Support,
#
#
# I am writing to bring to your attention a significant issue we are facing with one of your products, the Cisco Router ISR4331. We have been utilizing this device due to its robust performance capabilities and reliability, essential for maintaining the seamless operations of our network infrastructure. However, we have recently encountered sudden performance issues that have caused serious disruptions across multiple user connections. This has raised considerable concern within our organization, considering the reliance we place on this router for network efficiency.
#
#
# The unexpected degradation in performance manifests in slow data transmission across our network, resulting in considerable downtime and decreased productivity. We suspect that this may be attributed to either firmware glitches or potential hardware malfunction, although we couldn’t determine the exact cause based solely on our internal assessment. We have exhausted initial troubleshooting protocols, including basic resets and configuration reevaluations, with no improvement.
#
#
# Given the critical nature of this router to our networking operations, we urgently seek your expertise to diagnose and resolve the anomaly. Please let us know if there are specific diagnostic measures or updates you recommend. Additionally, if you could advise on any potential steps we might undertake to mitigate these disruptions while a solution is being identified, it would be greatly appreciated.
#
#
# Thank you in advance for your prompt response and assistance in addressing this issue. I look forward to your guidance.
#
#
# Sincerely,
#
#
# <name>
#
# Similar ticket index: 231
# Subject: Network Connectivity Issues
# Body: Dear Customer Support,
#
#
# I am writing to report a network connectivity issue we are experiencing with our Cisco Router ISR4331, impacting our secure enterprise networking and high-performance connections. The router, which is essential for our daily operations, has been intermittently dropping connections and affecting our overall productivity. We have rebooted the router and checked all physical connections, yet the problem persists. As this device is critical to ensure high-speed data transfer across our network, a prompt resolution is necessary.
#
#
# Could you please provide guidance or arrange for a technical specialist to assist us in diagnosing and resolving the issue? Any immediate advice to mitigate disruptions would be greatly appreciated.
#
#
# Thank you for your attention to this matter. I can be reached at <tel_num> or via email at <email> should you require further details.
#
#
# Best Regards,
#
#
# <name>
# <acc_num>
#
# Similar ticket index: 245
# Subject: Critical: Recurring Network Disconnection Problem
# Body: Dear Support Team,
#
#
# We are facing recurring network disconnections with our Cisco Router ISR4331, which is significantly impacting our office connectivity. We urgently require immediate troubleshooting and resolution. Please help us in addressing this issue.
#
#
# Thank you,
# <name>
#
# Similar ticket index: 256
# Subject: Issues with Cisco Router ISR4331
# Body: Hello, I am experiencing frequent disconnections on my Cisco Router ISR4331, severely affecting network performance and client productivity. Please assist in resolving this issue promptly. Thank you!
#
# Similar ticket index: 273
# Subject: Company Network Issue
# Body: Dear Customer Support,
#
#
# I am writing to report an issue with our Cisco Router ISR4331 at our headquarters. We are experiencing intermittent connection drops which are frequently disrupting our company's network activities. This issue has become increasingly problematic, affecting our daily operations and causing significant inconvenience. Our IT department has verified the problem is not sourced from our end. We would appreciate it if your team could provide us with a solution or suggest the next steps for troubleshooting. Your prompt attention to this matter would be highly appreciated.
#
#
# Thank you,
# <name>
# IT Department
# <name> Ltd.
#
# Similar ticket index: 279
# Subject: Critical Issue: Network Interruption
# Body: Dear IT Services Customer Support,<br><br>I trust this message reaches you in good spirits. I am writing to draw your attention to a serious matter that is disrupting our office activities. We are encountering a network interruption linked to our Cisco Router ISR4331, which is severely compromising connectivity throughout our company. This router problem began yesterday evening and continues, resulting in considerable disturbances to our operational capability.<br><br>Given the critical importance of consistent network connectivity for our business functions, the outages we are facing have obstructed communication and access to essential online resources vital for our daily transactions and operations. We regard this as a high-priority situation that necessitates urgent resolution to avert any further interruptions to our operations.<br><br>Previous attempts to restart the system and diagnose the router have proven unsuccessful. We suspect that this issue could be associated with the firmware of the Cisco Router ISR4331, and require professional insight to validate and address it. We kindly request guidance or to schedule a support session at your earliest convenience. Your expertise and swift intervention in this situation would be profoundly appreciated to restore our network operations and standard office functionality.<br><br>I eagerly anticipate your immediate response.<br><br>Thank you for your prompt attention to this pressing issue.<br><br>Best regards,<br><name><br><acc_num><br>Phone: <tel_num>
#
# Similar ticket index: 286
# Subject: Requesting Support: Router causing network issues
# Body: Dear Customer Support Team,
#
#
# I am reaching out to report a critical issue with our Cisco Router ISR4331. We have been experiencing repeated network disruptions at our enterprise due to frequent router resets and slow response times. These issues are severely impacting our organization's communication and operational efficiency, and we are unable to maintain stable network connections.
#
#
# We would greatly appreciate your prompt assistance in diagnosing and resolving this matter. Please let us know the next steps we should take to mitigate these disruptions.
#
#
# Thank you for your support.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 301
# Subject: Urgent Assistance Needed: Cisco ISR4331 Downtime
# Body: Dear Customer Support Team,
#
#
# I hope this message finds you well. I am reaching out to report an urgent issue with the Cisco Router ISR4331, which recently experienced sudden downtime, thereby significantly impacting our network performance at the office. This unexpected outage has disrupted our day-to-day operations, and we require immediate technical assistance to mitigate these issues.
#
#
# The router is critical to our network infrastructure and any prolonged downtime could hinder our core business processes. We have attempted initial diagnostics but were unable to resolve the issue on our own. Below, I have included some pertinent details for your reference:
#
#
# - Product Model: Cisco Router ISR4331
# - Date/Time of Issue: [Please Insert Date/Time]
#
#
# We kindly ask that a technical specialist be assigned to this matter at the earliest possible to assist us in troubleshooting and resolving the problem. Please let us know if further details are required from our end or if we should follow any preliminary steps before your team engages.
#
#
# Thank you very much for your prompt attention to this matter. We look forward to hearing from you soon.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 315
# Subject: Immediate Help Required
# Body: Dear Customer Service,
#
#
# I am encountering regular crashes with my Cisco Router ISR4331, which is greatly affecting my network performance. These interruptions are disrupting my daily tasks, and I urgently need your support to rectify this situation. Would you be able to provide any instructions or necessary actions to resolve this problem promptly? I am eager for your quick reply and assistance.
#
#
# Thank you,
#
#
# <name>
#
# Similar ticket index: 316
# Subject: Seeking Assistance: Router Leading to Network Disruptions
# Body: Dear Customer Support Team,
#
#
# I am contacting you to report a significant problem with our Cisco Router ISR4331. We have been encountering frequent network interruptions in our organization due to regular router resets and sluggish response times. These complications are profoundly affecting our enterprise's communication and operational productivity, hindering our ability to sustain stable network connections.
#
#
# We would sincerely appreciate your swift help in diagnosing and fixing this issue. Kindly inform us about the subsequent steps we should follow to alleviate these disturbances.
#
#
# Thank you for your assistance.
#
#
# Warm regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 318
# Subject: Immediate Support Required: Cisco ISR4331 Router Outage
# Body: Dear Customer Support,
#
#
# I trust this message finds you in good health. I am contacting you to inform you of a pressing issue with our Cisco Router ISR4331, which has recently gone offline unexpectedly, greatly affecting our network stability in the office. This unforeseen outage has interrupted our daily business activities, and we urgently seek technical support to address these challenges.
#
#
# The router plays a vital role in our network setup, and any extended outage could obstruct our essential business functions. We have conducted some preliminary diagnostics but were unsuccessful in resolving the problem independently. Here are relevant details for your reference:
#
#
# - Model: Cisco Router ISR4331
# - Time and Date of Issue: [Please Enter Date/Time]
#
#
# We humbly request that a technical expert be assigned to this case at your earliest convenience to aid us in the troubleshooting and resolution process. Please advise if any additional information is required on our part or if there are specific initial steps we should take prior to your team’s intervention.
#
#
# We greatly appreciate your immediate attention to this issue. We look forward to your swift response.
#
#
# Yours sincerely,
#   <name>
#   <tel_num>
#   <acc_num>
#
# Similar ticket index: 327
# Subject: High Priority: Recurrent Network Disconnections Problem
# Body: Hello Customer Care Team,
#
#
# We are facing recurrent disconnections with our Cisco Router ISR4331, which is significantly disrupting our office connectivity. We need immediate assistance and troubleshooting without delay. Please help us in addressing this issue.
#
#
# Best regards,
# <name>
#
# Similar ticket index: 336
# Subject: High Priority: Recurring Network Disruptions
# Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>
#
# --------------------
# Group with key ticket index: 220
# Subject: Urgent: Cisco ISR4331 Issues
# Body: Dear Customer Support,
#
#
# I am writing to bring to your attention a significant issue we are facing with one of your products, the Cisco Router ISR4331. We have been utilizing this device due to its robust performance capabilities and reliability, essential for maintaining the seamless operations of our network infrastructure. However, we have recently encountered sudden performance issues that have caused serious disruptions across multiple user connections. This has raised considerable concern within our organization, considering the reliance we place on this router for network efficiency.
#
#
# The unexpected degradation in performance manifests in slow data transmission across our network, resulting in considerable downtime and decreased productivity. We suspect that this may be attributed to either firmware glitches or potential hardware malfunction, although we couldn’t determine the exact cause based solely on our internal assessment. We have exhausted initial troubleshooting protocols, including basic resets and configuration reevaluations, with no improvement.
#
#
# Given the critical nature of this router to our networking operations, we urgently seek your expertise to diagnose and resolve the anomaly. Please let us know if there are specific diagnostic measures or updates you recommend. Additionally, if you could advise on any potential steps we might undertake to mitigate these disruptions while a solution is being identified, it would be greatly appreciated.
#
#
# Thank you in advance for your prompt response and assistance in addressing this issue. I look forward to your guidance.
#
#
# Sincerely,
#
#
# <name>
#
# Similar ticket index: 221
# Subject: Urgent: Network Outage
# Body: Dear IT Services Customer Support,<br><br>I hope this message finds you well. I am writing to report a severe issue impacting our office operations. We are experiencing a network outage due to a problem with our Cisco Router ISR4331, which is significantly affecting connectivity across our organization. The router issue commenced yesterday evening and has persisted, causing major disruptions in our working capabilities.<br><br>Given the nature of our business operations, maintaining uninterrupted network connectivity is crucial. The downtime we've experienced has hindered communication and access to critical online resources necessary for our daily transactions and operations. We believe this is a high-priority incident that requires immediate attention to prevent further operational disruption.<br><br>Earlier attempts to reboot the system and troubleshoot the router have not resolved the issue. We suspect the problem might be linked to the firmware of the Cisco Router ISR4331, but require expertise to confirm and resolve this. Please provide guidance or arrange a support session at your earliest convenience. Your expertise and prompt action in this matter would be highly appreciated to restore our network services and normal office functionality.<br><br>I look forward to your swift response.<br><br>Thank you for your attention to this urgent matter.<br><br>Best regards,<br><name><br><acc_num><br>Phone: <tel_num>
#
# Similar ticket index: 231
# Subject: Network Connectivity Issues
# Body: Dear Customer Support,
#
#
# I am writing to report a network connectivity issue we are experiencing with our Cisco Router ISR4331, impacting our secure enterprise networking and high-performance connections. The router, which is essential for our daily operations, has been intermittently dropping connections and affecting our overall productivity. We have rebooted the router and checked all physical connections, yet the problem persists. As this device is critical to ensure high-speed data transfer across our network, a prompt resolution is necessary.
#
#
# Could you please provide guidance or arrange for a technical specialist to assist us in diagnosing and resolving the issue? Any immediate advice to mitigate disruptions would be greatly appreciated.
#
#
# Thank you for your attention to this matter. I can be reached at <tel_num> or via email at <email> should you require further details.
#
#
# Best Regards,
#
#
# <name>
# <acc_num>
#
# Similar ticket index: 273
# Subject: Company Network Issue
# Body: Dear Customer Support,
#
#
# I am writing to report an issue with our Cisco Router ISR4331 at our headquarters. We are experiencing intermittent connection drops which are frequently disrupting our company's network activities. This issue has become increasingly problematic, affecting our daily operations and causing significant inconvenience. Our IT department has verified the problem is not sourced from our end. We would appreciate it if your team could provide us with a solution or suggest the next steps for troubleshooting. Your prompt attention to this matter would be highly appreciated.
#
#
# Thank you,
# <name>
# IT Department
# <name> Ltd.
#
# Similar ticket index: 279
# Subject: Critical Issue: Network Interruption
# Body: Dear IT Services Customer Support,<br><br>I trust this message reaches you in good spirits. I am writing to draw your attention to a serious matter that is disrupting our office activities. We are encountering a network interruption linked to our Cisco Router ISR4331, which is severely compromising connectivity throughout our company. This router problem began yesterday evening and continues, resulting in considerable disturbances to our operational capability.<br><br>Given the critical importance of consistent network connectivity for our business functions, the outages we are facing have obstructed communication and access to essential online resources vital for our daily transactions and operations. We regard this as a high-priority situation that necessitates urgent resolution to avert any further interruptions to our operations.<br><br>Previous attempts to restart the system and diagnose the router have proven unsuccessful. We suspect that this issue could be associated with the firmware of the Cisco Router ISR4331, and require professional insight to validate and address it. We kindly request guidance or to schedule a support session at your earliest convenience. Your expertise and swift intervention in this situation would be profoundly appreciated to restore our network operations and standard office functionality.<br><br>I eagerly anticipate your immediate response.<br><br>Thank you for your prompt attention to this pressing issue.<br><br>Best regards,<br><name><br><acc_num><br>Phone: <tel_num>
#
# Similar ticket index: 286
# Subject: Requesting Support: Router causing network issues
# Body: Dear Customer Support Team,
#
#
# I am reaching out to report a critical issue with our Cisco Router ISR4331. We have been experiencing repeated network disruptions at our enterprise due to frequent router resets and slow response times. These issues are severely impacting our organization's communication and operational efficiency, and we are unable to maintain stable network connections.
#
#
# We would greatly appreciate your prompt assistance in diagnosing and resolving this matter. Please let us know the next steps we should take to mitigate these disruptions.
#
#
# Thank you for your support.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 301
# Subject: Urgent Assistance Needed: Cisco ISR4331 Downtime
# Body: Dear Customer Support Team,
#
#
# I hope this message finds you well. I am reaching out to report an urgent issue with the Cisco Router ISR4331, which recently experienced sudden downtime, thereby significantly impacting our network performance at the office. This unexpected outage has disrupted our day-to-day operations, and we require immediate technical assistance to mitigate these issues.
#
#
# The router is critical to our network infrastructure and any prolonged downtime could hinder our core business processes. We have attempted initial diagnostics but were unable to resolve the issue on our own. Below, I have included some pertinent details for your reference:
#
#
# - Product Model: Cisco Router ISR4331
# - Date/Time of Issue: [Please Insert Date/Time]
#
#
# We kindly ask that a technical specialist be assigned to this matter at the earliest possible to assist us in troubleshooting and resolving the problem. Please let us know if further details are required from our end or if we should follow any preliminary steps before your team engages.
#
#
# Thank you very much for your prompt attention to this matter. We look forward to hearing from you soon.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 315
# Subject: Immediate Help Required
# Body: Dear Customer Service,
#
#
# I am encountering regular crashes with my Cisco Router ISR4331, which is greatly affecting my network performance. These interruptions are disrupting my daily tasks, and I urgently need your support to rectify this situation. Would you be able to provide any instructions or necessary actions to resolve this problem promptly? I am eager for your quick reply and assistance.
#
#
# Thank you,
#
#
# <name>
#
# Similar ticket index: 316
# Subject: Seeking Assistance: Router Leading to Network Disruptions
# Body: Dear Customer Support Team,
#
#
# I am contacting you to report a significant problem with our Cisco Router ISR4331. We have been encountering frequent network interruptions in our organization due to regular router resets and sluggish response times. These complications are profoundly affecting our enterprise's communication and operational productivity, hindering our ability to sustain stable network connections.
#
#
# We would sincerely appreciate your swift help in diagnosing and fixing this issue. Kindly inform us about the subsequent steps we should follow to alleviate these disturbances.
#
#
# Thank you for your assistance.
#
#
# Warm regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 318
# Subject: Immediate Support Required: Cisco ISR4331 Router Outage
# Body: Dear Customer Support,
#
#
# I trust this message finds you in good health. I am contacting you to inform you of a pressing issue with our Cisco Router ISR4331, which has recently gone offline unexpectedly, greatly affecting our network stability in the office. This unforeseen outage has interrupted our daily business activities, and we urgently seek technical support to address these challenges.
#
#
# The router plays a vital role in our network setup, and any extended outage could obstruct our essential business functions. We have conducted some preliminary diagnostics but were unsuccessful in resolving the problem independently. Here are relevant details for your reference:
#
#
# - Model: Cisco Router ISR4331
# - Time and Date of Issue: [Please Enter Date/Time]
#
#
# We humbly request that a technical expert be assigned to this case at your earliest convenience to aid us in the troubleshooting and resolution process. Please advise if any additional information is required on our part or if there are specific initial steps we should take prior to your team’s intervention.
#
#
# We greatly appreciate your immediate attention to this issue. We look forward to your swift response.
#
#
# Yours sincerely,
#   <name>
#   <tel_num>
#   <acc_num>
#
# Similar ticket index: 336
# Subject: High Priority: Recurring Network Disruptions
# Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>
#
# --------------------
# Group with key ticket index: 221
# Subject: Urgent: Network Outage
# Body: Dear IT Services Customer Support,<br><br>I hope this message finds you well. I am writing to report a severe issue impacting our office operations. We are experiencing a network outage due to a problem with our Cisco Router ISR4331, which is significantly affecting connectivity across our organization. The router issue commenced yesterday evening and has persisted, causing major disruptions in our working capabilities.<br><br>Given the nature of our business operations, maintaining uninterrupted network connectivity is crucial. The downtime we've experienced has hindered communication and access to critical online resources necessary for our daily transactions and operations. We believe this is a high-priority incident that requires immediate attention to prevent further operational disruption.<br><br>Earlier attempts to reboot the system and troubleshoot the router have not resolved the issue. We suspect the problem might be linked to the firmware of the Cisco Router ISR4331, but require expertise to confirm and resolve this. Please provide guidance or arrange a support session at your earliest convenience. Your expertise and prompt action in this matter would be highly appreciated to restore our network services and normal office functionality.<br><br>I look forward to your swift response.<br><br>Thank you for your attention to this urgent matter.<br><br>Best regards,<br><name><br><acc_num><br>Phone: <tel_num>
#
# Similar ticket index: 231
# Subject: Network Connectivity Issues
# Body: Dear Customer Support,
#
#
# ...
#
#
# - Model: Cisco Router ISR4331
# - Time and Date of Issue: [Please Enter Date/Time]
#
#
# We humbly request that a technical expert be assigned to this case at your earliest convenience to aid us in the troubleshooting and resolution process. Please advise if any additional information is required on our part or if there are specific initial steps we should take prior to your team’s intervention.
#
#
# We greatly appreciate your immediate attention to this issue. We look forward to your swift response.
#
#
# Yours sincerely,
#   <name>
#   <tel_num>
#   <acc_num>
#
# Similar ticket index: 327
# Subject: High Priority: Recurrent Network Disconnections Problem
# Body: Hello Customer Care Team,
#
#
# We are facing recurrent disconnections with our Cisco Router ISR4331, which is significantly disrupting our office connectivity. We need immediate assistance and troubleshooting without delay. Please help us in addressing this issue.
#
#
# Best regards,
# <name>
#
# Similar ticket index: 336
# Subject: High Priority: Recurring Network Disruptions
# Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>
#
# --------------------
# Group with key ticket index: 316
# Subject: Seeking Assistance: Router Leading to Network Disruptions
# Body: Dear Customer Support Team,
#
#
# I am contacting you to report a significant problem with our Cisco Router ISR4331. We have been encountering frequent network interruptions in our organization due to regular router resets and sluggish response times. These complications are profoundly affecting our enterprise's communication and operational productivity, hindering our ability to sustain stable network connections.
#
#
# We would sincerely appreciate your swift help in diagnosing and fixing this issue. Kindly inform us about the subsequent steps we should follow to alleviate these disturbances.
#
#
# Thank you for your assistance.
#
#
# Warm regards,
#
#
# <name>
# <tel_num>
# <acc_num>
#
# Similar ticket index: 318
# Subject: Immediate Support Required: Cisco ISR4331 Router Outage
# Body: Dear Customer Support,
#
#
# I trust this message finds you in good health. I am contacting you to inform you of a pressing issue with our Cisco Router ISR4331, which has recently gone offline unexpectedly, greatly affecting our network stability in the office. This unforeseen outage has interrupted our daily business activities, and we urgently seek technical support to address these challenges.
#
#
# The router plays a vital role in our network setup, and any extended outage could obstruct our essential business functions. We have conducted some preliminary diagnostics but were unsuccessful in resolving the problem independently. Here are relevant details for your reference:
#
#
# - Model: Cisco Router ISR4331
# - Time and Date of Issue: [Please Enter Date/Time]
#
#
# We humbly request that a technical expert be assigned to this case at your earliest convenience to aid us in the troubleshooting and resolution process. Please advise if any additional information is required on our part or if there are specific initial steps we should take prior to your team’s intervention.
#
#
# We greatly appreciate your immediate attention to this issue. We look forward to your swift response.
#
#
# Yours sincerely,
#   <name>
#   <tel_num>
#   <acc_num>
#
# Similar ticket index: 327
# Subject: High Priority: Recurrent Network Disconnections Problem
# Body: Hello Customer Care Team,
#
#
# We are facing recurrent disconnections with our Cisco Router ISR4331, which is significantly disrupting our office connectivity. We need immediate assistance and troubleshooting without delay. Please help us in addressing this issue.
#
#
# Best regards,
# <name>
#
# Similar ticket index: 336
# Subject: High Priority: Recurring Network Disruptions
# Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>
#
# --------------------
# Group with key ticket index: 317
# Subject: Billing Issue with AWS Management Service
# Body: Dear Customer Support,
#
#
# I hope this message finds you well. I am writing to bring to your attention an issue concerning the recent billing related to our AWS cloud usage. Upon reviewing our most recent statement, it appears that there are discrepancies that have significantly impacted our cost estimates. It seems the charges associated with the AWS Management Service do not align with the actual usage recorded on our account <acc_num>.
#
#
# The incorrect billing has resulted in unexpected costs that differ noticeably from our budget forecasts, making it difficult for us to manage our financial resources efficiently. This discrepancy was first noticed by <name> from our finance department, prompting an urgent need for your review of the billing details.
#
#
# Could you please conduct a thorough review of our account to determine the cause of this miscalculation? We believe that an error in recording or processing has occurred that needs rectification. We would appreciate it if you could provide us with an updated billing statement and any insights on preventing such issues from occurring in the future.
#
#
# Thank you for your prompt attention to this matter. We look forward to your swift resolution.
#
#
# Best regards,
#
#
# <name>
#
#
# <t_num>
#
# Similar ticket index: 326
# Subject: Request for Billing Support
# Body: Hello Customer Support Team,
#
#
# I am contacting you for help with some billing issues I have noticed concerning our AWS cloud computing services, specifically linked to the AWS Management Service. Our organization, <name> Tech Solutions, has recently received an invoice that seems to apply charges for services we did not use during the billing cycle. We have diligently tracked our usage and found no reason for the unanticipated fees linked to our account <acc_num>.
#
#
# Our billing statements show charges on various dates that require explanation. After scrutinizing the invoice, it appears there could be a problem regarding how the usage data has been documented or handled. We would be grateful for a comprehensive examination of our account and any updates on possible errors or inconsistencies.
#
#
# Please get in touch with me at your earliest convenience at <tel_num> or via email to resolve this pressing issue. Thank you for your prompt attention to this concern.
#
#
# Best regards,
# <name>
# IT Manager, <name> Tech Solutions
#
# --------------------
# Group with key ticket index: 318
# Subject: Immediate Support Required: Cisco ISR4331 Router Outage
# Body: Dear Customer Support,
#
#
# I trust this message finds you in good health. I am contacting you to inform you of a pressing issue with our Cisco Router ISR4331, which has recently gone offline unexpectedly, greatly affecting our network stability in the office. This unforeseen outage has interrupted our daily business activities, and we urgently seek technical support to address these challenges.
#
#
# The router plays a vital role in our network setup, and any extended outage could obstruct our essential business functions. We have conducted some preliminary diagnostics but were unsuccessful in resolving the problem independently. Here are relevant details for your reference:
#
#
# - Model: Cisco Router ISR4331
# - Time and Date of Issue: [Please Enter Date/Time]
#
#
# We humbly request that a technical expert be assigned to this case at your earliest convenience to aid us in the troubleshooting and resolution process. Please advise if any additional information is required on our part or if there are specific initial steps we should take prior to your team’s intervention.
#
#
# We greatly appreciate your immediate attention to this issue. We look forward to your swift response.
#
#
# Yours sincerely,
#   <name>
#   <tel_num>
#   <acc_num>
#
# Similar ticket index: 327
# Subject: High Priority: Recurrent Network Disconnections Problem
# Body: Hello Customer Care Team,
#
#
# We are facing recurrent disconnections with our Cisco Router ISR4331, which is significantly disrupting our office connectivity. We need immediate assistance and troubleshooting without delay. Please help us in addressing this issue.
#
#
# Best regards,
# <name>
#
# Similar ticket index: 336
# Subject: High Priority: Recurring Network Disruptions
# Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>
#
# --------------------
# Group with key ticket index: 322
# Subject: Urgent Help Needed: AWS Deployment Issue
# Body: Dear IT Services Support Team,
#
#
# I am writing to inform you of a critical issue we are facing with the AWS Management Service. We have encountered an unexpected deployment issue that has resulted in significant downtime for our customer-facing applications. The situation requires immediate attention to restore our services and ensure customers can access our platform without any further disruption.
#
#
# We are particularly concerned about the potential impact on our customer satisfaction and service-level agreements if this problem is not addressed promptly. Please provide guidance on the necessary steps to resolve this issue quickly or direct our request to a specialist team that can assist us further.
#
#
# For reference, the affected account number is <acc_num>, and our last contact with support was under case ID <case_id>. We appreciate your urgent response to this matter and look forward to a swift resolution.
#
#
# Thank you for your prompt attention to this critical issue.
#
#
# Warm regards,
# <name>
#
#
# Phone: <tel_num>
#
# Similar ticket index: 323
# Subject: Urgent Support Required for AWS Issue Resolution
# Body: Dear IT Services Customer Support Team, I hope this message finds you well. I am writing to urgently request assistance with a critical issue we are experiencing with the AWS Management Service. Currently, our team is encountering significant challenges in deploying AWS resources, and this has resulted in extensive downtime, severely impacting our operations. The inability to seamlessly deploy resources has not only hindered our daily functioning but also resulted in substantial cost implications. As you can imagine, downtime in our systems leads to delayed project delivery and affects our service level commitments to our clients. We have attempted several workarounds but have yet to identify a successful solution. This matter has become pressing and requires an immediate resolution. Given the extensive impact on both financial and operational fronts, we would appreciate it if your team could provide us with prompt and efficient support. Please let me know the specific details you require from us to expedite the resolution process. Our account number is <acc_num>, and if necessary, I can be reached directly at <tel_num> for further information or coordination. I look forward to your immediate response. Thank you in advance for your attention and support. Kind regards, <name>
#
# --------------------
# Group with key ticket index: 323
# Subject: Urgent Support Required for AWS Issue Resolution
# Body: Dear IT Services Customer Support Team, I hope this message finds you well. I am writing to urgently request assistance with a critical issue we are experiencing with the AWS Management Service. Currently, our team is encountering significant challenges in deploying AWS resources, and this has resulted in extensive downtime, severely impacting our operations. The inability to seamlessly deploy resources has not only hindered our daily functioning but also resulted in substantial cost implications. As you can imagine, downtime in our systems leads to delayed project delivery and affects our service level commitments to our clients. We have attempted several workarounds but have yet to identify a successful solution. This matter has become pressing and requires an immediate resolution. Given the extensive impact on both financial and operational fronts, we would appreciate it if your team could provide us with prompt and efficient support. Please let me know the specific details you require from us to expedite the resolution process. Our account number is <acc_num>, and if necessary, I can be reached directly at <tel_num> for further information or coordination. I look forward to your immediate response. Thank you in advance for your attention and support. Kind regards, <name>
#
# Similar ticket index: 331
# Subject: Inquiry About Economical AWS Management Alternatives
# Body: Hello Customer Support Team,
#
#
# I trust this message finds you in good spirits. My name is <name>, and I manage operations at <name>'s office. We have been utilizing your AWS Management Services for the past year, and while the services have generally met our expectations, we have faced some issues concerning the elevated operational expenses associated with it.
#
#
# Given our financial situation, we are seeking guidance on how to enhance our current utilization of AWS Management Services. More specifically, we are eager to explore economical solutions that can help streamline our processes while maintaining performance and reliability. Would you be able to share insights or suggestions on the options or modifications we might evaluate?
#
#
# A thorough understanding of our AWS usage and pinpointing potential areas for cost reduction would greatly aid our financial management and operational planning.
#
#
# Thank you for your support and for considering our request. I am looking forward to your prompt response with potential solutions or the possibility of arranging a meeting with a consultant.
#
#
# Sincerely,
#
#
# <name>
# <name>'s IT Department
# Contact: <tel_num>
#
# --------------------
# Group with key ticket index: 324
# Subject: Need Support
# Body: Kindly assist in setting up the Canon PIXMA MG3620 for wireless printing in my home.
#
# Similar ticket index: 337
# Subject: Request for Support
# Body: I would appreciate help setting up my Canon PIXMA MG3620 for wireless printing at my residence.
#
# --------------------
# Group with key ticket index: 327
# Subject: High Priority: Recurrent Network Disconnections Problem
# Body: Hello Customer Care Team,
#
#
# We are facing recurrent disconnections with our Cisco Router ISR4331, which is significantly disrupting our office connectivity. We need immediate assistance and troubleshooting without delay. Please help us in addressing this issue.
#
#
# Best regards,
# <name>
#
# Similar ticket index: 336
# Subject: High Priority: Recurring Network Disruptions
# Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>
#
# --------------------
# Group with key ticket index: 329
# Subject: Critical Problem
# Body: Hello Support Team, we are encountering a severe problem with the server management that is affecting our ticketing system and software development tasks. Prompt assistance is necessary to address this and reduce business repercussions. Best, <name>.
#
# Similar ticket index: 332
# Subject: Critical Concern
# Body: Dear Support Team, we are facing a pressing issue with the server management that is affecting our ticketing platform and software development activities. Immediate help is needed to rectify this situation and lessen the effects on our business operations. Best regards, <name>.
#
# --------------------

# %% [markdown]
# Tried to create cluster for issues having similar body

# %%
#  grouped_tickets_by_body = group_tickets_by_similar_bodies(data_en)


# Iterate through the grouped tickets
for key_index, similar_indices in grouped_tickets_by_body.items():
    # Create a list to store the ticket information for the current cluster
    cluster = []
    # Add the key ticket to the cluster
    cluster.append({
        "index": key_index,
        "subject": data_en['subject'].iloc[key_index],
        "body": data_en['body'].iloc[key_index]
    })
    # Add the similar tickets to the cluster
    for index in similar_indices:
        cluster.append({
            "index": index,
            "subject": data_en['subject'].iloc[index],
            "body": data_en['body'].iloc[index]
        })

    clusters[key_index] = cluster


if 0 in clusters:
  print("First cluster:")
  for ticket in clusters[0]:
    print(f"Index: {ticket['index']}, Subject: {ticket['subject']}, Body: {ticket['body']}")
# Out:
# First cluster:
# Index: 0, Subject: Urgent: Critical impact on enterprise network connectivity, Body: Dear Customer Support Team, We are experiencing a complete outage affecting our enterprise network involving Cisco Router ISR4331. This disruption is critically impacting our secure WAN connectivity across all domains, urgently requiring your immediate intervention. Due to this issue, our company has halted various essential operations, significantly affecting our services and commitments to clients. As our technical team has not been able to resolve the problem internally, we need your expert support to diagnose and rectify this issue swiftly. Please consider this a high priority and provide us with the necessary technical assistance to restore our network’s functionality. Thank you for your prompt attention. Best regards, <name>, IT Manager at <company>
# Index: 30, Subject: Intermittent Connectivity Issues with Cisco Router, Body: Dear Customer Support Team,
#
#
# I am writing to bring to your attention that our Cisco Router, model ISR4331, is experiencing intermittent connectivity issues. This has been ongoing and is significantly affecting network performance in our enterprise environment. We have performed an initial check on the basic configuration, including verifying firmware and software versions handling routing protocols, but have not identified any obvious faults or misconfigurations. Despite these preliminary checks, the router continues to exhibit unstable behavior which warrants deeper analysis to identify potential underlying issues. Given the message logs and our current operational reliance on consistent network performance, I urge your technical team to assist in thoroughly diagnosing these connectivity disruptions. Your expert support in identifying and rectifying this issue is crucial to restoring satisfactory performance levels quickly. Please let me know how we can proceed with escalating this issue or scheduling an in-depth technical support session. Thank you for your prompt attention to this matter.
#
#
# Sincerely,
# <name>
# IT Department
# <name> Corporation
# <tel_num>
# <email>
# Index: 53, Subject: Urgent Router Issue, Body: Dear Customer Support,
#
#
# I am writing to bring to your attention a critical issue we are currently experiencing with our Cisco Router ISR4331. Recently, it has been subject to frequent disconnections which are significantly affecting our enterprise network's performance and, consequently, our organizational productivity. The persistent interruptions in connectivity are impeding our ability to carry out daily operations smoothly.
#
#
# Given the core role this router plays in our infrastructure, we kindly request an immediate resolution to prevent further disruptions to our business processes. Since seamless network functionality is critical to our operations, it is essential for us to address this problem at the earliest possible opportunity.
#
#
# Please let us know the next steps we should take or any troubleshooting procedures we might attempt while awaiting further instructions from your team. Your urgent attention and prompt resolution of this matter would be greatly appreciated, as it is profoundly impacting our work.
#
#
# For your reference, my full name is <name>, and I am available anytime to discuss this issue or assist with any preliminary checks. You can reach me at <tel_num>.
#
#
# Thank you for your attention to this urgent matter.
#
#
# Best regards,
#
#
# <name>
# Index: 100, Subject: Frequent Disconnect Issues with Cisco Router ISR4331, Body: To whom it may concern, I am writing to report frequent disconnects with our Cisco Router ISR4331, which is impacting secure networking services. This issue has been affecting our high performance tech support team that relies on stable connections. Timely resolution of this issue is crucial for maintaining our service standards. I would appreciate technical guidance or a site visit to promptly resolve this matter. Please let us know the appointment process or escalation process. Thank you for your attention. Best regards, <name>
# Index: 105, Subject: Intermittent Network Issues, Body: Dear Customer Support Team,
#
#
# I hope this message finds you well. I am writing to bring to your attention a critical issue we are experiencing at our enterprise. We've been encountering intermittent network connectivity problems with our Cisco Router ISR4331. These disruptions have been ongoing and are significantly impacting our productivity and overall performance. The nature of the issue seems to suggest that the router periodically fails to maintain a stable connection, which in turn limits our capacity to effectively execute important tasks that depend on consistent network access.
#
#
# Our network plays a crucial role in day-to-day operations, and any downtime translates directly into loss of time and resources. Given the pivotal function of the Cisco Router ISR4331 in our network architecture, resolving this problem is of paramount importance to us. We kindly request your immediate assistance to diagnose and rectify these connectivity issues. If needed, please feel free to reach out to our technical lead, <name>, at <tel_num>.
#
#
# We appreciate your prompt attention to this matter and look forward to a quick resolution. Thank you for your support.
#
#
# Kind regards,
#
#
# <name>
# <company-name>
# <acc_num>
# Index: 115, Subject: Cisco Router Outage, Body: Dear Customer Support,
#
#
# I am writing to inform you about a high priority technical issue we are experiencing with the Cisco Router ISR4331. The error associated with this equipment has led to a complete service outage affecting multiple clients, necessitating immediate attention and resolution.
#
#
# This problem was first detected on <date>, and it has severely impacted our service delivery. We have received numerous reports from clients who are unable to access their services, and this is causing significant operational disruptions for them. It appears that the router is unable to maintain connectivity and this disruption is consistent across several linked networks. We have verified all connections and settings to ensure that the issue does not lie within our internal systems. Consequently, we strongly suspect a fault originating from the router’s hardware or firmware that needs urgent investigation.
#
#
# Given the critical nature of this problem, we are escalating this issue to the highest priority. Our clients depend on us for reliable service, and it is imperative that this disruption is resolved quickly to minimize further losses and restore the trust of those affected. We would appreciate it if you could dispatch a senior technical team to assess and address the root cause at the earliest opportunity.
#
#
# Could you please confirm receipt of this communication and provide guidance on the next steps? We trust in your proficiency and rely on your expertise to help us restore full functionality at the soonest possible.
#
#
# For documentation purposes, our account number is <acc_num>. Kindly contact us via this email or at <tel_num> should you require further information or clarification.
#
#
# Thank you for your prompt attention to this critical issue.
#
#
# Best regards,
#
#
# <name>
# IT Services Team
# Index: 123, Subject: Urgent: Connectivity Issues with Cisco Router ISR4331, Body: Dear IT Services Support Team,
#
#
# I am writing to report an issue with the Cisco Router ISR4331 that is experiencing sudden connectivity disruptions. The issue began affecting network performance across various departments, causing significant operational challenges. We rely on this router for critical communications, and this downtime impacts our productivity. Please prioritize this matter and advise on any troubleshooting steps or if requiring immediate attention from your team. Your prompt response will be greatly appreciated as we work towards resolving this problem. Looking forward to your guidance.
#
#
# Thank you,
# <name>
# <acc_num>
# <tel_num>
# Index: 134, Subject: Network Outage Due to Cisco Router ISR4331 Failure, Body: Dear Customer Support,
#
#
# We are experiencing a critical network outage owing to a malfunction in our Cisco Router ISR4331, which has led to widespread connectivity issues across our organization. This issue started earlier today and is affecting all communication and data transfer services, severely impacting our operations. We rely on dependable network solutions and would appreciate immediate assistance to rectify this problem. Kindly escalate this issue and prioritize our request, as it is affecting our entire team's productivity. Please provide guidance or a resolution pathway at your earliest convenience.
#
#
# Thank you for your prompt attention to this urgent matter.
#
#
# Best regards,
#
#
# <name>
# <name> Technologies
# Index: 136, Subject: Network Connectivity Challenges Occurring Intermittently, Body: Dear Support Team,
#
#
# I hope this message reaches you in good spirits. I am contacting you to highlight a serious issue that our organization is currently facing. We have been dealing with intermittent connectivity problems with our Cisco Router ISR4331. These incidents have persisted and are drastically affecting our productivity as well as overall performance. The issue appears to indicate that the router occasionally fails to maintain a reliable connection, consequently hindering our ability to perform crucial tasks that rely on a stable network.
#
#
# Our network is vital for our daily operations, and any interruption directly results in a waste of time and resources. Given the significant role the Cisco Router ISR4331 plays in our network structure, it is extremely important for us to resolve this matter. We kindly seek your immediate help in diagnosing and fixing these connectivity challenges. Should you require additional information, please do not hesitate to contact our technical lead, <name>, at <tel_num>.
#
#
# Thank you for your swift attention to this issue, and we look forward to a prompt resolution. We are grateful for your assistance.
#
#
# Best regards,
#
#
# <name>
# <company-name>
# <acc_num>
# Index: 154, Subject: Urgent Cisco Router Issue, Body: Dear IT Services Customer Support,
#
#
# We are reporting a high-priority incident involving a faulty Cisco Router ISR4331. This issue is causing significant network outages and requires your immediate attention and support. The router in question is crucial to our operations, and its malfunction is impacting our daily functions. Please assign someone to this at the earliest convenience to mitigate downtime impacts.
#
#
# Thank you for your prompt response.
#
#
# Best Regards,
# <name>, Network Admin
# <acc_num>
# <tel_num>
# Index: 160, Subject: Critical: Recurring Network Disruption Problem, Body: Hello Customer Support,
#
#
# We are facing constant network disruptions with our Cisco Router ISR4331 that are significantly hindering our office's connectivity. An immediate fix and troubleshooting assistance are urgently needed. Please help us resolve this problem.
#
#
# Thank you,
# <name>
# Index: 167, Subject: Network Issues with Cisco Router, Body: Dear Customer Support,
#
#
# I am reaching out to report frequent network disconnections that we have been experiencing in our system, potentially due to either misconfigured settings or a hardware malfunction in our Cisco Router ISR4331. We rely heavily on stable and continuous connectivity to efficiently run our operations, and these interruptions are significantly affecting our productivity.
#
#
# These issues began approximately two weeks ago and have progressively worsened, occurring at unpredictable intervals and causing considerable disruption to our workflow. We suspect that it may be either a setting within the router that needs to be updated or a possible hardware defect that requires repair or replacement.
#
#
# The device in question is located at our main office and serves as the primary router in our network infrastructure. Our IT department has already reviewed and confirmed all other equipment and network settings as operational and consistent with optimal performance standards, indicating that the problem is isolated to this particular Cisco model.
#
#
# Any guidance or support you could provide in resolving this matter would be greatly appreciated. If necessary, please let us know the soonest available opportunity to schedule a service assessment. We can accommodate investigations outside of regular business hours if it helps expedite the resolution.
#
#
# Thank you for your prompt attention to this issue. Please feel free to reach me anytime at <tel_num>, or reply to this email for further discussions. Looking forward to your support to fix this inconvenience.
#
#
# Best regards,
#
#
# <name>
# <acc_num>
# Index: 170, Subject: Urgent: Critical Network Issue with Router ISR4331, Body: Dear Support Team,
#
#
# I am writing to report a high-priority incident involving our Cisco Router ISR4331. Our network has been experiencing frequent dropouts, significantly affecting our enterprise connectivity. This issue impacts our operations, and we need urgent assistance to resolve it as soon as possible.
#
#
# The disruption in connectivity is causing delays and inefficiencies, impacting overall productivity. After multiple attempts to diagnose internally, we have been unable to pinpoint the root cause of the problem. Therefore, we seek your expert assistance in resolving this matter.
#
#
# We have logged this incident as urgent and would appreciate a prompt response outlining your next steps or any immediate actions we can take in the interim. Please coordinate this matter with our IT head, <name>, who can be reached at <tel_num>.
#
#
# Thank you for your immediate attention to this matter.
#
#
# Sincerely,
#
#
# <name>
# <position>
# <company>
# Index: 210, Subject: High Priority Incident: Router Connectivity Issues, Body: Dear Customer Support,
#
#
# I hope this message finds you well. I am writing to report a high-priority incident involving unstable connectivity issues with our Cisco Router ISR4331, which is currently impacting the performance of our enterprise network. Our entire network operations depend heavily on this router, and any disruptions can lead to significant operational setbacks.
#
#
# The connectivity issues started occurring approximately 48 hours ago and have progressively worsened. Our IT team has conducted preliminary troubleshooting, which includes checking the physical connections, updating the firmware, and resetting the device multiple times; however, these actions have not resolved the issue. The router still exhibits sporadic connectivity drop-offs, causing disruptions in our daily workflows and negatively affecting the user experience within our enterprise.
#
#
# We are requesting immediate technical assistance from your team to diagnose and resolve this matter as quickly as possible. Given that this issue is causing serious disruptions in our business operations, we would appreciate a swift response and an onsite assessment if required.
#
#
# Please let us know the next steps to take and if any additional information is needed from our end for a quicker resolution. You can reach me at <tel_num> or email me directly for any further queries. Our goal is to get this critical issue resolved at the earliest to mitigate any potential downsides resulting from prolonged network downtimes.
#
#
# Thank you for attending to this matter with urgency. I look forward to your prompt response.
#
#
# Best regards,
#
#
# <name>
# IT Manager
# <acc_num>
# Index: 220, Subject: Urgent: Cisco ISR4331 Issues, Body: Dear Customer Support,
#
#
# I am writing to bring to your attention a significant issue we are facing with one of your products, the Cisco Router ISR4331. We have been utilizing this device due to its robust performance capabilities and reliability, essential for maintaining the seamless operations of our network infrastructure. However, we have recently encountered sudden performance issues that have caused serious disruptions across multiple user connections. This has raised considerable concern within our organization, considering the reliance we place on this router for network efficiency.
#
#
# The unexpected degradation in performance manifests in slow data transmission across our network, resulting in considerable downtime and decreased productivity. We suspect that this may be attributed to either firmware glitches or potential hardware malfunction, although we couldn’t determine the exact cause based solely on our internal assessment. We have exhausted initial troubleshooting protocols, including basic resets and configuration reevaluations, with no improvement.
#
#
# Given the critical nature of this router to our networking operations, we urgently seek your expertise to diagnose and resolve the anomaly. Please let us know if there are specific diagnostic measures or updates you recommend. Additionally, if you could advise on any potential steps we might undertake to mitigate these disruptions while a solution is being identified, it would be greatly appreciated.
#
#
# Thank you in advance for your prompt response and assistance in addressing this issue. I look forward to your guidance.
#
#
# Sincerely,
#
#
# <name>
# Index: 221, Subject: Urgent: Network Outage, Body: Dear IT Services Customer Support,<br><br>I hope this message finds you well. I am writing to report a severe issue impacting our office operations. We are experiencing a network outage due to a problem with our Cisco Router ISR4331, which is significantly affecting connectivity across our organization. The router issue commenced yesterday evening and has persisted, causing major disruptions in our working capabilities.<br><br>Given the nature of our business operations, maintaining uninterrupted network connectivity is crucial. The downtime we've experienced has hindered communication and access to critical online resources necessary for our daily transactions and operations. We believe this is a high-priority incident that requires immediate attention to prevent further operational disruption.<br><br>Earlier attempts to reboot the system and troubleshoot the router have not resolved the issue. We suspect the problem might be linked to the firmware of the Cisco Router ISR4331, but require expertise to confirm and resolve this. Please provide guidance or arrange a support session at your earliest convenience. Your expertise and prompt action in this matter would be highly appreciated to restore our network services and normal office functionality.<br><br>I look forward to your swift response.<br><br>Thank you for your attention to this urgent matter.<br><br>Best regards,<br><name><br><acc_num><br>Phone: <tel_num>
# Index: 231, Subject: Network Connectivity Issues, Body: Dear Customer Support,
#
#
# I am writing to report a network connectivity issue we are experiencing with our Cisco Router ISR4331, impacting our secure enterprise networking and high-performance connections. The router, which is essential for our daily operations, has been intermittently dropping connections and affecting our overall productivity. We have rebooted the router and checked all physical connections, yet the problem persists. As this device is critical to ensure high-speed data transfer across our network, a prompt resolution is necessary.
#
#
# Could you please provide guidance or arrange for a technical specialist to assist us in diagnosing and resolving the issue? Any immediate advice to mitigate disruptions would be greatly appreciated.
#
#
# Thank you for your attention to this matter. I can be reached at <tel_num> or via email at <email> should you require further details.
#
#
# Best Regards,
#
#
# <name>
# <acc_num>
# Index: 273, Subject: Company Network Issue, Body: Dear Customer Support,
#
#
# I am writing to report an issue with our Cisco Router ISR4331 at our headquarters. We are experiencing intermittent connection drops which are frequently disrupting our company's network activities. This issue has become increasingly problematic, affecting our daily operations and causing significant inconvenience. Our IT department has verified the problem is not sourced from our end. We would appreciate it if your team could provide us with a solution or suggest the next steps for troubleshooting. Your prompt attention to this matter would be highly appreciated.
#
#
# Thank you,
# <name>
# IT Department
# <name> Ltd.
# Index: 279, Subject: Critical Issue: Network Interruption, Body: Dear IT Services Customer Support,<br><br>I trust this message reaches you in good spirits. I am writing to draw your attention to a serious matter that is disrupting our office activities. We are encountering a network interruption linked to our Cisco Router ISR4331, which is severely compromising connectivity throughout our company. This router problem began yesterday evening and continues, resulting in considerable disturbances to our operational capability.<br><br>Given the critical importance of consistent network connectivity for our business functions, the outages we are facing have obstructed communication and access to essential online resources vital for our daily transactions and operations. We regard this as a high-priority situation that necessitates urgent resolution to avert any further interruptions to our operations.<br><br>Previous attempts to restart the system and diagnose the router have proven unsuccessful. We suspect that this issue could be associated with the firmware of the Cisco Router ISR4331, and require professional insight to validate and address it. We kindly request guidance or to schedule a support session at your earliest convenience. Your expertise and swift intervention in this situation would be profoundly appreciated to restore our network operations and standard office functionality.<br><br>I eagerly anticipate your immediate response.<br><br>Thank you for your prompt attention to this pressing issue.<br><br>Best regards,<br><name><br><acc_num><br>Phone: <tel_num>
# Index: 286, Subject: Requesting Support: Router causing network issues, Body: Dear Customer Support Team,
#
#
# I am reaching out to report a critical issue with our Cisco Router ISR4331. We have been experiencing repeated network disruptions at our enterprise due to frequent router resets and slow response times. These issues are severely impacting our organization's communication and operational efficiency, and we are unable to maintain stable network connections.
#
#
# We would greatly appreciate your prompt assistance in diagnosing and resolving this matter. Please let us know the next steps we should take to mitigate these disruptions.
#
#
# Thank you for your support.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
# Index: 301, Subject: Urgent Assistance Needed: Cisco ISR4331 Downtime, Body: Dear Customer Support Team,
#
#
# I hope this message finds you well. I am reaching out to report an urgent issue with the Cisco Router ISR4331, which recently experienced sudden downtime, thereby significantly impacting our network performance at the office. This unexpected outage has disrupted our day-to-day operations, and we require immediate technical assistance to mitigate these issues.
#
#
# The router is critical to our network infrastructure and any prolonged downtime could hinder our core business processes. We have attempted initial diagnostics but were unable to resolve the issue on our own. Below, I have included some pertinent details for your reference:
#
#
# - Product Model: Cisco Router ISR4331
# - Date/Time of Issue: [Please Insert Date/Time]
#
#
# We kindly ask that a technical specialist be assigned to this matter at the earliest possible to assist us in troubleshooting and resolving the problem. Please let us know if further details are required from our end or if we should follow any preliminary steps before your team engages.
#
#
# Thank you very much for your prompt attention to this matter. We look forward to hearing from you soon.
#
#
# Best regards,
#
#
# <name>
# <tel_num>
# <acc_num>
# Index: 316, Subject: Seeking Assistance: Router Leading to Network Disruptions, Body: Dear Customer Support Team,
#
#
# I am contacting you to report a significant problem with our Cisco Router ISR4331. We have been encountering frequent network interruptions in our organization due to regular router resets and sluggish response times. These complications are profoundly affecting our enterprise's communication and operational productivity, hindering our ability to sustain stable network connections.
#
#
# We would sincerely appreciate your swift help in diagnosing and fixing this issue. Kindly inform us about the subsequent steps we should follow to alleviate these disturbances.
#
#
# Thank you for your assistance.
#
#
# Warm regards,
#
#
# <name>
# <tel_num>
# <acc_num>
# Index: 318, Subject: Immediate Support Required: Cisco ISR4331 Router Outage, Body: Dear Customer Support,
#
#
# I trust this message finds you in good health. I am contacting you to inform you of a pressing issue with our Cisco Router ISR4331, which has recently gone offline unexpectedly, greatly affecting our network stability in the office. This unforeseen outage has interrupted our daily business activities, and we urgently seek technical support to address these challenges.
#
#
# The router plays a vital role in our network setup, and any extended outage could obstruct our essential business functions. We have conducted some preliminary diagnostics but were unsuccessful in resolving the problem independently. Here are relevant details for your reference:
#
#
# - Model: Cisco Router ISR4331
# - Time and Date of Issue: [Please Enter Date/Time]
#
#
# We humbly request that a technical expert be assigned to this case at your earliest convenience to aid us in the troubleshooting and resolution process. Please advise if any additional information is required on our part or if there are specific initial steps we should take prior to your team’s intervention.
#
#
# We greatly appreciate your immediate attention to this issue. We look forward to your swift response.
#
#
# Yours sincerely,
#   <name>
#   <tel_num>
#   <acc_num>
# Index: 336, Subject: High Priority: Recurring Network Disruptions, Body: Hello Customer Support Team,
#
#
# Our Cisco Router ISR4331 is facing recurring network disruptions, greatly impacting our office connectivity. We urgently require a resolution and troubleshooting assistance. Please help us in fixing this issue.
#
#
# Thank you,
# <name>

# %%
# prompt: from grouped_tickets_by_body make new dataframe

import pandas as pd

# Assuming 'grouped_tickets_by_body' and 'data_en' are defined from the previous code

clusters = {}  # Initialize an empty dictionary to store clusters

# Iterate through the grouped tickets
for key_index, similar_indices in grouped_tickets_by_body.items():
    # Create a list to store the ticket information for the current cluster
    cluster = []
    # Add the key ticket to the cluster
    cluster.append({
        "index": key_index,
        "subject": data_en['subject'].iloc[key_index],
        "body": data_en['body'].iloc[key_index]
    })
    # Add the similar tickets to the cluster
    for index in similar_indices:
        cluster.append({
            "index": index,
            "subject": data_en['subject'].iloc[index],
            "body": data_en['body'].iloc[index]
        })
    # Add the cluster to the clusters dictionary, using the key ticket index as the key
    clusters[key_index] = cluster

# Create a list to store the rows for the new DataFrame
rows = []
for cluster_key, cluster_data in clusters.items():
    for ticket in cluster_data:
        rows.append({
            'cluster_key': cluster_key,
            'index': ticket['index'],
            'subject': ticket['subject'],
            'body': ticket['body']
        })

# Create the new DataFrame
new_df = pd.DataFrame(rows)

# Save the DataFrame to a CSV file
new_df.to_csv('grouped_tickets.csv', index=False)

# %%
grouped = pd.read_csv("grouped_tickets.csv")

# %%
grouped.head()
# Out:
#    cluster_key  index                                            subject  \
# 0            0      0  Urgent: Critical impact on enterprise network ...
# 1            0     30  Intermittent Connectivity Issues with Cisco Ro...
# 2            0     53                                Urgent Router Issue
# 3            0    100  Frequent Disconnect Issues with Cisco Router I...
# 4            0    105                        Intermittent Network Issues
#
#                                                 body
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support Team,\n\n\nI am writing ...
# 2  Dear Customer Support,\n\n\nI am writing to br...
# 3  To whom it may concern, I am writing to report...
# 4  Dear Customer Support Team,\n\n\nI hope this m...

# %%
# prompt:  from grouped  in text form only get subject gruped with cluster_key

import pandas as pd

# Assuming 'grouped' DataFrame is already loaded as in your provided code
grouped = pd.read_csv("grouped_tickets.csv")

# Extract 'subject' and 'cluster_key' columns
subject_cluster = grouped[['subject', 'cluster_key']]

# Print the result to text form
print(subject_cluster.to_string(index=False))
# Out:
#                                                                     subject  cluster_key
#                  Urgent: Critical impact on enterprise network connectivity            0
#                          Intermittent Connectivity Issues with Cisco Router            0
#                                                         Urgent Router Issue            0
#                        Frequent Disconnect Issues with Cisco Router ISR4331            0
#                                                 Intermittent Network Issues            0
#                                                         Cisco Router Outage            0
#                       Urgent: Connectivity Issues with Cisco Router ISR4331            0
#                          Network Outage Due to Cisco Router ISR4331 Failure            0
#                    Network Connectivity Challenges Occurring Intermittently            0
#                                                   Urgent Cisco Router Issue            0
#                              Critical: Recurring Network Disruption Problem            0
#                                            Network Issues with Cisco Router            0
#                          Urgent: Critical Network Issue with Router ISR4331            0
#                          High Priority Incident: Router Connectivity Issues            0
#                                                Urgent: Cisco ISR4331 Issues            0
#                                                      Urgent: Network Outage            0
#                                                 Network Connectivity Issues            0
#                                                       Company Network Issue            0
#                                        Critical Issue: Network Interruption            0
#                           Requesting Support: Router causing network issues            0
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime            0
#                   Seeking Assistance: Router Leading to Network Disruptions            0
#                     Immediate Support Required: Cisco ISR4331 Router Outage            0
#                                High Priority: Recurring Network Disruptions            0
#                             Exchange Request for Malfunctioning Dell XPS 13            2
#                               Request for Product Exchange - Faulty Battery            2
#                                Request for Server Administration Assistance            3
#                                                       IT Consulting Inquiry            3
#                                          Guidance on IT Consulting Services            3
#                                      Assistance with IT Consultancy Options            3
#                             Assistance Required: Software and Server Issues            3
#                            Request for Expert Consultation on Ticket System            3
#                            Immediate Attention Required: AWS Outage Concern            4
#                                       Urgent: AWS Management Service Issues            4
#                      Urgent: Immediate Resolution Required for AWS Downtime            4
#                                               Urgent AWS Connectivity Issue            4
#                                  Urgent: Issues with AWS Management Service            4
#                         Urgent: Service Outage During Scheduled Maintenance            4
#                         Ticket Raised: AWS Resources Misconfiguration Issue            4
#                                Critical: Significant AWS Service Disruption            4
#                                                       AWS Deployment Issues            4
#                                         Urgent: AWS Management Service Down            4
#                                              Critical: AWS Outage Situation            4
#                                                  Urgent: AWS Downtime Issue            4
#                           Urgent: Resolve AWS Infrastructure Downtime Issue            4
#                                                Urgent AWS Deployment Issues            4
#                                            Urgent Issue with AWS Deployment            4
#                                   Urgent Assistance Required for AWS Issues            4
#                                                    Urgent: Major AWS Outage            4
#                                         Notification of Planned Maintenance            4
#                             Urgent: Critical AWS Service Outage Experienced            4
#                                    Urgent Help Needed: AWS Deployment Issue            4
#                            Urgent Support Required for AWS Issue Resolution            4
#                                                    Urgent Assistance Needed            5
#                                                  Immediate Support Required            5
#                                             Bug Report: UI Bug in React App            6
#                            Alert: User Interface Issue in React Application            6
#                            Urgent: AWS Web Access Issue Resolution Required            7
#                                               Urgent AWS Connectivity Issue            7
#                                   Intermittent Connectivity Issues with AWS            7
#                                       Issues with AWS Resource Optimization            8
#                               Issues with AWS Management Service Deployment            8
#                                           Request for Configuration Changes            8
#                                  Urgent: Issues with AWS Management Service            8
#                   Request for Change in AWS Configurations for Optimization            8
#                          Request for Change in AWS Management Configuration            8
#               Request for Optimization of AWS Cloud Resources and Stability            8
#                                              AWS Management Service Inquiry            8
#                                           Infrastructure Assistance Request            8
#                         Request for Cost-Effective AWS Management Solutions            8
#                             Urgent Assistance Required for AWS Optimization            8
#                Request for Improvements: AWS Infrastructure Settings Update            8
#                                           Cloud Infrastructure Optimization            8
#                                               Critical AWS Cost Enhancement            8
#                          Urgent Request for AWS Infrastructure Optimization            8
#                                            Urgent Issue with AWS Deployment            8
#                                                Critical AWS Cost Management            8
#                                   Urgent Assistance Required for AWS Issues            8
#                            Urgent Support Required for AWS Issue Resolution            8
#                        Inquiry About Economical AWS Management Alternatives            8
#                                               Urgent Request for Assistance           10
#                      Request for Guidance: Optimizing Server Configurations           10
#                                                 Immediate Assistance Needed           10
#                                    Request for Server Configuration Changes           10
#                                                      Urgent Support Inquiry           10
#                                                       Urgent Support Needed           10
#                                      Urgent: Immediate IT Assistance Needed           10
#                                              Immediate Assistance Requested           10
#                                           Assistance Needed for Canon Setup           11
#                                                           Assistance Needed           11
#                                         Assistance Needed for Printer Setup           11
#                Assistance Needed with Wireless Setup for Canon PIXMA MG3620           11
#                                             Printer Settings Update Request           11
#                                                                Need Support           11
#                                                         Request for Support           11
#                                       Urgent: AWS Management Service Issues           12
#                      Urgent: Immediate Resolution Required for AWS Downtime           12
#                               Issues with AWS Management Service Deployment           12
#                         Urgent: Service Outage During Scheduled Maintenance           12
#                         Ticket Raised: AWS Resources Misconfiguration Issue           12
#                                Critical: Significant AWS Service Disruption           12
#                                                       AWS Deployment Issues           12
#                                              Critical: AWS Outage Situation           12
#                                                  Urgent: AWS Downtime Issue           12
#                           Urgent: Resolve AWS Infrastructure Downtime Issue           12
#                                            Urgent Issue with AWS Deployment           12
#                                   Urgent Assistance Required for AWS Issues           12
#                                                    Urgent: Major AWS Outage           12
#                             Urgent: Critical AWS Service Outage Experienced           12
#                                    Urgent Help Needed: AWS Deployment Issue           12
#                            Urgent Support Required for AWS Issue Resolution           12
#                               Urgent Care Needed: Issue with AWS Deployment           13
#                                                Urgent: AWS deployment issue           13
#                                       Critical: Problem with AWS Deployment           13
#                         Urgent Assistance Needed: Issue with AWS Deployment           13
#                       Urgent Assistance Required: Issue with AWS Deployment           13
#                             Assistance Required: Printer Connectivity Issue           15
#                           Request for Setup Assistance with HP DeskJet 3755           15
#                                       Issue with HP DeskJet 3755 Connection           15
#                                           Request to Return HP DeskJet 3755           15
#                                     Help Needed: Printer Connection Problem           15
#                    Urgent: Cisco Router ISR4331 Network Connectivity Issues           16
#                                                         Connectivity Issues           16
#                          Intermittent Connectivity Issues with Cisco Router           16
#                                    Intermittent Network Connectivity Issues           16
#                                                         Urgent Router Issue           16
#                                    Support Request for Cisco Router ISR4331           16
#                                       Connectivity Issues with Cisco Router           16
#                        Frequent Disconnect Issues with Cisco Router ISR4331           16
#                                                 Intermittent Network Issues           16
#                                                         Cisco Router Outage           16
#                                        Urgent: Frequent Network Drops Issue           16
#                       Urgent: Connectivity Issues with Cisco Router ISR4331           16
#                    Network Connectivity Challenges Occurring Intermittently           16
#                                                 Network Configuration Issue           16
#                                                Internet Connectivity Issues           16
#                              Critical: Recurring Network Disruption Problem           16
#                                            Network Issues with Cisco Router           16
#                          Urgent: Critical Network Issue with Router ISR4331           16
#                          High Priority Incident: Router Connectivity Issues           16
#                                     Intermittent Connectivity Issues Report           16
#                                            Issues with Cisco ISR4331 Router           16
#                                                Urgent: Cisco ISR4331 Issues           16
#                                                 Network Connectivity Issues           16
#                           Critical: Recurring Network Disconnection Problem           16
#                                            Issues with Cisco Router ISR4331           16
#                                                       Company Network Issue           16
#                           Requesting Support: Router causing network issues           16
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime           16
#                                                     Immediate Help Required           16
#                   Seeking Assistance: Router Leading to Network Disruptions           16
#                     Immediate Support Required: Cisco ISR4331 Router Outage           16
#                     High Priority: Recurrent Network Disconnections Problem           16
#                                High Priority: Recurring Network Disruptions           16
#                      Urgent: Immediate Resolution Required for AWS Downtime           17
#                                               Urgent AWS Connectivity Issue           17
#                               Issues with AWS Management Service Deployment           17
#                                  Urgent: Issues with AWS Management Service           17
#                         Urgent: Service Outage During Scheduled Maintenance           17
#                         Ticket Raised: AWS Resources Misconfiguration Issue           17
#                                Critical: Significant AWS Service Disruption           17
#                                                       AWS Deployment Issues           17
#                                         Urgent: AWS Management Service Down           17
#                                              Critical: AWS Outage Situation           17
#                                                  Urgent: AWS Downtime Issue           17
#                                   Intermittent Connectivity Issues with AWS           17
#                           Urgent: Resolve AWS Infrastructure Downtime Issue           17
#                          Urgent Request for AWS Infrastructure Optimization           17
#                                                Urgent AWS Deployment Issues           17
#                                            Urgent Issue with AWS Deployment           17
#                                   Urgent Assistance Required for AWS Issues           17
#                                                    Urgent: Major AWS Outage           17
#                                         Notification of Planned Maintenance           17
#                             Urgent: Critical AWS Service Outage Experienced           17
#                                    Urgent Help Needed: AWS Deployment Issue           17
#                            Urgent Support Required for AWS Issue Resolution           17
#                                             Critical AWS Connection Problem           17
#                                               Urgent AWS Connectivity Issue           18
#          High Priority Incident: Immediate AWS Deployment Resolution Needed           18
#                                               Immediate Assistance Required           18
#                                                    Immediate AWS Assistance           18
#                                Critical: Significant AWS Service Disruption           18
#                                                       AWS Deployment Issues           18
#                                                 Urgent AWS Support Required           18
#                                         Urgent: AWS Management Service Down           18
#                                                    Urgent Resolution Needed           18
#                                   Intermittent Connectivity Issues with AWS           18
#                                                Immediate Attention Required           18
#                           Urgent: Resolve AWS Infrastructure Downtime Issue           18
#                                                   Urgent AWS Support Needed           18
#                                                Urgent AWS Deployment Issues           18
#                                                    Urgent: Major AWS Outage           18
#                                    Urgent Help Needed: AWS Deployment Issue           18
#                                             Critical AWS Connection Problem           18
#       Microsoft Surface Pro 7 Touchscreen Issue - Urgent Attention Required           21
#                                Issue with Surface Pro 7 - Screen Flickering           21
#                          Touchscreen and Keyboard Issues with Surface Pro 7           21
#           Immediate Assistance Required: Touchscreen Not Responding Problem           21
#           Immediate Assistance Required: Touchscreen Non-Responsive Problem           21
#                Immediate Support Needed: Touchscreen Non-Responsive Problem           21
#                   Wi-Fi Connectivity Issues with Canon PIXMA MG3620 Printer           22
#                Assistance Needed for Canon PIXMA MG3620 Print Quality Issue           22
#                                         Assistance Needed for Printer Setup           22
#                     Request for Product Exchange Due to Connectivity Issues           22
#                Assistance Needed with Wireless Setup for Canon PIXMA MG3620           22
#                              Issue with Canon PIXMA MG3620 Wi-Fi Connection           22
#                                                       IT Consulting Inquiry           23
#                                                 Immediate Assistance Needed           23
#                                            Inquiry for Professional Support           23
#                                        High Priority Request for Assistance           23
#                                    Request for Server Configuration Changes           23
#                             Assistance Required: Software and Server Issues           23
#                                                  Requesting Expert Guidance           23
#                                                      Urgent Support Inquiry           23
#                                              Immediate Assistance Requested           23
#                                    Urgent Assistance Needed for Zoom Issues           24
#                          Immediate Support Required for Connectivity Issues           24
#                                              Zoom Video Conferencing Issues           24
#                                               Urgent: Zoom Application Down           24
#                                          High Priority: Zoom Service Outage           24
#                            Immediate Resolution Needed: Zoom 5.11.0 Crashes           24
#                                                         Connectivity Issues           25
#                          Intermittent Connectivity Issues with Cisco Router           25
#                                    Intermittent Network Connectivity Issues           25
#                                                         Urgent Router Issue           25
#                                    Support Request for Cisco Router ISR4331           25
#                        Frequent Disconnect Issues with Cisco Router ISR4331           25
#                                                 Intermittent Network Issues           25
#                                                         Cisco Router Outage           25
#                                        Urgent: Frequent Network Drops Issue           25
#                       Urgent: Connectivity Issues with Cisco Router ISR4331           25
#                    Network Connectivity Challenges Occurring Intermittently           25
#                              Critical: Recurring Network Disruption Problem           25
#                                            Network Issues with Cisco Router           25
#                          Urgent: Critical Network Issue with Router ISR4331           25
#                          High Priority Incident: Router Connectivity Issues           25
#                                            Issues with Cisco ISR4331 Router           25
#                                                Urgent: Cisco ISR4331 Issues           25
#                                                 Network Connectivity Issues           25
#                                                       Company Network Issue           25
#                           Requesting Support: Router causing network issues           25
#                                                     Immediate Help Required           25
#                   Seeking Assistance: Router Leading to Network Disruptions           25
#                             Urgent: Dell XPS 13 9310 Laptop Not Powering On           26
#                                          Issue with Dell XPS 13 Powering On           26
#                Assistance Needed for Canon PIXMA MG3620 Print Quality Issue           27
#         Exchange Request for Canon PIXMA MG3620 Due to Print Quality Issues           27
#                     Request for Product Exchange Due to Connectivity Issues           27
#                Assistance Needed with Wireless Setup for Canon PIXMA MG3620           27
#                              Issue with Canon PIXMA MG3620 Wi-Fi Connection           27
#                                         Canon PIXMA MG3620 Exchange Request           27
#                               Issues with AWS Management Service Deployment           29
#          High Priority Incident: Immediate AWS Deployment Resolution Needed           29
#                                  Urgent: Issues with AWS Management Service           29
#                         Urgent: Service Outage During Scheduled Maintenance           29
#                         Ticket Raised: AWS Resources Misconfiguration Issue           29
#               Request for Optimization of AWS Cloud Resources and Stability           29
#                                               Immediate Assistance Required           29
#                                                    Immediate AWS Assistance           29
#                                Critical: Significant AWS Service Disruption           29
#                                                       AWS Deployment Issues           29
#                                                 Urgent AWS Support Required           29
#                                         Urgent: AWS Management Service Down           29
#                                              Critical: AWS Outage Situation           29
#                                                  Urgent: AWS Downtime Issue           29
#                                                    Urgent Resolution Needed           29
#                                   Intermittent Connectivity Issues with AWS           29
#                                                Immediate Attention Required           29
#                           Urgent: Resolve AWS Infrastructure Downtime Issue           29
#                                                   Urgent AWS Support Needed           29
#                          Urgent Request for AWS Infrastructure Optimization           29
#                                                Urgent AWS Deployment Issues           29
#                                                      AWS Performance Issues           29
#                                            Urgent Issue with AWS Deployment           29
#                                   Urgent Assistance Required for AWS Issues           29
#                                                    Urgent: Major AWS Outage           29
#                             Urgent: Critical AWS Service Outage Experienced           29
#                                    Urgent Help Needed: AWS Deployment Issue           29
#                            Urgent Support Required for AWS Issue Resolution           29
#                          Intermittent Connectivity Issues with Cisco Router           30
#                                    Intermittent Network Connectivity Issues           30
#                                                         Urgent Router Issue           30
#                                    Support Request for Cisco Router ISR4331           30
#                                       Connectivity Issues with Cisco Router           30
#                        Frequent Disconnect Issues with Cisco Router ISR4331           30
#                                                 Intermittent Network Issues           30
#                                                         Cisco Router Outage           30
#                                        Urgent: Frequent Network Drops Issue           30
#                       Urgent: Connectivity Issues with Cisco Router ISR4331           30
#                          Network Outage Due to Cisco Router ISR4331 Failure           30
#                    Network Connectivity Challenges Occurring Intermittently           30
#                                                 Network Configuration Issue           30
#                                                Internet Connectivity Issues           30
#                                                   Urgent Cisco Router Issue           30
#                              Critical: Recurring Network Disruption Problem           30
#                                            Network Issues with Cisco Router           30
#                          Urgent: Critical Network Issue with Router ISR4331           30
#                          High Priority Incident: Router Connectivity Issues           30
#                                     Intermittent Connectivity Issues Report           30
#                                            Issues with Cisco ISR4331 Router           30
#                                                Urgent: Cisco ISR4331 Issues           30
#                                                      Urgent: Network Outage           30
#                                                 Network Connectivity Issues           30
#                           Critical: Recurring Network Disconnection Problem           30
#                                            Issues with Cisco Router ISR4331           30
#                                                       Company Network Issue           30
#                                        Critical Issue: Network Interruption           30
#                           Requesting Support: Router causing network issues           30
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime           30
#                                                     Immediate Help Required           30
#                   Seeking Assistance: Router Leading to Network Disruptions           30
#                     Immediate Support Required: Cisco ISR4331 Router Outage           30
#                     High Priority: Recurrent Network Disconnections Problem           30
#                                High Priority: Recurring Network Disruptions           30
#                                           Request for Configuration Changes           32
#                   Request for Change in AWS Configurations for Optimization           32
#                          Request for Change in AWS Management Configuration           32
#               Request for Optimization of AWS Cloud Resources and Stability           32
#                                              AWS Management Service Inquiry           32
#                                           Infrastructure Assistance Request           32
#                         Request for Cost-Effective AWS Management Solutions           32
#                             Urgent Assistance Required for AWS Optimization           32
#                Request for Improvements: AWS Infrastructure Settings Update           32
#                                           Cloud Infrastructure Optimization           32
#                                              Assistance with AWS Management           32
#                          Urgent Request for AWS Infrastructure Optimization           32
#                        Inquiry About Economical AWS Management Alternatives           32
#                                  Urgent Resolution Needed: VS Code Crashing           33
#                  Immediate Assistance Required: Visual Studio Code Crashing           33
#          High Priority Incident: Immediate AWS Deployment Resolution Needed           34
#                                  Urgent: Issues with AWS Management Service           34
#                                               Immediate Assistance Required           34
#                                                    Immediate AWS Assistance           34
#                                Critical: Significant AWS Service Disruption           34
#                                                       AWS Deployment Issues           34
#                                                 Urgent AWS Support Required           34
#                                         Urgent: AWS Management Service Down           34
#                                                    Urgent Resolution Needed           34
#                                                Immediate Attention Required           34
#                           Urgent: Resolve AWS Infrastructure Downtime Issue           34
#                                                   Urgent AWS Support Needed           34
#                                            Urgent Issue with AWS Deployment           34
#                                   Urgent Assistance Required for AWS Issues           34
#                             Urgent: Critical AWS Service Outage Experienced           34
#                                    Urgent Help Needed: AWS Deployment Issue           34
#                                             Critical AWS Connection Problem           34
#                                   Inquiry Regarding Updates on AWS Services           35
#                                             Request for AWS Service Updates           35
#                                                Scheduled Maintenance Notice           36
#                         Urgent: Service Outage During Scheduled Maintenance           36
#                         Ticket Raised: AWS Resources Misconfiguration Issue           36
#                                Critical: Significant AWS Service Disruption           36
#                           Urgent: Resolve AWS Infrastructure Downtime Issue           36
#                                                Urgent AWS Deployment Issues           36
#                                   Urgent Assistance Required for AWS Issues           36
#                                                    Urgent: Major AWS Outage           36
#                                         Notification of Planned Maintenance           36
#                             Urgent: Critical AWS Service Outage Experienced           36
#                            Urgent Support Required for AWS Issue Resolution           36
#                        Missing ticket notifications impacting Jira feedback           37
#                                       Urgent: Jira Ticket System Disruption           37
#                           Request for Setup Assistance with HP DeskJet 3755           38
#                                       Issue with HP DeskJet 3755 Connection           38
#                                           Request to Return HP DeskJet 3755           38
#                                     Help Needed: Printer Connection Problem           38
#                               Urgent Update Required for Jira Software 8.20           39
#                                                     Software Update Request           39
#                                       Urgent: Jira Ticket System Disruption           39
#                                  Urgent: Issues with AWS Management Service           41
#                         Urgent: Service Outage During Scheduled Maintenance           41
#                         Ticket Raised: AWS Resources Misconfiguration Issue           41
#               Request for Optimization of AWS Cloud Resources and Stability           41
#                                               Immediate Assistance Required           41
#                                                    Immediate AWS Assistance           41
#                                Critical: Significant AWS Service Disruption           41
#                                                       AWS Deployment Issues           41
#                                                 Urgent AWS Support Required           41
#                                         Urgent: AWS Management Service Down           41
#                                                  Urgent: AWS Downtime Issue           41
#                                                    Urgent Resolution Needed           41
#                                               Critical AWS Cost Enhancement           41
#                                                Immediate Attention Required           41
#                           Urgent: Resolve AWS Infrastructure Downtime Issue           41
#                                                   Urgent AWS Support Needed           41
#                          Urgent Request for AWS Infrastructure Optimization           41
#                                                Urgent AWS Deployment Issues           41
#                                                      AWS Performance Issues           41
#                                            Urgent Issue with AWS Deployment           41
#                                   Urgent Assistance Required for AWS Issues           41
#                                                    Urgent: Major AWS Outage           41
#                             Urgent: Critical AWS Service Outage Experienced           41
#                                    Urgent Help Needed: AWS Deployment Issue           41
#                            Urgent Support Required for AWS Issue Resolution           41
#                          Inquiry About JavaScript React Development Service           42
#                          Request for Detailed Information on React Services           42
#                        Inquiry About Features and Pricing Options for React           42
#                                    Intermittent Network Connectivity Issues           44
#                                                         Urgent Router Issue           44
#                                    Support Request for Cisco Router ISR4331           44
#                                       Connectivity Issues with Cisco Router           44
#                        Frequent Disconnect Issues with Cisco Router ISR4331           44
#                                                 Intermittent Network Issues           44
#                                                         Cisco Router Outage           44
#                                        Urgent: Frequent Network Drops Issue           44
#                       Urgent: Connectivity Issues with Cisco Router ISR4331           44
#                          Network Outage Due to Cisco Router ISR4331 Failure           44
#                    Network Connectivity Challenges Occurring Intermittently           44
#                                                Internet Connectivity Issues           44
#                                                   Urgent Cisco Router Issue           44
#                              Critical: Recurring Network Disruption Problem           44
#                                            Network Issues with Cisco Router           44
#                          Urgent: Critical Network Issue with Router ISR4331           44
#                          High Priority Incident: Router Connectivity Issues           44
#                                     Intermittent Connectivity Issues Report           44
#                                            Issues with Cisco ISR4331 Router           44
#                                                Urgent: Cisco ISR4331 Issues           44
#                                                      Urgent: Network Outage           44
#                                                 Network Connectivity Issues           44
#                           Critical: Recurring Network Disconnection Problem           44
#                                            Issues with Cisco Router ISR4331           44
#                                                       Company Network Issue           44
#                                        Critical Issue: Network Interruption           44
#                           Requesting Support: Router causing network issues           44
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime           44
#                                                     Immediate Help Required           44
#                   Seeking Assistance: Router Leading to Network Disruptions           44
#                     Immediate Support Required: Cisco ISR4331 Router Outage           44
#                     High Priority: Recurrent Network Disconnections Problem           44
#                                High Priority: Recurring Network Disruptions           44
#                     Urgent: Dell XPS 13 overheating and battery drain issue           45
#                                                     Dell XPS 13 9310 Issues           45
#                                               Dell XPS 13 Overheating Issue           45
#                                    Screen Flickering Issue on Surface Pro 7           46
#                                Issue with Surface Pro 7 - Screen Flickering           46
#                                          Issue with Microsoft Surface Pro 7           46
#               Inquiry: MacBook Air M1 Graphic Design Software Compatibility           47
#                                       Inquiry About MacBook Air M1 Features           47
#                                       Inquiry about Dell XPS 13 9310 issues           48
#                                      Screen Flickering Issue on Dell XPS 13           48
#                                    Screen Flickering Issue with Dell XPS 13           48
#                                Issue with Surface Pro 7 - Screen Flickering           49
#                                   Login Issues with Microsoft Surface Pro 7           49
#                          Touchscreen and Keyboard Issues with Surface Pro 7           49
#                                          Issue with Microsoft Surface Pro 7           49
#           Immediate Assistance Required: Touchscreen Not Responding Problem           49
#           Immediate Assistance Required: Touchscreen Non-Responsive Problem           49
#                Immediate Support Needed: Touchscreen Non-Responsive Problem           49
#                                                         Urgent Router Issue           53
#                                    Support Request for Cisco Router ISR4331           53
#                                       Connectivity Issues with Cisco Router           53
#                        Frequent Disconnect Issues with Cisco Router ISR4331           53
#                                                 Intermittent Network Issues           53
#                                                         Cisco Router Outage           53
#                                        Urgent: Frequent Network Drops Issue           53
#                       Urgent: Connectivity Issues with Cisco Router ISR4331           53
#                          Network Outage Due to Cisco Router ISR4331 Failure           53
#                    Network Connectivity Challenges Occurring Intermittently           53
#                                                 Network Configuration Issue           53
#                                                Internet Connectivity Issues           53
#                                                   Urgent Cisco Router Issue           53
#                              Critical: Recurring Network Disruption Problem           53
#                                            Network Issues with Cisco Router           53
#                          Urgent: Critical Network Issue with Router ISR4331           53
#                                   Malfunctioning Cisco Router ISR4331 Issue           53
#                          High Priority Incident: Router Connectivity Issues           53
#                                     Intermittent Connectivity Issues Report           53
#                                            Issues with Cisco ISR4331 Router           53
#                                                Urgent: Cisco ISR4331 Issues           53
#                                                      Urgent: Network Outage           53
#                                                   Network Instability Issue           53
#                                                 Network Connectivity Issues           53
#                                             Problems with Network Stability           53
#                           Critical: Recurring Network Disconnection Problem           53
#                                            Issues with Cisco Router ISR4331           53
#                                                       Company Network Issue           53
#                                        Critical Issue: Network Interruption           53
#                           Requesting Support: Router causing network issues           53
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime           53
#                                                     Immediate Help Required           53
#                   Seeking Assistance: Router Leading to Network Disruptions           53
#                     Immediate Support Required: Cisco ISR4331 Router Outage           53
#                     High Priority: Recurrent Network Disconnections Problem           53
#                                High Priority: Recurring Network Disruptions           53
#                       Concerns regarding MacBook Air M1 battery performance           54
#                                Inquiry Regarding MacBook Air M1 Performance           54
#                                       Immediate Fix Needed for Jira Crashes           55
#                                                     Software Update Request           55
#                                 Frequent audio issues with Zoom application           57
#                                              Zoom Video Conferencing Issues           57
#                               Urgent: Epson EcoTank ET-4760 Paper Jam Issue           58
#                       Assistance Required for Epson EcoTank ET-4760 Printer           58
#                      Assistance Needed for Epson EcoTank ET-4760 Paper Jams           58
#                  Request for billing details and payment options assistance           60
#                                                Service Charge Clarification           60
#                                         Urgent Server Admin Interface Issue           61
#                                                       High-Priority Problem           61
#                         High Priority Request: Server Administration Issues           61
#                                                     Screen Flickering Issue           63
#                                                    MacBook Air Screen Issue           63
#                                                           Assistance Needed           64
#                                         Assistance Needed for Printer Setup           64
#                Assistance Needed with Wireless Setup for Canon PIXMA MG3620           64
#                                                                Need Support           64
#                                                         Request for Support           64
#                                    Support Request for Cisco Router ISR4331           65
#                                       Connectivity Issues with Cisco Router           65
#                        Frequent Disconnect Issues with Cisco Router ISR4331           65
#                                                 Intermittent Network Issues           65
#                                                         Cisco Router Outage           65
#                                        Urgent: Frequent Network Drops Issue           65
#                       Urgent: Connectivity Issues with Cisco Router ISR4331           65
#                    Network Connectivity Challenges Occurring Intermittently           65
#                                                Internet Connectivity Issues           65
#                              Critical: Recurring Network Disruption Problem           65
#                                            Network Issues with Cisco Router           65
#                          Urgent: Critical Network Issue with Router ISR4331           65
#                          High Priority Incident: Router Connectivity Issues           65
#                                     Intermittent Connectivity Issues Report           65
#                                            Issues with Cisco ISR4331 Router           65
#                                                Urgent: Cisco ISR4331 Issues           65
#                                                 Network Connectivity Issues           65
#                                             Problems with Network Stability           65
#                           Critical: Recurring Network Disconnection Problem           65
#                                            Issues with Cisco Router ISR4331           65
#                                                       Company Network Issue           65
#                           Requesting Support: Router causing network issues           65
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime           65
#                                                     Immediate Help Required           65
#                   Seeking Assistance: Router Leading to Network Disruptions           65
#                     High Priority: Recurrent Network Disconnections Problem           65
#                                High Priority: Recurring Network Disruptions           65
#                                                       High-Priority Problem           66
#                                                                Urgent Issue           66
#                                  Urgent Assistance Needed for Ticket System           66
#                                                       High-Priority Concern           66
#                                                          Critical Situation           66
#                         High Priority Request: Server Administration Issues           66
#                                                               Major Concern           66
# ...
#                            Urgent Support Required for AWS Issue Resolution          253
#                                             Critical AWS Connection Problem          253
#                         High Priority Request: Server Administration Issues          255
#                        Immediate Assistance Needed to Resolve Server Outage          255
#                           Immediate Assistance Required for Server Downtime          255
#                              Urgent Support Required to Fix Server Downtime          255
#                                          Critical Server Management Problem          255
#                  Immediate Assistance Needed: Issues with Server Management          255
#                                              Immediate Assistance Requested          255
#                                            Issues with Cisco Router ISR4331          256
#                                                       Company Network Issue          256
#                     High Priority: Recurrent Network Disconnections Problem          256
#                                High Priority: Recurring Network Disruptions          256
#                             Urgent IT consulting required for server issues          258
#                                                    Issue with Ticket System          258
#                                                   Urgent AWS Support Needed          259
#                          Urgent Request for AWS Infrastructure Optimization          259
#                                                Urgent AWS Deployment Issues          259
#                                            Urgent Issue with AWS Deployment          259
#                                   Urgent Assistance Required for AWS Issues          259
#                                                    Urgent: Major AWS Outage          259
#                             Urgent: Critical AWS Service Outage Experienced          259
#                                    Urgent Help Needed: AWS Deployment Issue          259
#                            Urgent Support Required for AWS Issue Resolution          259
#                                             Critical AWS Connection Problem          259
#                                              Issue with AWS Billing Charges          261
#                                                       Billing Discrepancies          261
#                                                   Billing Discrepancy Issue          261
#                                  Investigation into AWS Billing Discrepancy          261
#                                        Billing Discrepancy with AWS Service          261
#                                   Billing Issue with AWS Management Service          261
#                                                 Request for Billing Support          261
#                          Urgent Request for AWS Infrastructure Optimization          263
#                                                Urgent AWS Deployment Issues          263
#                                            Urgent Issue with AWS Deployment          263
#                                   Urgent Assistance Required for AWS Issues          263
#                                                    Urgent: Major AWS Outage          263
#                             Urgent: Critical AWS Service Outage Experienced          263
#                                    Urgent Help Needed: AWS Deployment Issue          263
#                            Urgent Support Required for AWS Issue Resolution          263
#                        Inquiry About Economical AWS Management Alternatives          263
#                                                Urgent AWS Deployment Issues          270
#                                            Urgent Issue with AWS Deployment          270
#                                   Urgent Assistance Required for AWS Issues          270
#                                                    Urgent: Major AWS Outage          270
#                                         Notification of Planned Maintenance          270
#                             Urgent: Critical AWS Service Outage Experienced          270
#                                    Urgent Help Needed: AWS Deployment Issue          270
#                            Urgent Support Required for AWS Issue Resolution          270
#                                             Critical AWS Connection Problem          270
#                                                       Company Network Issue          273
#                                        Critical Issue: Network Interruption          273
#                           Requesting Support: Router causing network issues          273
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime          273
#                                           Problems with Network Reliability          273
#                                                     Immediate Help Required          273
#                   Seeking Assistance: Router Leading to Network Disruptions          273
#                     Immediate Support Required: Cisco ISR4331 Router Outage          273
#                     High Priority: Recurrent Network Disconnections Problem          273
#                                High Priority: Recurring Network Disruptions          273
#                                                      AWS Performance Issues          274
#                                            Urgent Issue with AWS Deployment          274
#                                   Urgent Assistance Required for AWS Issues          274
#                             Urgent: Critical AWS Service Outage Experienced          274
#                                    Urgent Help Needed: AWS Deployment Issue          274
#                            Urgent Support Required for AWS Issue Resolution          274
#                        Immediate Assistance Needed to Resolve Server Outage          276
#                           Immediate Assistance Required for Server Downtime          276
#                              Urgent Support Required to Fix Server Downtime          276
#                                          Critical Server Management Problem          276
#                  Immediate Assistance Needed: Issues with Server Management          276
#                                            Urgent Issue with AWS Deployment          277
#                                   Urgent Assistance Required for AWS Issues          277
#                                                    Urgent: Major AWS Outage          277
#                             Urgent: Critical AWS Service Outage Experienced          277
#                                    Urgent Help Needed: AWS Deployment Issue          277
#                            Urgent Support Required for AWS Issue Resolution          277
#                                                       Billing Discrepancies          278
#                                                   Billing Discrepancy Issue          278
#                                  Investigation into AWS Billing Discrepancy          278
#                                        Billing Discrepancy with AWS Service          278
#                                   Billing Issue with AWS Management Service          278
#                                                 Request for Billing Support          278
#                                        Critical Issue: Network Interruption          279
#                           Requesting Support: Router causing network issues          279
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime          279
#                                                     Immediate Help Required          279
#                   Seeking Assistance: Router Leading to Network Disruptions          279
#                     Immediate Support Required: Cisco ISR4331 Router Outage          279
#                                High Priority: Recurring Network Disruptions          279
#                                                   Billing Discrepancy Issue          285
#                                  Investigation into AWS Billing Discrepancy          285
#                                        Billing Discrepancy with AWS Service          285
#                                   Billing Issue with AWS Management Service          285
#                                                 Request for Billing Support          285
#                           Requesting Support: Router causing network issues          286
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime          286
#                                                     Immediate Help Required          286
#                   Seeking Assistance: Router Leading to Network Disruptions          286
#                     Immediate Support Required: Cisco ISR4331 Router Outage          286
#                     High Priority: Recurrent Network Disconnections Problem          286
#                                High Priority: Recurring Network Disruptions          286
#                                  Investigation into AWS Billing Discrepancy          287
#                                        Billing Discrepancy with AWS Service          287
#                                   Billing Issue with AWS Management Service          287
#                                                 Request for Billing Support          287
#                                       Assistance Required for Printer Setup          288
#                                             Help with Printer Configuration          288
#                            Request for Expert Consultation on Ticket System          289
#                                          Request for IT Consulting Services          289
#                                               Urgent: Zoom Application Down          291
#                                          High Priority: Zoom Service Outage          291
#                            Immediate Resolution Needed: Zoom 5.11.0 Crashes          291
#                           Immediate Assistance Required for Server Downtime          292
#                              Urgent Support Required to Fix Server Downtime          292
#                                          Critical Server Management Problem          292
#                  Immediate Assistance Needed: Issues with Server Management          292
#                              Urgent Support Required to Fix Server Downtime          296
#                                          Critical Server Management Problem          296
#                  Immediate Assistance Needed: Issues with Server Management          296
#                                   Urgent Assistance Required for AWS Issues          298
#                                                    Urgent: Major AWS Outage          298
#                                         Notification of Planned Maintenance          298
#                             Urgent: Critical AWS Service Outage Experienced          298
#                                    Urgent Help Needed: AWS Deployment Issue          298
#                            Urgent Support Required for AWS Issue Resolution          298
#           Immediate Assistance Required: Touchscreen Non-Responsive Problem          299
#                Immediate Support Needed: Touchscreen Non-Responsive Problem          299
#                                                    Urgent: Major AWS Outage          300
#                                         Notification of Planned Maintenance          300
#                             Urgent: Critical AWS Service Outage Experienced          300
#                                    Urgent Help Needed: AWS Deployment Issue          300
#                            Urgent Support Required for AWS Issue Resolution          300
#                                             Critical AWS Connection Problem          300
#                            Urgent Assistance Needed: Cisco ISR4331 Downtime          301
#                                                     Immediate Help Required          301
#                   Seeking Assistance: Router Leading to Network Disruptions          301
#                     Immediate Support Required: Cisco ISR4331 Router Outage          301
#                     High Priority: Recurrent Network Disconnections Problem          301
#                                High Priority: Recurring Network Disruptions          301
#                                         Notification of Planned Maintenance          302
#                             Urgent: Critical AWS Service Outage Experienced          302
#                                    Urgent Help Needed: AWS Deployment Issue          302
#                            Urgent Support Required for AWS Issue Resolution          302
#                         Urgent Assistance Needed: Issue with AWS Deployment          304
#                       Urgent Assistance Required: Issue with AWS Deployment          304
#                                        Billing Discrepancy with AWS Service          307
#                                   Billing Issue with AWS Management Service          307
#                                                 Request for Billing Support          307
#                                                               Major Concern          310
#                                                            Critical Problem          310
#                                                            Critical Concern          310
#                             Urgent: Critical AWS Service Outage Experienced          313
#                                    Urgent Help Needed: AWS Deployment Issue          313
#                            Urgent Support Required for AWS Issue Resolution          313
#                                                     Immediate Help Required          315
#                   Seeking Assistance: Router Leading to Network Disruptions          315
#                     Immediate Support Required: Cisco ISR4331 Router Outage          315
#                     High Priority: Recurrent Network Disconnections Problem          315
#                                High Priority: Recurring Network Disruptions          315
#                   Seeking Assistance: Router Leading to Network Disruptions          316
#                     Immediate Support Required: Cisco ISR4331 Router Outage          316
#                     High Priority: Recurrent Network Disconnections Problem          316
#                                High Priority: Recurring Network Disruptions          316
#                                   Billing Issue with AWS Management Service          317
#                                                 Request for Billing Support          317
#                     Immediate Support Required: Cisco ISR4331 Router Outage          318
#                     High Priority: Recurrent Network Disconnections Problem          318
#                                High Priority: Recurring Network Disruptions          318
#                                    Urgent Help Needed: AWS Deployment Issue          322
#                            Urgent Support Required for AWS Issue Resolution          322
#                            Urgent Support Required for AWS Issue Resolution          323
#                        Inquiry About Economical AWS Management Alternatives          323
#                                                                Need Support          324
#                                                         Request for Support          324
#                     High Priority: Recurrent Network Disconnections Problem          327
#                                High Priority: Recurring Network Disruptions          327
#                                                            Critical Problem          329
#                                                            Critical Concern          329

# %% [markdown]
# match the nouns with body text

# %%
import pandas as pd
import re

# Load the CSV file
file_path = '/content/grouped_tickets.csv'
data = pd.read_csv(file_path)

# List of nouns to match
nouns = [
    "AWS Deployment", "Dell XPS", "Canon PIXMA MG3620 Printer", "AWS Management Service Deployment",
    "Cisco Router", "HP DeskJet", "AWS Management Service", "Surface Pro", "MacBook Air M1",
    "Adobe Photoshop", "Zoom application", "Wireless Printing", "Cisco Router ISR4331",
    "Microsoft Surface Pro", "IT Consultancy Options", "Slack Channel Integration",
    "Wireless Setup", "Printer Setup", "Jira Software", "Server Outage", "PostgreSQL Database",
    "MySQL 8.0.30 Database", "AWS Management", "AWS", "AWS Billing Charges", "Office",
    "Ticket System", "IntelliJ IDEA", "Network Stability", "Network Reliability",
    "Server Management", "Printer Configuration"
]

# Compile the list of nouns into a regex pattern
pattern = re.compile(r'|'.join(map(re.escape, nouns)))

# Function to find matches in the body column
def find_matches(text):
    if isinstance(text, str):  # Ensure the text is a string
        return ', '.join(pattern.findall(text))  # Join matches as a single string
    return ""

# Apply the function to the 'body' column
data['matched_nouns'] = data['body'].apply(find_matches)

# Save the updated DataFrame with the new column
output_path = '/content/grouped_tickets_with_matched_nouns.csv'
data.to_csv(output_path, index=False)

# Display a confirmation message and the first few rows of the updated DataFrame
print(f"Updated DataFrame with matched nouns saved to {output_path}")
print(data.head())
# Out:
# Updated DataFrame with matched nouns saved to /content/grouped_tickets_with_matched_nouns.csv
#    cluster_key  index                                            subject  \
# 0            0      0  Urgent: Critical impact on enterprise network ...
# 1            0     30  Intermittent Connectivity Issues with Cisco Ro...
# 2            0     53                                Urgent Router Issue
# 3            0    100  Frequent Disconnect Issues with Cisco Router I...
# 4            0    105                        Intermittent Network Issues
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support Team,\n\n\nI am writing ...
# 2  Dear Customer Support,\n\n\nI am writing to br...
# 3  To whom it may concern, I am writing to report...
# 4  Dear Customer Support Team,\n\n\nI hope this m...
#
#                 matched_nouns
# 0                Cisco Router
# 1                Cisco Router
# 2                Cisco Router
# 3                Cisco Router
# 4  Cisco Router, Cisco Router

# %%
import pandas as pd

# Load
df = pd.read_csv('/content/grouped_tickets_with_matched_nouns.csv')
df = df.rename(columns={'matched_nouns': 'product_tag'})
df = df[['cluster_key', 'subject', 'product_tag']]
print(df.to_string(index=False))
# Out:
#  cluster_key                                                                     subject                                                     product_tag
#            0                  Urgent: Critical impact on enterprise network connectivity                                                    Cisco Router
#            0                          Intermittent Connectivity Issues with Cisco Router                                                    Cisco Router
#            0                                                         Urgent Router Issue                                                    Cisco Router
#            0                        Frequent Disconnect Issues with Cisco Router ISR4331                                                    Cisco Router
#            0                                                 Intermittent Network Issues                                      Cisco Router, Cisco Router
#            0                                                         Cisco Router Outage                                                    Cisco Router
#            0                       Urgent: Connectivity Issues with Cisco Router ISR4331                                                    Cisco Router
#            0                          Network Outage Due to Cisco Router ISR4331 Failure                                                    Cisco Router
#            0                    Network Connectivity Challenges Occurring Intermittently                                      Cisco Router, Cisco Router
#            0                                                   Urgent Cisco Router Issue                                                    Cisco Router
#            0                              Critical: Recurring Network Disruption Problem                                                    Cisco Router
#            0                                            Network Issues with Cisco Router                                                    Cisco Router
#            0                          Urgent: Critical Network Issue with Router ISR4331                                                    Cisco Router
#            0                          High Priority Incident: Router Connectivity Issues                                                    Cisco Router
#            0                                                Urgent: Cisco ISR4331 Issues                                                    Cisco Router
#            0                                                      Urgent: Network Outage                                      Cisco Router, Cisco Router
#            0                                                 Network Connectivity Issues                                                    Cisco Router
#            0                                                       Company Network Issue                                                    Cisco Router
#            0                                        Critical Issue: Network Interruption                                      Cisco Router, Cisco Router
#            0                           Requesting Support: Router causing network issues                                                    Cisco Router
#            0                            Urgent Assistance Needed: Cisco ISR4331 Downtime                                      Cisco Router, Cisco Router
#            0                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#            0                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#            0                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#            2                             Exchange Request for Malfunctioning Dell XPS 13                                                        Dell XPS
#            2                               Request for Product Exchange - Faulty Battery                                                        Dell XPS
#            3                                Request for Server Administration Assistance                                                             NaN
#            3                                                       IT Consulting Inquiry                                                             NaN
#            3                                          Guidance on IT Consulting Services                                                             NaN
#            3                                      Assistance with IT Consultancy Options                                                             NaN
#            3                             Assistance Required: Software and Server Issues                                                             NaN
#            3                            Request for Expert Consultation on Ticket System                                                             NaN
#            4                            Immediate Attention Required: AWS Outage Concern                                     AWS Management Service, AWS
#            4                                       Urgent: AWS Management Service Issues                                     AWS Management Service, AWS
#            4                      Urgent: Immediate Resolution Required for AWS Downtime                                AWS, AWS Management Service, AWS
#            4                                               Urgent AWS Connectivity Issue                                          AWS Management Service
#            4                                  Urgent: Issues with AWS Management Service                                          AWS Management Service
#            4                         Urgent: Service Outage During Scheduled Maintenance                                     AWS, AWS Management Service
#            4                         Ticket Raised: AWS Resources Misconfiguration Issue                                     AWS, AWS Management Service
#            4                                Critical: Significant AWS Service Disruption                                     AWS, AWS Management Service
#            4                                                       AWS Deployment Issues                                     AWS Management Service, AWS
#            4                                         Urgent: AWS Management Service Down                                          AWS Management Service
#            4                                              Critical: AWS Outage Situation                                     AWS Management Service, AWS
#            4                                                  Urgent: AWS Downtime Issue                                     AWS Management Service, AWS
#            4                           Urgent: Resolve AWS Infrastructure Downtime Issue                                          AWS Management Service
#            4                                                Urgent AWS Deployment Issues                                          AWS Management Service
#            4                                            Urgent Issue with AWS Deployment                                     AWS, AWS Management Service
#            4                                   Urgent Assistance Required for AWS Issues                                          AWS Management Service
#            4                                                    Urgent: Major AWS Outage                                     AWS, AWS Management Service
#            4                                         Notification of Planned Maintenance                                          AWS Management Service
#            4                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#            4                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#            4                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#            5                                                    Urgent Assistance Needed                                                          Office
#            5                                                  Immediate Support Required                                                          Office
#            6                                             Bug Report: UI Bug in React App                                                             NaN
#            6                            Alert: User Interface Issue in React Application                                                             NaN
#            7                            Urgent: AWS Web Access Issue Resolution Required                                     AWS, AWS Management Service
#            7                                               Urgent AWS Connectivity Issue                                          AWS Management Service
#            7                                   Intermittent Connectivity Issues with AWS                                     AWS, AWS Management Service
#            8                                       Issues with AWS Resource Optimization                                AWS, AWS Management Service, AWS
#            8                               Issues with AWS Management Service Deployment                                          AWS Management Service
#            8                                           Request for Configuration Changes                                          AWS Management Service
#            8                                  Urgent: Issues with AWS Management Service                                          AWS Management Service
#            8                   Request for Change in AWS Configurations for Optimization                                     AWS, AWS Management Service
#            8                          Request for Change in AWS Management Configuration                                          AWS Management Service
#            8               Request for Optimization of AWS Cloud Resources and Stability                                          AWS Management Service
#            8                                              AWS Management Service Inquiry        AWS Management Service, AWS, AWS, AWS Management Service
#            8                                           Infrastructure Assistance Request                                          AWS Management Service
#            8                         Request for Cost-Effective AWS Management Solutions             AWS Management Service, AWS Management Service, AWS
#            8                             Urgent Assistance Required for AWS Optimization                                     AWS, AWS Management Service
#            8                Request for Improvements: AWS Infrastructure Settings Update                                     AWS, AWS Management Service
#            8                                           Cloud Infrastructure Optimization        AWS Management Service, AWS, AWS, AWS Management Service
#            8                                               Critical AWS Cost Enhancement                                     AWS, AWS Management Service
#            8                          Urgent Request for AWS Infrastructure Optimization                                AWS, AWS Management Service, AWS
#            8                                            Urgent Issue with AWS Deployment                                     AWS, AWS Management Service
#            8                                                Critical AWS Cost Management                                     AWS, AWS Management Service
#            8                                   Urgent Assistance Required for AWS Issues                                          AWS Management Service
#            8                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#            8                        Inquiry About Economical AWS Management Alternatives             AWS Management Service, AWS Management Service, AWS
#           10                                               Urgent Request for Assistance                                                             NaN
#           10                      Request for Guidance: Optimizing Server Configurations                                                             NaN
#           10                                                 Immediate Assistance Needed                                                             NaN
#           10                                    Request for Server Configuration Changes                                                             NaN
#           10                                                      Urgent Support Inquiry                                                             NaN
#           10                                                       Urgent Support Needed                                                             NaN
#           10                                      Urgent: Immediate IT Assistance Needed                                                             NaN
#           10                                              Immediate Assistance Requested                                                             NaN
#           11                                           Assistance Needed for Canon Setup                                                             NaN
#           11                                                           Assistance Needed                                                             NaN
#           11                                         Assistance Needed for Printer Setup                                                             NaN
#           11                Assistance Needed with Wireless Setup for Canon PIXMA MG3620                                                             NaN
#           11                                             Printer Settings Update Request                                                             NaN
#           11                                                                Need Support                                                             NaN
#           11                                                         Request for Support                                                             NaN
#           12                                       Urgent: AWS Management Service Issues                                     AWS Management Service, AWS
#           12                      Urgent: Immediate Resolution Required for AWS Downtime                                AWS, AWS Management Service, AWS
#           12                               Issues with AWS Management Service Deployment                                          AWS Management Service
#           12                         Urgent: Service Outage During Scheduled Maintenance                                     AWS, AWS Management Service
#           12                         Ticket Raised: AWS Resources Misconfiguration Issue                                     AWS, AWS Management Service
#           12                                Critical: Significant AWS Service Disruption                                     AWS, AWS Management Service
#           12                                                       AWS Deployment Issues                                     AWS Management Service, AWS
#           12                                              Critical: AWS Outage Situation                                     AWS Management Service, AWS
#           12                                                  Urgent: AWS Downtime Issue                                     AWS Management Service, AWS
#           12                           Urgent: Resolve AWS Infrastructure Downtime Issue                                          AWS Management Service
#           12                                            Urgent Issue with AWS Deployment                                     AWS, AWS Management Service
#           12                                   Urgent Assistance Required for AWS Issues                                          AWS Management Service
#           12                                                    Urgent: Major AWS Outage                                     AWS, AWS Management Service
#           12                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#           12                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#           12                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#           13                               Urgent Care Needed: Issue with AWS Deployment                                                             AWS
#           13                                                Urgent: AWS deployment issue                                                             AWS
#           13                                       Critical: Problem with AWS Deployment                                                             AWS
#           13                         Urgent Assistance Needed: Issue with AWS Deployment                                                             AWS
#           13                       Urgent Assistance Required: Issue with AWS Deployment                                                             AWS
#           15                             Assistance Required: Printer Connectivity Issue                                                      HP DeskJet
#           15                           Request for Setup Assistance with HP DeskJet 3755                                                      HP DeskJet
#           15                                       Issue with HP DeskJet 3755 Connection                                                      HP DeskJet
#           15                                           Request to Return HP DeskJet 3755                                                      HP DeskJet
#           15                                     Help Needed: Printer Connection Problem                                                      HP DeskJet
#           16                    Urgent: Cisco Router ISR4331 Network Connectivity Issues                                                    Cisco Router
#           16                                                         Connectivity Issues                                                    Cisco Router
#           16                          Intermittent Connectivity Issues with Cisco Router                                                    Cisco Router
#           16                                    Intermittent Network Connectivity Issues                                                    Cisco Router
#           16                                                         Urgent Router Issue                                                    Cisco Router
#           16                                    Support Request for Cisco Router ISR4331                                                    Cisco Router
#           16                                       Connectivity Issues with Cisco Router                                                    Cisco Router
#           16                        Frequent Disconnect Issues with Cisco Router ISR4331                                                    Cisco Router
#           16                                                 Intermittent Network Issues                                      Cisco Router, Cisco Router
#           16                                                         Cisco Router Outage                                                    Cisco Router
#           16                                        Urgent: Frequent Network Drops Issue                                                    Cisco Router
#           16                       Urgent: Connectivity Issues with Cisco Router ISR4331                                                    Cisco Router
#           16                    Network Connectivity Challenges Occurring Intermittently                                      Cisco Router, Cisco Router
#           16                                                 Network Configuration Issue                                                    Cisco Router
#           16                                                Internet Connectivity Issues                                                    Cisco Router
#           16                              Critical: Recurring Network Disruption Problem                                                    Cisco Router
#           16                                            Network Issues with Cisco Router                                                    Cisco Router
#           16                          Urgent: Critical Network Issue with Router ISR4331                                                    Cisco Router
#           16                          High Priority Incident: Router Connectivity Issues                                                    Cisco Router
#           16                                     Intermittent Connectivity Issues Report                                                    Cisco Router
#           16                                            Issues with Cisco ISR4331 Router                                                    Cisco Router
#           16                                                Urgent: Cisco ISR4331 Issues                                                    Cisco Router
#           16                                                 Network Connectivity Issues                                                    Cisco Router
#           16                           Critical: Recurring Network Disconnection Problem                                                    Cisco Router
#           16                                            Issues with Cisco Router ISR4331                                                    Cisco Router
#           16                                                       Company Network Issue                                                    Cisco Router
#           16                           Requesting Support: Router causing network issues                                                    Cisco Router
#           16                            Urgent Assistance Needed: Cisco ISR4331 Downtime                                      Cisco Router, Cisco Router
#           16                                                     Immediate Help Required                                                    Cisco Router
#           16                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#           16                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#           16                     High Priority: Recurrent Network Disconnections Problem                                                    Cisco Router
#           16                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#           17                      Urgent: Immediate Resolution Required for AWS Downtime                                AWS, AWS Management Service, AWS
#           17                                               Urgent AWS Connectivity Issue                                          AWS Management Service
#           17                               Issues with AWS Management Service Deployment                                          AWS Management Service
#           17                                  Urgent: Issues with AWS Management Service                                          AWS Management Service
#           17                         Urgent: Service Outage During Scheduled Maintenance                                     AWS, AWS Management Service
#           17                         Ticket Raised: AWS Resources Misconfiguration Issue                                     AWS, AWS Management Service
#           17                                Critical: Significant AWS Service Disruption                                     AWS, AWS Management Service
#           17                                                       AWS Deployment Issues                                     AWS Management Service, AWS
#           17                                         Urgent: AWS Management Service Down                                          AWS Management Service
#           17                                              Critical: AWS Outage Situation                                     AWS Management Service, AWS
#           17                                                  Urgent: AWS Downtime Issue                                     AWS Management Service, AWS
#           17                                   Intermittent Connectivity Issues with AWS                                     AWS, AWS Management Service
#           17                           Urgent: Resolve AWS Infrastructure Downtime Issue                                          AWS Management Service
#           17                          Urgent Request for AWS Infrastructure Optimization                                AWS, AWS Management Service, AWS
#           17                                                Urgent AWS Deployment Issues                                          AWS Management Service
#           17                                            Urgent Issue with AWS Deployment                                     AWS, AWS Management Service
#           17                                   Urgent Assistance Required for AWS Issues                                          AWS Management Service
#           17                                                    Urgent: Major AWS Outage                                     AWS, AWS Management Service
#           17                                         Notification of Planned Maintenance                                          AWS Management Service
#           17                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#           17                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#           17                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#           17                                             Critical AWS Connection Problem                                          AWS Management Service
#           18                                               Urgent AWS Connectivity Issue                                          AWS Management Service
#           18          High Priority Incident: Immediate AWS Deployment Resolution Needed                                          AWS Management Service
#           18                                               Immediate Assistance Required                                          AWS Management Service
#           18                                                    Immediate AWS Assistance                                     AWS, AWS Management Service
#           18                                Critical: Significant AWS Service Disruption                                     AWS, AWS Management Service
#           18                                                       AWS Deployment Issues                                     AWS Management Service, AWS
#           18                                                 Urgent AWS Support Required                                     AWS, AWS Management Service
#           18                                         Urgent: AWS Management Service Down                                          AWS Management Service
#           18                                                    Urgent Resolution Needed                                          AWS Management Service
#           18                                   Intermittent Connectivity Issues with AWS                                     AWS, AWS Management Service
#           18                                                Immediate Attention Required                                          AWS Management Service
#           18                           Urgent: Resolve AWS Infrastructure Downtime Issue                                          AWS Management Service
#           18                                                   Urgent AWS Support Needed                                     AWS, AWS Management Service
#           18                                                Urgent AWS Deployment Issues                                          AWS Management Service
#           18                                                    Urgent: Major AWS Outage                                     AWS, AWS Management Service
#           18                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#           18                                             Critical AWS Connection Problem                                          AWS Management Service
#           21       Microsoft Surface Pro 7 Touchscreen Issue - Urgent Attention Required                    Microsoft Surface Pro, Microsoft Surface Pro
#           21                                Issue with Surface Pro 7 - Screen Flickering                                           Microsoft Surface Pro
#           21                          Touchscreen and Keyboard Issues with Surface Pro 7                                           Microsoft Surface Pro
#           21           Immediate Assistance Required: Touchscreen Not Responding Problem                                           Microsoft Surface Pro
#           21           Immediate Assistance Required: Touchscreen Non-Responsive Problem                                           Microsoft Surface Pro
#           21                Immediate Support Needed: Touchscreen Non-Responsive Problem                                           Microsoft Surface Pro
#           22                   Wi-Fi Connectivity Issues with Canon PIXMA MG3620 Printer                                                             NaN
#           22                Assistance Needed for Canon PIXMA MG3620 Print Quality Issue                                                             NaN
#           22                                         Assistance Needed for Printer Setup                                                             NaN
#           22                     Request for Product Exchange Due to Connectivity Issues                                                             NaN
#           22                Assistance Needed with Wireless Setup for Canon PIXMA MG3620                                                             NaN
#           22                              Issue with Canon PIXMA MG3620 Wi-Fi Connection                                                             NaN
#           23                                                       IT Consulting Inquiry                                                             NaN
#           23                                                 Immediate Assistance Needed                                                             NaN
#           23                                            Inquiry for Professional Support                                                             NaN
#           23                                        High Priority Request for Assistance                                                             NaN
#           23                                    Request for Server Configuration Changes                                                             NaN
#           23                             Assistance Required: Software and Server Issues                                                             NaN
#           23                                                  Requesting Expert Guidance                                                             NaN
#           23                                                      Urgent Support Inquiry                                                             NaN
#           23                                              Immediate Assistance Requested                                                             NaN
#           24                                    Urgent Assistance Needed for Zoom Issues                                                Zoom application
#           24                          Immediate Support Required for Connectivity Issues                                                             NaN
#           24                                              Zoom Video Conferencing Issues                                                             NaN
#           24                                               Urgent: Zoom Application Down                                                Zoom application
#           24                                          High Priority: Zoom Service Outage                                                Zoom application
#           24                            Immediate Resolution Needed: Zoom 5.11.0 Crashes                                                             NaN
#           25                                                         Connectivity Issues                                                    Cisco Router
#           25                          Intermittent Connectivity Issues with Cisco Router                                                    Cisco Router
#           25                                    Intermittent Network Connectivity Issues                                                    Cisco Router
#           25                                                         Urgent Router Issue                                                    Cisco Router
#           25                                    Support Request for Cisco Router ISR4331                                                    Cisco Router
#           25                        Frequent Disconnect Issues with Cisco Router ISR4331                                                    Cisco Router
#           25                                                 Intermittent Network Issues                                      Cisco Router, Cisco Router
#           25                                                         Cisco Router Outage                                                    Cisco Router
#           25                                        Urgent: Frequent Network Drops Issue                                                    Cisco Router
#           25                       Urgent: Connectivity Issues with Cisco Router ISR4331                                                    Cisco Router
#           25                    Network Connectivity Challenges Occurring Intermittently                                      Cisco Router, Cisco Router
#           25                              Critical: Recurring Network Disruption Problem                                                    Cisco Router
#           25                                            Network Issues with Cisco Router                                                    Cisco Router
#           25                          Urgent: Critical Network Issue with Router ISR4331                                                    Cisco Router
#           25                          High Priority Incident: Router Connectivity Issues                                                    Cisco Router
#           25                                            Issues with Cisco ISR4331 Router                                                    Cisco Router
#           25                                                Urgent: Cisco ISR4331 Issues                                                    Cisco Router
#           25                                                 Network Connectivity Issues                                                    Cisco Router
#           25                                                       Company Network Issue                                                    Cisco Router
#           25                           Requesting Support: Router causing network issues                                                    Cisco Router
#           25                                                     Immediate Help Required                                                    Cisco Router
#           25                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#           26                             Urgent: Dell XPS 13 9310 Laptop Not Powering On                                                        Dell XPS
#           26                                          Issue with Dell XPS 13 Powering On                                                        Dell XPS
#           27                Assistance Needed for Canon PIXMA MG3620 Print Quality Issue                                                             NaN
#           27         Exchange Request for Canon PIXMA MG3620 Due to Print Quality Issues                                                             NaN
#           27                     Request for Product Exchange Due to Connectivity Issues                                                             NaN
#           27                Assistance Needed with Wireless Setup for Canon PIXMA MG3620                                                             NaN
#           27                              Issue with Canon PIXMA MG3620 Wi-Fi Connection                                                             NaN
#           27                                         Canon PIXMA MG3620 Exchange Request                                                             NaN
#           29                               Issues with AWS Management Service Deployment                                          AWS Management Service
#           29          High Priority Incident: Immediate AWS Deployment Resolution Needed                                          AWS Management Service
#           29                                  Urgent: Issues with AWS Management Service                                          AWS Management Service
#           29                         Urgent: Service Outage During Scheduled Maintenance                                     AWS, AWS Management Service
#           29                         Ticket Raised: AWS Resources Misconfiguration Issue                                     AWS, AWS Management Service
#           29               Request for Optimization of AWS Cloud Resources and Stability                                          AWS Management Service
#           29                                               Immediate Assistance Required                                          AWS Management Service
#           29                                                    Immediate AWS Assistance                                     AWS, AWS Management Service
#           29                                Critical: Significant AWS Service Disruption                                     AWS, AWS Management Service
#           29                                                       AWS Deployment Issues                                     AWS Management Service, AWS
#           29                                                 Urgent AWS Support Required                                     AWS, AWS Management Service
#           29                                         Urgent: AWS Management Service Down                                          AWS Management Service
#           29                                              Critical: AWS Outage Situation                                     AWS Management Service, AWS
#           29                                                  Urgent: AWS Downtime Issue                                     AWS Management Service, AWS
#           29                                                    Urgent Resolution Needed                                          AWS Management Service
#           29                                   Intermittent Connectivity Issues with AWS                                     AWS, AWS Management Service
#           29                                                Immediate Attention Required                                          AWS Management Service
#           29                           Urgent: Resolve AWS Infrastructure Downtime Issue                                          AWS Management Service
#           29                                                   Urgent AWS Support Needed                                     AWS, AWS Management Service
#           29                          Urgent Request for AWS Infrastructure Optimization                                AWS, AWS Management Service, AWS
#           29                                                Urgent AWS Deployment Issues                                          AWS Management Service
#           29                                                      AWS Performance Issues                  AWS Management Service, AWS Management Service
#           29                                            Urgent Issue with AWS Deployment                                     AWS, AWS Management Service
#           29                                   Urgent Assistance Required for AWS Issues                                          AWS Management Service
#           29                                                    Urgent: Major AWS Outage                                     AWS, AWS Management Service
#           29                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#           29                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#           29                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#           30                          Intermittent Connectivity Issues with Cisco Router                                                    Cisco Router
#           30                                    Intermittent Network Connectivity Issues                                                    Cisco Router
#           30                                                         Urgent Router Issue                                                    Cisco Router
#           30                                    Support Request for Cisco Router ISR4331                                                    Cisco Router
#           30                                       Connectivity Issues with Cisco Router                                                    Cisco Router
#           30                        Frequent Disconnect Issues with Cisco Router ISR4331                                                    Cisco Router
#           30                                                 Intermittent Network Issues                                      Cisco Router, Cisco Router
#           30                                                         Cisco Router Outage                                                    Cisco Router
#           30                                        Urgent: Frequent Network Drops Issue                                                    Cisco Router
#           30                       Urgent: Connectivity Issues with Cisco Router ISR4331                                                    Cisco Router
#           30                          Network Outage Due to Cisco Router ISR4331 Failure                                                    Cisco Router
#           30                    Network Connectivity Challenges Occurring Intermittently                                      Cisco Router, Cisco Router
#           30                                                 Network Configuration Issue                                                    Cisco Router
#           30                                                Internet Connectivity Issues                                                    Cisco Router
#           30                                                   Urgent Cisco Router Issue                                                    Cisco Router
#           30                              Critical: Recurring Network Disruption Problem                                                    Cisco Router
#           30                                            Network Issues with Cisco Router                                                    Cisco Router
#           30                          Urgent: Critical Network Issue with Router ISR4331                                                    Cisco Router
#           30                          High Priority Incident: Router Connectivity Issues                                                    Cisco Router
#           30                                     Intermittent Connectivity Issues Report                                                    Cisco Router
#           30                                            Issues with Cisco ISR4331 Router                                                    Cisco Router
#           30                                                Urgent: Cisco ISR4331 Issues                                                    Cisco Router
#           30                                                      Urgent: Network Outage                                      Cisco Router, Cisco Router
#           30                                                 Network Connectivity Issues                                                    Cisco Router
#           30                           Critical: Recurring Network Disconnection Problem                                                    Cisco Router
#           30                                            Issues with Cisco Router ISR4331                                                    Cisco Router
#           30                                                       Company Network Issue                                                    Cisco Router
#           30                                        Critical Issue: Network Interruption                                      Cisco Router, Cisco Router
#           30                           Requesting Support: Router causing network issues                                                    Cisco Router
#           30                            Urgent Assistance Needed: Cisco ISR4331 Downtime                                      Cisco Router, Cisco Router
#           30                                                     Immediate Help Required                                                    Cisco Router
#           30                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#           30                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
# ...
#          277                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#          277                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#          278                                                       Billing Discrepancies                                          AWS Management Service
#          278                                                   Billing Discrepancy Issue                                     AWS, AWS Management Service
#          278                                  Investigation into AWS Billing Discrepancy                                          AWS Management Service
#          278                                        Billing Discrepancy with AWS Service                                          AWS Management Service
#          278                                   Billing Issue with AWS Management Service                                     AWS, AWS Management Service
#          278                                                 Request for Billing Support                                     AWS, AWS Management Service
#          279                                        Critical Issue: Network Interruption                                      Cisco Router, Cisco Router
#          279                           Requesting Support: Router causing network issues                                                    Cisco Router
#          279                            Urgent Assistance Needed: Cisco ISR4331 Downtime                                      Cisco Router, Cisco Router
#          279                                                     Immediate Help Required                                                    Cisco Router
#          279                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#          279                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#          279                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#          285                                                   Billing Discrepancy Issue                                     AWS, AWS Management Service
#          285                                  Investigation into AWS Billing Discrepancy                                          AWS Management Service
#          285                                        Billing Discrepancy with AWS Service                                          AWS Management Service
#          285                                   Billing Issue with AWS Management Service                                     AWS, AWS Management Service
#          285                                                 Request for Billing Support                                     AWS, AWS Management Service
#          286                           Requesting Support: Router causing network issues                                                    Cisco Router
#          286                            Urgent Assistance Needed: Cisco ISR4331 Downtime                                      Cisco Router, Cisco Router
#          286                                                     Immediate Help Required                                                    Cisco Router
#          286                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#          286                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#          286                     High Priority: Recurrent Network Disconnections Problem                                                    Cisco Router
#          286                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#          287                                  Investigation into AWS Billing Discrepancy                                          AWS Management Service
#          287                                        Billing Discrepancy with AWS Service                                          AWS Management Service
#          287                                   Billing Issue with AWS Management Service                                     AWS, AWS Management Service
#          287                                                 Request for Billing Support                                     AWS, AWS Management Service
#          288                                       Assistance Required for Printer Setup                                                             NaN
#          288                                             Help with Printer Configuration                                                             NaN
#          289                            Request for Expert Consultation on Ticket System                                                             NaN
#          289                                          Request for IT Consulting Services                                                             NaN
#          291                                               Urgent: Zoom Application Down                                                Zoom application
#          291                                          High Priority: Zoom Service Outage                                                Zoom application
#          291                            Immediate Resolution Needed: Zoom 5.11.0 Crashes                                                             NaN
#          292                           Immediate Assistance Required for Server Downtime                                                             NaN
#          292                              Urgent Support Required to Fix Server Downtime                                                             NaN
#          292                                          Critical Server Management Problem                                                             NaN
#          292                  Immediate Assistance Needed: Issues with Server Management                                                             NaN
#          296                              Urgent Support Required to Fix Server Downtime                                                             NaN
#          296                                          Critical Server Management Problem                                                             NaN
#          296                  Immediate Assistance Needed: Issues with Server Management                                                             NaN
#          298                                   Urgent Assistance Required for AWS Issues                                          AWS Management Service
#          298                                                    Urgent: Major AWS Outage                                     AWS, AWS Management Service
#          298                                         Notification of Planned Maintenance                                          AWS Management Service
#          298                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#          298                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#          298                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#          299           Immediate Assistance Required: Touchscreen Non-Responsive Problem                                           Microsoft Surface Pro
#          299                Immediate Support Needed: Touchscreen Non-Responsive Problem                                           Microsoft Surface Pro
#          300                                                    Urgent: Major AWS Outage                                     AWS, AWS Management Service
#          300                                         Notification of Planned Maintenance                                          AWS Management Service
#          300                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#          300                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#          300                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#          300                                             Critical AWS Connection Problem                                          AWS Management Service
#          301                            Urgent Assistance Needed: Cisco ISR4331 Downtime                                      Cisco Router, Cisco Router
#          301                                                     Immediate Help Required                                                    Cisco Router
#          301                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#          301                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#          301                     High Priority: Recurrent Network Disconnections Problem                                                    Cisco Router
#          301                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#          302                                         Notification of Planned Maintenance                                          AWS Management Service
#          302                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#          302                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#          302                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#          304                         Urgent Assistance Needed: Issue with AWS Deployment                                                             AWS
#          304                       Urgent Assistance Required: Issue with AWS Deployment                                                             AWS
#          307                                        Billing Discrepancy with AWS Service                                          AWS Management Service
#          307                                   Billing Issue with AWS Management Service                                     AWS, AWS Management Service
#          307                                                 Request for Billing Support                                     AWS, AWS Management Service
#          310                                                               Major Concern                                                             NaN
#          310                                                            Critical Problem                                                             NaN
#          310                                                            Critical Concern                                                             NaN
#          313                             Urgent: Critical AWS Service Outage Experienced                  AWS Management Service, AWS Management Service
#          313                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#          313                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#          315                                                     Immediate Help Required                                                    Cisco Router
#          315                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#          315                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#          315                     High Priority: Recurrent Network Disconnections Problem                                                    Cisco Router
#          315                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#          316                   Seeking Assistance: Router Leading to Network Disruptions                                                    Cisco Router
#          316                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#          316                     High Priority: Recurrent Network Disconnections Problem                                                    Cisco Router
#          316                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#          317                                   Billing Issue with AWS Management Service                                     AWS, AWS Management Service
#          317                                                 Request for Billing Support                                     AWS, AWS Management Service
#          318                     Immediate Support Required: Cisco ISR4331 Router Outage                                      Cisco Router, Cisco Router
#          318                     High Priority: Recurrent Network Disconnections Problem                                                    Cisco Router
#          318                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#          322                                    Urgent Help Needed: AWS Deployment Issue                                          AWS Management Service
#          322                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#          323                            Urgent Support Required for AWS Issue Resolution                                     AWS Management Service, AWS
#          323                        Inquiry About Economical AWS Management Alternatives             AWS Management Service, AWS Management Service, AWS
#          324                                                                Need Support                                                             NaN
#          324                                                         Request for Support                                                             NaN
#          327                     High Priority: Recurrent Network Disconnections Problem                                                    Cisco Router
#          327                                High Priority: Recurring Network Disruptions                                                    Cisco Router
#          329                                                            Critical Problem                                                             NaN
#          329                                                            Critical Concern                                                             NaN

# %%
# prompt: get cluster no. having product tags and percent of occuerence of product tag same cluster having different product tags combine them in one and display list should have one cluster name only once and its product tags and percent

import pandas as pd

# Load the dataframe.
df = pd.read_csv('/content/grouped_tickets_with_matched_nouns.csv')
df = df.rename(columns={'matched_nouns': 'product_tag'})
df = df[['cluster_key', 'subject', 'product_tag']]

# Group by cluster and aggregate product tags.
cluster_summary = df.groupby('cluster_key')['product_tag'].agg(
    lambda x: ', '.join(set(x.dropna()))
).reset_index()

# Calculate the percentage of occurrence of each tag within its cluster.
cluster_counts = df.groupby(['cluster_key', 'product_tag']).size().reset_index(name='count')
cluster_totals = cluster_counts.groupby('cluster_key')['count'].sum().reset_index(name='total')

cluster_percentages = pd.merge(cluster_counts, cluster_totals, on='cluster_key')
cluster_percentages['percentage'] = (cluster_percentages['count'] / cluster_percentages['total']) * 100

# Merge with cluster summary to include percentage.
result = pd.merge(cluster_summary, cluster_percentages, on='cluster_key')

# Display only necessary columns and format.
result = result[['cluster_key', 'product_tag_x', 'percentage']].rename(
    columns={'product_tag_x': 'product_tags'}
)
print(result.to_string(index=False))
# Out:
#  cluster_key                                                                                                                                                                                                                                                                      product_tags  percentage
#            0                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   75.000000
#            0                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   25.000000
#            2                                                                                                                                                                                                                                                                          Dell XPS  100.000000
#            4                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   38.095238
#            4                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   28.571429
#            4                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    4.761905
#            4                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   23.809524
#            4                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    4.761905
#            5                                                                                                                                                                                                                                                                            Office  100.000000
#            7                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   33.333333
#            7                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   66.666667
#            8                                                 AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   35.000000
#            8                                                 AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    5.000000
#            8                                                 AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   10.000000
#            8                                                 AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   10.000000
#            8                                                 AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   30.000000
#            8                                                 AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   10.000000
#           12                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   25.000000
#           12                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   31.250000
#           12                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    6.250000
#           12                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   31.250000
#           12                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    6.250000
#           13                                                                                                                                                                                                                                                                               AWS  100.000000
#           15                                                                                                                                                                                                                                                                        HP DeskJet  100.000000
#           16                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   87.878788
#           16                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   12.121212
#           17                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   43.478261
#           17                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   17.391304
#           17                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    4.347826
#           17                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   26.086957
#           17                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    8.695652
#           18                                                                                                                                                                                                  AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   58.823529
#           18                                                                                                                                                                                                  AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service    5.882353
#           18                                                                                                                                                                                                  AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   35.294118
#           21                                                                                                                                                                                                               Microsoft Surface Pro, Microsoft Surface Pro, Microsoft Surface Pro   83.333333
#           21                                                                                                                                                                                                               Microsoft Surface Pro, Microsoft Surface Pro, Microsoft Surface Pro   16.666667
#           24                                                                                                                                                                                                                                                                  Zoom application  100.000000
#           25                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   90.909091
#           25                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router    9.090909
#           26                                                                                                                                                                                                                                                                          Dell XPS  100.000000
#           29                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   42.857143
#           29                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   14.285714
#           29                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    7.142857
#           29                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   32.142857
#           29                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    3.571429
#           30                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   82.857143
#           30                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   17.142857
#           32                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   30.769231
#           32                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   15.384615
#           32                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   15.384615
#           32                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   23.076923
#           32                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   15.384615
#           34                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   58.823529
#           34                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service    5.882353
#           34                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service    5.882353
#           34                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   29.411765
#           35                                                                                                                                                                                                                                                                               AWS  100.000000
#           36                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   45.454545
#           36                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service    9.090909
#           36                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service    9.090909
#           36                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   36.363636
#           37                                                                                                                                                                                                                                                                     Jira Software  100.000000
#           38                                                                                                                                                                                                                                                                        HP DeskJet  100.000000
#           39                                                                                                                                                                                                                                                                     Jira Software  100.000000
#           41                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   40.000000
#           41                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   12.000000
#           41                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    8.000000
#           41                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   36.000000
#           41                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    4.000000
#           44                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   81.818182
#           44                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   18.181818
#           45                                                                                                                                                                                                                                                                          Dell XPS  100.000000
#           46                                                                                                                                                                                                                                                             Microsoft Surface Pro  100.000000
#           47                                                                                                                                                                                   MacBook Air M1, MacBook Air M1, Adobe Photoshop, MacBook Air M1, MacBook Air M1, MacBook Air M1   50.000000
#           47                                                                                                                                                                                   MacBook Air M1, MacBook Air M1, Adobe Photoshop, MacBook Air M1, MacBook Air M1, MacBook Air M1   50.000000
#           48                                                                                                                                                                                                                                                                          Dell XPS  100.000000
#           49                                                                                                                                                                                                                                                             Microsoft Surface Pro  100.000000
#           53                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   83.333333
#           53                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   16.666667
#           54                                                                                                                                                                                                                                                                    MacBook Air M1  100.000000
#           55                                                                                                                                                                                                                                                                     Jira Software  100.000000
#           57                                                                                                                                                                                                                                                                  Zoom application  100.000000
#           63                                                                                                                                                                                                                                                                    MacBook Air M1  100.000000
#           65                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   88.888889
#           65                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   11.111111
#           67                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   50.000000
#           67                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   50.000000
#           71                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   84.000000
#           71                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   16.000000
#           77                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   18.181818
#           77                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   18.181818
#           77                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   18.181818
#           77                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   27.272727
#           77                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   18.181818
#           79                                                                                                                                                                                                                         Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro   50.000000
#           79                                                                                                                                                                                                                         Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro   50.000000
#           80                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   35.294118
#           80                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   23.529412
#           80                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service    5.882353
#           80                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   35.294118
#           82                                                                                                                                                                                                                                                            Office, Office, Office   50.000000
#           82                                                                                                                                                                                                                                                            Office, Office, Office   50.000000
#           86                                                                                                                                                                                                                                                                        HP DeskJet  100.000000
#           88                                                                                                                                                                                                                                                                        HP DeskJet  100.000000
#           89                                                                                                                                                                                                                         Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro   50.000000
#           89                                                                                                                                                                                                                         Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro   50.000000
#           90                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   20.000000
#           90                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   20.000000
#           90                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   20.000000
#           90                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   30.000000
#           90                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   10.000000
#           98                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   36.842105
#           98                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   21.052632
#           98                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    5.263158
#           98                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   31.578947
#           98                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    5.263158
#           99                                                                                                                                                                                                                                                                          Dell XPS  100.000000
#          100                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   78.571429
#          100                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   21.428571
#          105                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   78.571429
#          105                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   21.428571
#          108 AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   18.750000
#          108 AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   12.500000
#          108 AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   12.500000
#          108 AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   12.500000
#          108 AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    6.250000
#          108 AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   31.250000
#          108 AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    6.250000
#          110                                                                                                                                                                                                                                                             Microsoft Surface Pro  100.000000
#          112                                                                                                                                                                                                                                                       AWS, AWS Management Service  100.000000
#          114                                                                                                                                                                                                                                                                          Dell XPS  100.000000
#          115                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   82.142857
#          115                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   17.857143
#          116                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   47.058824
#          116                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service    5.882353
#          116                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   11.764706
#          116                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   35.294118
#          122                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   91.304348
#          122                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router    8.695652
#          123                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   81.481481
#          123                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   18.518519
#          125                                                                                                                                                                                                                                                                   Adobe Photoshop  100.000000
#          130                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   10.000000
#          130                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   20.000000
#          130                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   20.000000
#          130                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   40.000000
#          130                                                                              AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   10.000000
#          134                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   73.684211
#          134                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   26.315789
#          136                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   79.166667
#          136                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   20.833333
#          141                                                                                                                                                                                                                                                                      Cisco Router  100.000000
#          143                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   42.105263
#          143                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   10.526316
#          143                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    5.263158
#          143                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service   36.842105
#          143                                                                                                                AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service    5.263158
#          146                                                                                                                                                                                                                                                                               AWS  100.000000
#          153                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   93.750000
# ...
#          273                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   70.000000
#          273                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   30.000000
#          274                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   33.333333
#          274                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          274                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   33.333333
#          274                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          277                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   33.333333
#          277                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          277                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          277                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   33.333333
#          278                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   50.000000
#          278                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   50.000000
#          279                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   57.142857
#          279                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   42.857143
#          285                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   40.000000
#          285                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   60.000000
#          286                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   71.428571
#          286                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   28.571429
#          287                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   50.000000
#          287                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   50.000000
#          291                                                                                                                                                                                                                                                                  Zoom application  100.000000
#          298                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   50.000000
#          298                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          298                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          298                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          299                                                                                                                                                                                                                                                             Microsoft Surface Pro  100.000000
#          300                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   50.000000
#          300                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          300                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          300                                                                                                                                                  AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service   16.666667
#          301                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   66.666667
#          301                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   33.333333
#          302                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS   50.000000
#          302                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS   25.000000
#          302                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS   25.000000
#          304                                                                                                                                                                                                                                                                               AWS  100.000000
#          307                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   33.333333
#          307                                                                                                                                                                                                                               AWS Management Service, AWS, AWS Management Service   66.666667
#          313                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS   33.333333
#          313                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS   33.333333
#          313                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS   33.333333
#          315                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   80.000000
#          315                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   20.000000
#          316                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   75.000000
#          316                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   25.000000
#          317                                                                                                                                                                                                                                                       AWS, AWS Management Service  100.000000
#          318                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   66.666667
#          318                                                                                                                                                                                                                                          Cisco Router, Cisco Router, Cisco Router   33.333333
#          322                                                                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS   50.000000
#          322                                                                                                                                                                                                                               AWS Management Service, AWS Management Service, AWS   50.000000
#          323                                                                                                                                                                                                  AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS   50.000000
#          323                                                                                                                                                                                                  AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS   50.000000
#          327                                                                                                                                                                                                                                                                      Cisco Router  100.000000

# %%
# prompt: display above result in string containing cluster_key,product_tag,percentage  not in table form

# Load the dataframe.
df = pd.read_csv('/content/grouped_tickets_with_matched_nouns.csv')
df = df.rename(columns={'matched_nouns': 'product_tag'})
df = df[['cluster_key', 'subject', 'product_tag']]

# Group by cluster and aggregate product tags.
cluster_summary = df.groupby('cluster_key')['product_tag'].agg(
    lambda x: ', '.join(set(x.dropna()))
).reset_index()

# Calculate the percentage of occurrence of each tag within its cluster.
cluster_counts = df.groupby(['cluster_key', 'product_tag']).size().reset_index(name='count')
cluster_totals = cluster_counts.groupby('cluster_key')['count'].sum().reset_index(name='total')

cluster_percentages = pd.merge(cluster_counts, cluster_totals, on='cluster_key')
cluster_percentages['percentage'] = (cluster_percentages['count'] / cluster_percentages['total']) * 100

# Merge with cluster summary to include percentage.
result = pd.merge(cluster_summary, cluster_percentages, on='cluster_key')

# Display only necessary columns and format without the table structure
for index, row in result.iterrows():
    print(f"cluster_key: {row['cluster_key']}, product_tag: {row['product_tag_x']}, percentage: {row['percentage']}")
# Out:
# cluster_key: 0, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 75.0
# cluster_key: 0, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 25.0
# cluster_key: 2, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 4, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 38.095238095238095
# cluster_key: 4, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 28.57142857142857
# cluster_key: 4, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 4.761904761904762
# cluster_key: 4, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 23.809523809523807
# cluster_key: 4, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 4.761904761904762
# cluster_key: 5, product_tag: Office, percentage: 100.0
# cluster_key: 7, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 7, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 66.66666666666666
# cluster_key: 8, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 35.0
# cluster_key: 8, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 5.0
# cluster_key: 8, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 8, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 8, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 30.0
# cluster_key: 8, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 12, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 12, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 31.25
# cluster_key: 12, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 6.25
# cluster_key: 12, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 31.25
# cluster_key: 12, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 6.25
# cluster_key: 13, product_tag: AWS, percentage: 100.0
# cluster_key: 15, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 16, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 87.87878787878788
# cluster_key: 16, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 12.121212121212121
# cluster_key: 17, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 43.47826086956522
# cluster_key: 17, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 17.391304347826086
# cluster_key: 17, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 4.3478260869565215
# cluster_key: 17, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 26.08695652173913
# cluster_key: 17, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 8.695652173913043
# cluster_key: 18, product_tag: AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 58.82352941176471
# cluster_key: 18, product_tag: AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 5.88235294117647
# cluster_key: 18, product_tag: AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 35.294117647058826
# cluster_key: 21, product_tag: Microsoft Surface Pro, Microsoft Surface Pro, Microsoft Surface Pro, percentage: 83.33333333333334
# cluster_key: 21, product_tag: Microsoft Surface Pro, Microsoft Surface Pro, Microsoft Surface Pro, percentage: 16.666666666666664
# cluster_key: 24, product_tag: Zoom application, percentage: 100.0
# cluster_key: 25, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 90.9090909090909
# cluster_key: 25, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 9.090909090909092
# cluster_key: 26, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 29, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 42.857142857142854
# cluster_key: 29, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 14.285714285714285
# cluster_key: 29, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 7.142857142857142
# cluster_key: 29, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 32.142857142857146
# cluster_key: 29, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 3.571428571428571
# cluster_key: 30, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 82.85714285714286
# cluster_key: 30, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 17.142857142857142
# cluster_key: 32, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 30.76923076923077
# cluster_key: 32, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 15.384615384615385
# cluster_key: 32, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 15.384615384615385
# cluster_key: 32, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 23.076923076923077
# cluster_key: 32, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 15.384615384615385
# cluster_key: 34, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 58.82352941176471
# cluster_key: 34, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 5.88235294117647
# cluster_key: 34, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 5.88235294117647
# cluster_key: 34, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 29.411764705882355
# cluster_key: 35, product_tag: AWS, percentage: 100.0
# cluster_key: 36, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 45.45454545454545
# cluster_key: 36, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 9.090909090909092
# cluster_key: 36, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 9.090909090909092
# cluster_key: 36, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 36.36363636363637
# cluster_key: 37, product_tag: Jira Software, percentage: 100.0
# cluster_key: 38, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 39, product_tag: Jira Software, percentage: 100.0
# cluster_key: 41, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 40.0
# cluster_key: 41, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 12.0
# cluster_key: 41, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 8.0
# cluster_key: 41, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 36.0
# cluster_key: 41, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 4.0
# cluster_key: 44, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 81.81818181818183
# cluster_key: 44, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 18.181818181818183
# cluster_key: 45, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 46, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 47, product_tag: MacBook Air M1, MacBook Air M1, Adobe Photoshop, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 50.0
# cluster_key: 47, product_tag: MacBook Air M1, MacBook Air M1, Adobe Photoshop, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 50.0
# cluster_key: 48, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 49, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 53, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 83.33333333333334
# cluster_key: 53, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 16.666666666666664
# cluster_key: 54, product_tag: MacBook Air M1, percentage: 100.0
# cluster_key: 55, product_tag: Jira Software, percentage: 100.0
# cluster_key: 57, product_tag: Zoom application, percentage: 100.0
# cluster_key: 63, product_tag: MacBook Air M1, percentage: 100.0
# cluster_key: 65, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 88.88888888888889
# cluster_key: 65, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 11.11111111111111
# cluster_key: 67, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 67, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 71, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 84.0
# cluster_key: 71, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 16.0
# cluster_key: 77, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 77, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 77, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 77, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 27.27272727272727
# cluster_key: 77, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 79, product_tag: Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro, percentage: 50.0
# cluster_key: 79, product_tag: Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro, percentage: 50.0
# cluster_key: 80, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 35.294117647058826
# cluster_key: 80, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 23.52941176470588
# cluster_key: 80, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 5.88235294117647
# cluster_key: 80, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 35.294117647058826
# cluster_key: 82, product_tag: Office, Office, Office, percentage: 50.0
# cluster_key: 82, product_tag: Office, Office, Office, percentage: 50.0
# cluster_key: 86, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 88, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 89, product_tag: Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro, percentage: 50.0
# cluster_key: 89, product_tag: Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro, percentage: 50.0
# cluster_key: 90, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 20.0
# cluster_key: 90, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 20.0
# cluster_key: 90, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 20.0
# cluster_key: 90, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 30.0
# cluster_key: 90, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 98, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 36.84210526315789
# cluster_key: 98, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 21.052631578947366
# cluster_key: 98, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 5.263157894736842
# cluster_key: 98, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 31.57894736842105
# cluster_key: 98, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 5.263157894736842
# cluster_key: 99, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 100, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.57142857142857
# cluster_key: 100, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 21.428571428571427
# cluster_key: 105, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.57142857142857
# cluster_key: 105, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 21.428571428571427
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 18.75
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 12.5
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 12.5
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 12.5
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 6.25
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 31.25
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 6.25
# cluster_key: 110, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 112, product_tag: AWS, AWS Management Service, percentage: 100.0
# cluster_key: 114, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 115, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 82.14285714285714
# cluster_key: 115, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 17.857142857142858
# cluster_key: 116, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 47.05882352941176
# cluster_key: 116, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 5.88235294117647
# cluster_key: 116, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 11.76470588235294
# cluster_key: 116, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 35.294117647058826
# cluster_key: 122, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 91.30434782608695
# cluster_key: 122, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 8.695652173913043
# cluster_key: 123, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 81.48148148148148
# cluster_key: 123, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 18.51851851851852
# cluster_key: 125, product_tag: Adobe Photoshop, percentage: 100.0
# cluster_key: 130, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 130, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 20.0
# cluster_key: 130, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 20.0
# cluster_key: 130, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 40.0
# cluster_key: 130, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 134, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 73.68421052631578
# cluster_key: 134, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 26.31578947368421
# cluster_key: 136, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 79.16666666666666
# cluster_key: 136, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 20.833333333333336
# cluster_key: 141, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 143, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 42.10526315789473
# cluster_key: 143, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.526315789473683
# cluster_key: 143, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 5.263157894736842
# cluster_key: 143, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 36.84210526315789
# cluster_key: 143, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 5.263157894736842
# cluster_key: 146, product_tag: AWS, percentage: 100.0
# cluster_key: 153, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 93.75
# cluster_key: 153, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 6.25
# cluster_key: 154, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.94736842105263
# cluster_key: 154, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 21.052631578947366
# cluster_key: 156, product_tag: Zoom application, percentage: 100.0
# cluster_key: 158, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 42.857142857142854
# cluster_key: 158, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 19.047619047619047
# cluster_key: 158, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 4.761904761904762
# cluster_key: 158, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 28.57142857142857
# cluster_key: 158, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 4.761904761904762
# cluster_key: 159, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 160, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.95238095238095
# cluster_key: 160, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 19.047619047619047
# cluster_key: 165, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 166, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 167, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.95238095238095
# cluster_key: 167, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 19.047619047619047
# cluster_key: 170, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 77.77777777777779
# cluster_key: 170, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 22.22222222222222
# cluster_key: 172, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 35.0
# cluster_key: 172, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 20.0
# cluster_key: 172, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 172, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 30.0
# cluster_key: 172, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 5.0
# cluster_key: 173, product_tag: Zoom application, percentage: 100.0
# cluster_key: 178, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 178, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 178, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 178, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 178, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 179, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 53.84615384615385
# cluster_key: 179, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 7.6923076923076925
# cluster_key: 179, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 7.6923076923076925
# cluster_key: 179, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 30.76923076923077
# cluster_key: 180, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 180, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 18.75
# cluster_key: 180, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 6.25
# cluster_key: 180, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 181, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 184, product_tag: AWS, percentage: 100.0
# cluster_key: 185, product_tag: AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 28.57142857142857
# cluster_key: 185, product_tag: AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 14.285714285714285
# cluster_key: 185, product_tag: AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 28.57142857142857
# cluster_key: 185, product_tag: AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 28.57142857142857
# cluster_key: 188, product_tag: MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 33.33333333333333
# cluster_key: 188, product_tag: MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 33.33333333333333
# cluster_key: 188, product_tag: MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 33.33333333333333
# cluster_key: 190, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 45.45454545454545
# cluster_key: 190, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 27.27272727272727
# cluster_key: 190, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 9.090909090909092
# cluster_key: 190, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 192, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 192, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 192, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 192, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 192, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 197, product_tag: MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 50.0
# cluster_key: 197, product_tag: MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 50.0
# cluster_key: 198, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 69.23076923076923
# cluster_key: 198, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 30.76923076923077
# cluster_key: 210, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 76.47058823529412
# cluster_key: 210, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 23.52941176470588
# cluster_key: 213, product_tag: AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 66.66666666666666
# cluster_key: 213, product_tag: AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 214, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 45.45454545454545
# cluster_key: 214, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 214, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 9.090909090909092
# cluster_key: 214, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 27.27272727272727
# cluster_key: 216, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 85.71428571428571
# cluster_key: 216, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 14.285714285714285
# cluster_key: 218, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.57142857142857
# cluster_key: 218, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 21.428571428571427
# cluster_key: 220, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 63.63636363636363
# cluster_key: 220, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 36.36363636363637
# cluster_key: 221, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 55.55555555555556
# cluster_key: 221, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 44.44444444444444
# cluster_key: 222, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 54.54545454545454
# cluster_key: 222, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 222, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 27.27272727272727
# cluster_key: 223, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 223, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 224, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 226, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 228, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 231, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 76.92307692307693
# cluster_key: 231, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 23.076923076923077
# cluster_key: 236, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 237, product_tag: AWS, percentage: 100.0
# cluster_key: 239, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 239, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 239, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 239, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 242, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, percentage: 25.0
# cluster_key: 242, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, percentage: 25.0
# cluster_key: 242, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 243, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 243, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 75.0
# cluster_key: 245, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.0
# cluster_key: 245, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 20.0
# cluster_key: 246, product_tag: AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 246, product_tag: AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 247, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 42.857142857142854
# cluster_key: 247, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 14.285714285714285
# cluster_key: 247, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 14.285714285714285
# cluster_key: 247, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 28.57142857142857
# cluster_key: 252, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 252, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 252, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 253, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 253, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 8.333333333333332
# cluster_key: 253, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 253, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 256, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 259, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 40.0
# cluster_key: 259, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 259, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 259, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 30.0
# cluster_key: 259, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 261, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 57.14285714285714
# cluster_key: 261, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 42.857142857142854
# cluster_key: 263, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 263, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 11.11111111111111
# cluster_key: 263, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 11.11111111111111
# cluster_key: 263, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 11.11111111111111
# cluster_key: 263, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 22.22222222222222
# cluster_key: 263, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 11.11111111111111
# cluster_key: 270, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 55.55555555555556
# cluster_key: 270, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 11.11111111111111
# cluster_key: 270, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 11.11111111111111
# cluster_key: 270, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 22.22222222222222
# cluster_key: 273, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 70.0
# cluster_key: 273, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 30.0
# cluster_key: 274, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 274, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 274, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 274, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 277, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 277, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 277, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 277, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 278, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 278, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 279, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 57.14285714285714
# cluster_key: 279, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 42.857142857142854
# cluster_key: 285, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 40.0
# cluster_key: 285, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 60.0
# cluster_key: 286, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 71.42857142857143
# cluster_key: 286, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 28.57142857142857
# cluster_key: 287, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 287, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 291, product_tag: Zoom application, percentage: 100.0
# cluster_key: 298, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 298, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 298, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 298, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 299, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 300, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 300, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 300, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 300, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 301, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 66.66666666666666
# cluster_key: 301, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 33.33333333333333
# cluster_key: 302, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 302, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 25.0
# cluster_key: 302, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 25.0
# cluster_key: 304, product_tag: AWS, percentage: 100.0
# cluster_key: 307, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 307, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 66.66666666666666
# cluster_key: 313, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 33.33333333333333
# cluster_key: 313, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 33.33333333333333
# cluster_key: 313, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 33.33333333333333
# cluster_key: 315, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.0
# cluster_key: 315, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 20.0
# cluster_key: 316, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 75.0
# cluster_key: 316, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 25.0
# cluster_key: 317, product_tag: AWS, AWS Management Service, percentage: 100.0
# cluster_key: 318, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 66.66666666666666
# cluster_key: 318, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 33.33333333333333
# cluster_key: 322, product_tag: AWS Management Service, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 322, product_tag: AWS Management Service, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 323, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 323, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 327, product_tag: Cisco Router, percentage: 100.0

# %%
# prompt: merge same cluster keys and their corresponding product_tag percentage

# Load the dataframe.
df = pd.read_csv('/content/grouped_tickets_with_matched_nouns.csv')
df = df.rename(columns={'matched_nouns': 'product_tag'})
df = df[['cluster_key', 'subject', 'product_tag']]

# Group by cluster and aggregate product tags.
cluster_summary = df.groupby('cluster_key')['product_tag'].agg(lambda x: ', '.join(set(x.dropna()))).reset_index()

# Calculate the percentage of occurrence of each tag within its cluster.
cluster_counts = df.groupby(['cluster_key', 'product_tag']).size().reset_index(name='count')
cluster_totals = cluster_counts.groupby('cluster_key')['count'].sum().reset_index(name='total')
cluster_percentages = pd.merge(cluster_counts, cluster_totals, on='cluster_key')
cluster_percentages['percentage'] = (cluster_percentages['count'] / cluster_percentages['total']) * 100

# Merge with cluster summary and handle potential duplicates
merged_df = pd.merge(cluster_summary, cluster_percentages, on='cluster_key')
merged_df = merged_df.drop_duplicates(subset=['cluster_key', 'product_tag_x'], keep='first')

# Display only necessary columns and format without the table structure
for index, row in merged_df.iterrows():
    print(f"cluster_key: {row['cluster_key']}, product_tag: {row['product_tag_x']}, percentage: {row['percentage']}")
# Out:
# cluster_key: 0, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 75.0
# cluster_key: 2, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 4, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 38.095238095238095
# cluster_key: 5, product_tag: Office, percentage: 100.0
# cluster_key: 7, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 8, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 35.0
# cluster_key: 12, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 13, product_tag: AWS, percentage: 100.0
# cluster_key: 15, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 16, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 87.87878787878788
# cluster_key: 17, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 43.47826086956522
# cluster_key: 18, product_tag: AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 58.82352941176471
# cluster_key: 21, product_tag: Microsoft Surface Pro, Microsoft Surface Pro, Microsoft Surface Pro, percentage: 83.33333333333334
# cluster_key: 24, product_tag: Zoom application, percentage: 100.0
# cluster_key: 25, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 90.9090909090909
# cluster_key: 26, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 29, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 42.857142857142854
# cluster_key: 30, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 82.85714285714286
# cluster_key: 32, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 30.76923076923077
# cluster_key: 34, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 58.82352941176471
# cluster_key: 35, product_tag: AWS, percentage: 100.0
# cluster_key: 36, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 45.45454545454545
# cluster_key: 37, product_tag: Jira Software, percentage: 100.0
# cluster_key: 38, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 39, product_tag: Jira Software, percentage: 100.0
# cluster_key: 41, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 40.0
# cluster_key: 44, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 81.81818181818183
# cluster_key: 45, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 46, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 47, product_tag: MacBook Air M1, MacBook Air M1, Adobe Photoshop, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 50.0
# cluster_key: 48, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 49, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 53, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 83.33333333333334
# cluster_key: 54, product_tag: MacBook Air M1, percentage: 100.0
# cluster_key: 55, product_tag: Jira Software, percentage: 100.0
# cluster_key: 57, product_tag: Zoom application, percentage: 100.0
# cluster_key: 63, product_tag: MacBook Air M1, percentage: 100.0
# cluster_key: 65, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 88.88888888888889
# cluster_key: 67, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 71, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 84.0
# cluster_key: 77, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 18.181818181818183
# cluster_key: 79, product_tag: Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro, percentage: 50.0
# cluster_key: 80, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 35.294117647058826
# cluster_key: 82, product_tag: Office, Office, Office, percentage: 50.0
# cluster_key: 86, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 88, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 89, product_tag: Microsoft Surface Pro, Surface Pro, Microsoft Surface Pro, percentage: 50.0
# cluster_key: 90, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 20.0
# cluster_key: 98, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 36.84210526315789
# cluster_key: 99, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 100, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.57142857142857
# cluster_key: 105, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.57142857142857
# cluster_key: 108, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 18.75
# cluster_key: 110, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 112, product_tag: AWS, AWS Management Service, percentage: 100.0
# cluster_key: 114, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 115, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 82.14285714285714
# cluster_key: 116, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 47.05882352941176
# cluster_key: 122, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 91.30434782608695
# cluster_key: 123, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 81.48148148148148
# cluster_key: 125, product_tag: Adobe Photoshop, percentage: 100.0
# cluster_key: 130, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 10.0
# cluster_key: 134, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 73.68421052631578
# cluster_key: 136, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 79.16666666666666
# cluster_key: 141, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 143, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 42.10526315789473
# cluster_key: 146, product_tag: AWS, percentage: 100.0
# cluster_key: 153, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 93.75
# cluster_key: 154, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.94736842105263
# cluster_key: 156, product_tag: Zoom application, percentage: 100.0
# cluster_key: 158, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 42.857142857142854
# cluster_key: 159, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 160, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.95238095238095
# cluster_key: 165, product_tag: HP DeskJet, percentage: 100.0
# cluster_key: 166, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 167, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.95238095238095
# cluster_key: 170, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 77.77777777777779
# cluster_key: 172, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 35.0
# cluster_key: 173, product_tag: Zoom application, percentage: 100.0
# cluster_key: 178, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 179, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 53.84615384615385
# cluster_key: 180, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 181, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 184, product_tag: AWS, percentage: 100.0
# cluster_key: 185, product_tag: AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 28.57142857142857
# cluster_key: 188, product_tag: MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 33.33333333333333
# cluster_key: 190, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 45.45454545454545
# cluster_key: 192, product_tag: AWS Management Service, AWS, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 16.666666666666664
# cluster_key: 197, product_tag: MacBook Air M1, MacBook Air M1, MacBook Air M1, MacBook Air M1, percentage: 50.0
# cluster_key: 198, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 69.23076923076923
# cluster_key: 210, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 76.47058823529412
# cluster_key: 213, product_tag: AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 66.66666666666666
# cluster_key: 214, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 45.45454545454545
# cluster_key: 216, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 85.71428571428571
# cluster_key: 218, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 78.57142857142857
# cluster_key: 220, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 63.63636363636363
# cluster_key: 221, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 55.55555555555556
# cluster_key: 222, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 54.54545454545454
# cluster_key: 223, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 224, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 226, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 228, product_tag: Dell XPS, percentage: 100.0
# cluster_key: 231, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 76.92307692307693
# cluster_key: 236, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 237, product_tag: AWS, percentage: 100.0
# cluster_key: 239, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 242, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, percentage: 25.0
# cluster_key: 243, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 25.0
# cluster_key: 245, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.0
# cluster_key: 246, product_tag: AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 247, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 42.857142857142854
# cluster_key: 252, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 253, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 256, product_tag: Cisco Router, percentage: 100.0
# cluster_key: 259, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 40.0
# cluster_key: 261, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 57.14285714285714
# cluster_key: 263, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, AWS, AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 270, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 55.55555555555556
# cluster_key: 273, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 70.0
# cluster_key: 274, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 277, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 278, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 279, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 57.14285714285714
# cluster_key: 285, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 40.0
# cluster_key: 286, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 71.42857142857143
# cluster_key: 287, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 291, product_tag: Zoom application, percentage: 100.0
# cluster_key: 298, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 299, product_tag: Microsoft Surface Pro, percentage: 100.0
# cluster_key: 300, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, AWS, AWS Management Service, percentage: 50.0
# cluster_key: 301, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 66.66666666666666
# cluster_key: 302, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 304, product_tag: AWS, percentage: 100.0
# cluster_key: 307, product_tag: AWS Management Service, AWS, AWS Management Service, percentage: 33.33333333333333
# cluster_key: 313, product_tag: AWS Management Service, AWS Management Service, AWS Management Service, AWS Management Service, AWS, percentage: 33.33333333333333
# cluster_key: 315, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 80.0
# cluster_key: 316, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 75.0
# cluster_key: 317, product_tag: AWS, AWS Management Service, percentage: 100.0
# cluster_key: 318, product_tag: Cisco Router, Cisco Router, Cisco Router, percentage: 66.66666666666666
# cluster_key: 322, product_tag: AWS Management Service, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 323, product_tag: AWS Management Service, AWS Management Service, AWS, AWS Management Service, AWS, percentage: 50.0
# cluster_key: 327, product_tag: Cisco Router, percentage: 100.0

# %%
#  plot 3d graph for x=cluster_key,y=index ,z=matched_nouns  and hover matched_noun on datapoint

import pandas as pd
import plotly.express as px

# Load the updated DataFrame
file_path = '/content/grouped_tickets_with_matched_nouns.csv'
data = pd.read_csv(file_path)

# Create the 3D scatter plot
fig = px.scatter_3d(data,
                    x='cluster_key',
                    y=data.index,
                    z='index',
                    color='matched_nouns',
                    hover_data=['matched_nouns','subject'])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3dade815-b475-4d51-9144-758b2c2e6f2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dade815-b475-4d51-9144-758b2c2e6f2f")) {                    Plotly.newPlot(                        "3dade815-b475-4d51-9144-758b2c2e6f2f",                        [{"customdata":[["Cisco Router","Urgent: Critical impact on enterprise network connectivity"],["Cisco Router","Intermittent Connectivity Issues with Cisco Router"],["Cisco Router","Urgent Router Issue"],["Cisco Router","Frequent Disconnect Issues with Cisco Router ISR4331"],["Cisco Router","Cisco Router Outage"],["Cisco Router","Urgent: Connectivity Issues with Cisco Router ISR4331"],["Cisco Router","Network Outage Due to Cisco Router ISR4331 Failure"],["Cisco Router","Urgent Cisco Router Issue"],["Cisco Router","Critical: Recurring Network Disruption Problem"],["Cisco Router","Network Issues with Cisco Router"],["Cisco Router","Urgent: Critical Network Issue with Router ISR4331"],["Cisco Router","High Priority Incident: Router Connectivity Issues"],["Cisco Router","Urgent: Cisco ISR4331 Issues"],["Cisco Router","Network Connectivity Issues"],["Cisco Router","Company Network Issue"],["Cisco Router","Requesting Support: Router causing network issues"],["Cisco Router","Seeking Assistance: Router Leading to Network Disruptions"],["Cisco Router","High Priority: Recurring Network Disruptions"],["Cisco Router","Urgent: Cisco Router ISR4331 Network Connectivity Issues"],["Cisco Router","Connectivity Issues"],["Cisco Router","Intermittent Connectivity Issues with Cisco Router"],["Cisco Router","Intermittent Network Connectivity Issues"],["Cisco Router","Urgent Router Issue"],["Cisco Router","Support Request for Cisco Router ISR4331"],["Cisco Router","Connectivity Issues with Cisco Router"],["Cisco Router","Frequent Disconnect Issues with Cisco Router ISR4331"],["Cisco Router","Cisco Router Outage"],["Cisco Router","Urgent: Frequent Network Drops Issue"],["Cisco Router","Urgent: Connectivity Issues with Cisco Router ISR4331"],["Cisco Router","Network Configuration Issue"],["Cisco Router","Internet Connectivity Issues"],["Cisco Router","Critical: Recurring Network Disruption Problem"],["Cisco Router","Network Issues with Cisco Router"],["Cisco Router","Urgent: Critical Network Issue with Router ISR4331"],["Cisco Router","High Priority Incident: Router Connectivity Issues"],["Cisco Router","Intermittent Connectivity Issues Report"],["Cisco Router","Issues with Cisco ISR4331 Router"],["Cisco Router","Urgent: Cisco ISR4331 Issues"],["Cisco Router","Network Connectivity Issues"],["Cisco Router","Critical: Recurring Network Disconnection Problem"],["Cisco Router","Issues with Cisco Router ISR4331"],["Cisco Router","Company Network Issue"],["Cisco Router","Requesting Support: Router causing network issues"],["Cisco Router","Immediate Help Required"],["Cisco Router","Seeking Assistance: Router Leading to Network Disruptions"],["Cisco Router","High Priority: Recurrent Network Disconnections Problem"],["Cisco Router","High Priority: Recurring Network Disruptions"],["Cisco Router","Connectivity Issues"],["Cisco Router","Intermittent Connectivity Issues with Cisco Router"],["Cisco Router","Intermittent Network Connectivity Issues"],["Cisco Router","Urgent Router Issue"],["Cisco Router","Support Request for Cisco Router ISR4331"],["Cisco Router","Frequent Disconnect Issues with Cisco Router ISR4331"],["Cisco Router","Cisco Router Outage"],["Cisco Router","Urgent: Frequent Network Drops Issue"],["Cisco Router","Urgent: Connectivity Issues with Cisco Router ISR4331"],["Cisco Router","Critical: Recurring Network Disruption Problem"],["Cisco Router","Network Issues with Cisco Router"],["Cisco Router" ...
